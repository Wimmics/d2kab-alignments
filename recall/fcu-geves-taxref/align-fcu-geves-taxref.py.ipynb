# %% [markdown]
# # Join French Crop Usage (FCU) with TAXREF-LD via GEVES scientific names
#
# Join FCU with TAXREF-LD using GEVES as an intermediate because GEVES has most FCU varieties and provides scientific names.
# Process:
# - join FCU with GEVES: where FCU variety name = GEVES species name
# - join only the matched GEVES species names with the scientific names in TAXREF-LD

# %% [markdown]
# ### Initializations

# %%
import sys
import json
import os
from string import Template
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON, POST
from time import sleep
from math import isnan, nan

# %%
sys.path.append('../..')
from utils import *

# %%
local_endpoint = 'http://localhost:8080/sparql'
fcu_endpoint = "http://ontology.inrae.fr/frenchcropusage/sparql"
#fcu_endpoint = "http://localhost:8080/sparql"
taxref_endpoint = "https://taxref.mnhn.fr/sparql"
geves_endpoint = "http://graph.i3s.unice.fr/repositories/geves"

# %% [markdown]
# ---
# ## Join FCU with GEVES: FCU varieties names = GEVES species

# %%
query =  prefixes + '''
select distinct ?fcu_concept ?fcu_name ?fcu_name_type ?geves_lab_spe_dus ?geves_scientific_name where {

    # Query FCU crops
    service <''' + fcu_endpoint + '''> {
        select distinct ?fcu_concept ?fcu_name ?fcu_name_type where {

            # Select cultivated and multi-usage crops
            { <http://ontology.inrae.fr/frenchcropusage/Usages_plantes_cultivees> skos:narrower+ ?fcu_concept. }
            UNION
            { <http://ontology.inrae.fr/frenchcropusage/Multi_usages> skos:narrower+ ?fcu_concept. }

            # Get prefered and alternate labels and keep track of the type of label
            # ?fcu_concept a skos:Concept.
            { ?fcu_concept skos:prefLabel ?lb. bind("pref" as ?fcu_name_type) }
            UNION
            { ?fcu_concept skos:altLabel  ?lb. bind("alt" as ?fcu_name_type) }

            bind(str(lcase(?lb)) as ?fcu_name)
        } order by ?fcu_concept
    }

    # Query GEVES
    optional {
        service <http://graph.i3s.unice.fr/repositories/geves> {
            [] 
                api:lab_spe_bota ?lab_spe_bota;
                api:lab_spe_dus ?geves_lab_spe_dus.
            bind(str(lcase(?lab_spe_bota))      as ?geves_scientific_name)
            bind(str(lcase(?geves_lab_spe_dus)) as ?geves_species)
        }

        # Match the GEVES species names and the FCU preferred/alternate labels:
        filter (?fcu_name = ?geves_species) 
    }
}'''

# %%
# %time df_fcu_geves = exec_sparql(local_endpoint, query)
# Out:
# Wall time: 11.8 s

# %%
dataframe_preview(df_fcu_geves, end=10)
# Out:
# == Number of lines: 1712
# == Number of unique values:
# fcu_concept               524
# fcu_name                 1656
# fcu_name_type               2
# geves_lab_spe_dus         104
# geves_scientific_name      98
# dtype: int64
#                                          fcu_concept                 fcu_name  \
# 0  http://ontology.inrae.fr/frenchcropusage/Abric...               abricotier
# 1  http://ontology.inrae.fr/frenchcropusage/Abric...                  abricot
# 2  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier pays
# 3  http://ontology.inrae.fr/frenchcropusage/Abric...             abricot pays
# 4  http://ontology.inrae.fr/frenchcropusage/Abric...  abricotier des antilles
# 5  http://ontology.inrae.fr/frenchcropusage/Abric...                    mamey
# 6  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier-pays
# 7  http://ontology.inrae.fr/frenchcropusage/Actin...                actinidia
# 8  http://ontology.inrae.fr/frenchcropusage/Actin...       groseille de chine
# 9  http://ontology.inrae.fr/frenchcropusage/Actin...                     kiwi
#
#   fcu_name_type geves_lab_spe_dus geves_scientific_name
# 0          pref        Abricotier   prunus armeniaca l.
# 1           alt              None                  None
# 2          pref              None                  None
# 3           alt              None                  None
# 4           alt              None                  None
# 5           alt              None                  None
# 6           alt              None                  None
# 7          pref              None                  None
# 8           alt              None                  None
# 9           alt              None                  None

# %%
df_fcu_geves.to_excel("result1_fcu_geves.xlsx")

# %% [markdown]
# #### Count only matches

# %%
dataframe_preview(df_fcu_geves.dropna())
# Out:
# == Number of lines: 115
# == Number of unique values:
# fcu_concept              108
# fcu_name                 104
# fcu_name_type              2
# geves_lab_spe_dus        104
# geves_scientific_name     98
# dtype: int64
#                                           fcu_concept  \
# 0   http://ontology.inrae.fr/frenchcropusage/Abric...
# 13      http://ontology.inrae.fr/frenchcropusage/Ails
# 21  http://ontology.inrae.fr/frenchcropusage/Amand...
# 68  http://ontology.inrae.fr/frenchcropusage/Artic...
# 69  http://ontology.inrae.fr/frenchcropusage/Artic...
# 71  http://ontology.inrae.fr/frenchcropusage/Asperges
# 80  http://ontology.inrae.fr/frenchcropusage/Auber...
# 86  http://ontology.inrae.fr/frenchcropusage/Avoin...
# 90  http://ontology.inrae.fr/frenchcropusage/Avoin...
# 92  http://ontology.inrae.fr/frenchcropusage/Avoin...
#
#                    fcu_name fcu_name_type        geves_lab_spe_dus  \
# 0                abricotier          pref               Abricotier
# 13                      ail          pref                      Ail
# 21                 amandier          pref                 Amandier
# 68                artichaut          pref                Artichaut
# 69                artichaut          pref                Artichaut
# 71                  asperge          pref                  Asperge
# 80                aubergine          pref                Aubergine
# 86           avoine d'hiver          pref           Avoine d'hiver
# 90       avoine nue d'hiver          pref       Avoine nue d'hiver
# 92  avoine nue de printemps          pref  Avoine nue de printemps
#
#        geves_scientific_name
# 0        prunus armeniaca l.
# 13         allium sativum l.
# 21  prunus amygdalus bartock
# 68           cynara scolymus
# 69     cynara cardunculus l.
# 71  asparagus officinalis l.
# 80      solanum melongena l.
# 86           avena sativa l.
# 90             avena nuda l.
# 92             avena nuda l.

# %% [markdown]
# ### Matches:
# - FCU: 108 unique concepts, 104 unique labels
# - GEVES: 104 unique species, 98 unique scientific names

# %% [markdown]
# ---
# ## Join GEVES with TAXREF-LD on scientific name, only on the GEVES species matched with FCU

# %%
# SPARQL query to TAXREF-LD to match a single GEVES scientific name (placeholder $geves_scientific_name)
queryTpl = Template(prefixes + '''
select distinct ("$geves_scientific_name" as ?geves_scientific_name) ?taxref_full_name ?taxref_name_type ?taxon ?rank 
from <http://taxref.mnhn.fr/lod/graph/classes/15.0>
from <http://taxref.mnhn.fr/lod/graph/vernacular/15.0>
from <http://taxref.mnhn.fr/lod/graph/concepts>
where {
    # ?name
       a                      skos:Concept, <http://rs.tdwg.org/ontology/voc/TaxonName#TaxonName>;
       rdfs:label             ?taxref_full_name.

    { ?name taxrefp:isReferenceNameOf ?taxon. bind("pref" as ?taxref_name_type) }
    union
    { ?name taxrefp:isSynonymOf       ?taxon. bind("alt" as ?taxref_name_type) }

    # ?taxon
       taxrefp:hasRank        ?rank.

    # All ranks up to spcecies but not above
    filter (?rank in (
        taxrefrk:Species,  taxrefrk:SemiSpecies, taxrefrk:MicroSpecies, taxrefrk:SubSpecies, taxrefrk:Natio, 
        taxrefrk:Varietas, taxrefrk:SubVarietas, taxrefrk:Forma,        taxrefrk:SubForma,   taxrefrk:FormaSpecies,
        taxrefrk:Linea,    taxrefrk:Clone,       taxrefrk:Race,         taxrefrk:Cultivar,   taxrefrk:Morpha,
        taxrefrk:Abberatio ))

    # TAXREF names have the authority and date, whereas GEVES names do not have the date.
    # => match the GEVES name as a subpart of the TAXREF name
    bind(str(lcase(?taxref_full_name)) as ?taxref_scn_sl)
    filter(strstarts(?taxref_scn_sl, "$geves_scientific_name"))
}
''')

# %%
# Set a max number of queries to submit. 0 = unlimited.
MAX_QUERIES = 0

# Result DataFrame
df_geves_taxref = pd.DataFrame()

idx = 1
df_fcu_geves_matched = df_fcu_geves.dropna()
unique_names = df_fcu_geves_matched.geves_scientific_name.unique()
for geves_scientific_name in unique_names:
    query = queryTpl.substitute(geves_scientific_name = geves_scientific_name.strip().lower())
    #print(query)
    
    print(f"---- Running query {idx}/{len(unique_names)} - geves_scientific_name = {geves_scientific_name}")
    # %time _df = exec_sparql(taxref_endpoint, query)
    print(f'Number of results: {_df.shape[0]}')
    df_geves_taxref = df_geves_taxref.append(_df)
    
    # Keep track of GEVES names not matched with TAXREF
    if _df.shape[0] == 0:
        nomatch_row = {'taxref_full_name': None, 'taxref_name_type': None, 'taxon': None, 'geves_scientific_name': geves_scientific_name.strip().lower()}
        df_geves_taxref = df_geves_taxref.append(nomatch_row, ignore_index=True)
    
    idx = idx + 1
    if MAX_QUERIES > 0 and idx > MAX_QUERIES:
        break
# Out:
# ---- Running query 1/98 - geves_scientific_name = prunus armeniaca l.
# Wall time: 8.79 s
# Number of results: 1
# ---- Running query 2/98 - geves_scientific_name = allium sativum l.
# Wall time: 10.1 s
# Number of results: 1
# ---- Running query 3/98 - geves_scientific_name = prunus amygdalus bartock
# Wall time: 10.3 s
# Number of results: 0
# ---- Running query 4/98 - geves_scientific_name = cynara scolymus
# Wall time: 8.53 s
# Number of results: 3
# ---- Running query 5/98 - geves_scientific_name = cynara cardunculus l.
# Wall time: 10.4 s
# Number of results: 1
# ---- Running query 6/98 - geves_scientific_name = asparagus officinalis l.
# Wall time: 8.85 s
# Number of results: 1
# ---- Running query 7/98 - geves_scientific_name = solanum melongena l.
# Wall time: 9.28 s
# Number of results: 1
# ---- Running query 8/98 - geves_scientific_name = avena sativa l.
# Wall time: 8.93 s
# Number of results: 1
# ---- Running query 9/98 - geves_scientific_name = avena nuda l.
# Wall time: 8.41 s
# Number of results: 1
# ---- Running query 10/98 - geves_scientific_name = avena strigosa schreb.
# Wall time: 9.46 s
# Number of results: 1
# ---- Running query 11/98 - geves_scientific_name = beta vulgaris l. ssp. vulgaris var. alba dc
# Wall time: 10.2 s
# Number of results: 0
# ---- Running query 12/98 - geves_scientific_name = beta vulgaris l. ssp. vulgaris var. saccharifera alef.
# Wall time: 9.54 s
# Number of results: 0
# ---- Running query 13/98 - geves_scientific_name = beta vulgaris l. ssp. vulgaris var. altissima doell
# Wall time: 10.2 s
# Number of results: 0
# ---- Running query 14/98 - geves_scientific_name = triticum durum desf.
# Wall time: 8.46 s
# Number of results: 1
# ---- Running query 15/98 - geves_scientific_name = triticum aestivum l.
# Wall time: 9.03 s
# Number of results: 1
# ---- Running query 16/98 - geves_scientific_name = daucus carota l.
# Wall time: 10 s
# Number of results: 1
# ---- Running query 17/98 - geves_scientific_name = ribes nigrum l.
# Wall time: 9.3 s
# Number of results: 1
# ---- Running query 18/98 - geves_scientific_name = citrus medica l.
# Wall time: 9.42 s
# Number of results: 1
# ---- Running query 19/98 - geves_scientific_name = apium graveolens l.
# Wall time: 9.86 s
# Number of results: 1
# ---- Running query 20/98 - geves_scientific_name = anthriscus cerefolium (l.) hoffm.
# Wall time: 9.66 s
# Number of results: 1
# ---- Running query 21/98 - geves_scientific_name = prunus cerasus l.
# Wall time: 9.12 s
# Number of results: 1
# ---- Running query 22/98 - geves_scientific_name = prunus avium l.
# Wall time: 9.56 s
# Number of results: 0
# ---- Running query 23/98 - geves_scientific_name = cannabis sativa l.
# Wall time: 8.61 s
# Number of results: 1
# ---- Running query 24/98 - geves_scientific_name = castanea vulgaris
# Wall time: 9.73 s
# Number of results: 1
# ---- Running query 25/98 - geves_scientific_name = cichorium intybus l.
# Wall time: 10.1 s
# Number of results: 1
# ---- Running query 26/98 - geves_scientific_name = brassica oleracea l. var. gemmifera zenker
# Wall time: 9.93 s
# Number of results: 0
# ---- Running query 27/98 - geves_scientific_name = brassica oleracea l. convar. capitata (l.) alef. var. sabauda l.
# Wall time: 8.6 s
# Number of results: 0
# ---- Running query 28/98 - geves_scientific_name = brassica oleracea l. convar. botrytis (l.) alef. var. cymosa duch.
# Wall time: 10.2 s
# Number of results: 0
# ---- Running query 29/98 - geves_scientific_name = brassica oleracea l. convar. capitata (l.) alef. var. alba dc.
# Wall time: 9.37 s
# Number of results: 0
# ---- Running query 30/98 - geves_scientific_name = brassica oleracea l. convar. capitata (l.) alef. var. rubra (l.) thell.
# Wall time: 8.36 s
# Number of results: 0
# ---- Running query 31/98 - geves_scientific_name = brassica pekinensis ( lour. ) rupr.
# Wall time: 9.69 s
# Number of results: 0
# ---- Running query 32/98 - geves_scientific_name = brassica oleracea l. convar. botrytis (l.) alef. var. botrytis
# Wall time: 9.42 s
# Number of results: 0
# ---- Running query 33/98 - geves_scientific_name = brassica oleracea l. convar. acephala ( dc. ) alef. var. medullosa thell.+ var. viridis
# Wall time: 8.96 s
# Number of results: 0
# ---- Running query 34/98 - geves_scientific_name = brassica oleracea l. convar. acephala (dc.) alef. var. gongylodes
# Wall time: 9.51 s
# Number of results: 0
# ---- Running query 35/98 - geves_scientific_name = allium schoenoprasum l.
# Wall time: 9.46 s
# Number of results: 1
# ---- Running query 36/98 - geves_scientific_name = citrus limon (l.) burm.
# Wall time: 9.43 s
# Number of results: 1
# ---- Running query 37/98 - geves_scientific_name = citrus clementina hort. ex. tan.
# Wall time: 8.03 s
# Number of results: 0
# ---- Running query 38/98 - geves_scientific_name = brassica napus l.
# Wall time: 10.5 s
# Number of results: 1
# ---- Running query 39/98 - geves_scientific_name = cucurbita pepo l.
# Wall time: 9.6 s
# Number of results: 1
# ---- Running query 40/98 - geves_scientific_name = foeniculum vulgare mill.
# Wall time: 9.84 s
# Number of results: 1
# ---- Running query 41/98 - geves_scientific_name = trigonella foenum-graecum l.
# Wall time: 8.73 s
# Number of results: 1
# ---- Running query 42/98 - geves_scientific_name = vicia faba l.
# Wall time: 9.08 s
# Number of results: 1
# ---- Running query 43/98 - geves_scientific_name = fragaria xananassa duch.
# Wall time: 7.16 s
# Number of results: 0
# ---- Running query 44/98 - geves_scientific_name = rubus idaeus l.
# Wall time: 9.66 s
# Number of results: 1
# ---- Running query 45/98 - geves_scientific_name = ribes rubrum l.
# Wall time: 9.79 s
# Number of results: 1
# ---- Running query 46/98 - geves_scientific_name = phaseolus vulgaris l.
# Wall time: 8.88 s
# Number of results: 1
# ---- Running query 47/98 - geves_scientific_name = phaseolus coccineus l.
# Wall time: 6.75 s
# Number of results: 1
# ---- Running query 48/98 - geves_scientific_name = lactuca sativa l.
# Wall time: 8.71 s
# Number of results: 1
# ---- Running query 49/98 - geves_scientific_name = lens culinaris medik.
# Wall time: 9.01 s
# Number of results: 1
# ---- Running query 50/98 - geves_scientific_name = linum usitatissimum l.
# Wall time: 10 s
# Number of results: 1
# ---- Running query 51/98 - geves_scientific_name = lotus corniculatus l.
# Wall time: 8.67 s
# Number of results: 1
# ---- Running query 52/98 - geves_scientific_name = lupinus albus l.
# Wall time: 8.26 s
# Number of results: 1
# ---- Running query 53/98 - geves_scientific_name = medicago sativa l.
# Wall time: 7.9 s
# Number of results: 1
# ---- Running query 54/98 - geves_scientific_name = valerianella locusta (l.) laterr.
# Wall time: 9.34 s
# Number of results: 1
# ---- Running query 55/98 - geves_scientific_name = zea mays l.
# Wall time: 9.59 s
# Number of results: 1
# ---- Running query 56/98 - geves_scientific_name = citrus deliciosa ten.
# Wall time: 8.71 s
# Number of results: 1
# ---- Running query 57/98 - geves_scientific_name = cucumis melo l.
# Wall time: 8.24 s
# Number of results: 1
# ---- Running query 58/98 - geves_scientific_name = brassica juncea (l.) czern.
# Wall time: 10.1 s
# Number of results: 1
# ---- Running query 59/98 - geves_scientific_name = brassica rapa l. subsp. campestris (l.) a. r. clapham
# Wall time: 9.5 s
# Number of results: 0
# ---- Running query 60/98 - geves_scientific_name = corylus avellana l.
# Wall time: 8.03 s
# Number of results: 1
# ---- Running query 61/98 - geves_scientific_name = juglans regia l.
# Wall time: 9.09 s
# Number of results: 1
# ---- Running query 62/98 - geves_scientific_name = allium cepa l.
# Wall time: 8.72 s
# Number of results: 1
# ---- Running query 63/98 - geves_scientific_name = olea europaea l.
# Wall time: 7.05 s
# Number of results: 1
# ---- Running query 64/98 - geves_scientific_name = citrus sinensis (l.) osb.
# Wall time: 10.1 s
# Number of results: 0
# ---- Running query 65/98 - geves_scientific_name = hordeum vulgare l.
# Wall time: 9.62 s
# Number of results: 1
# ---- Running query 66/98 - geves_scientific_name = prunus persica (l.) batsch
# Wall time: 7.43 s
# Number of results: 1
# ---- Running query 67/98 - geves_scientific_name = petroselinum crispum (mill.) nyman ex a. w. hill
# Wall time: 8.87 s
# Number of results: 0
# ---- Running query 68/98 - geves_scientific_name = phacelia tanacetifolia benth.
# Wall time: 9.37 s
# Number of results: 1
# ---- Running query 69/98 - geves_scientific_name = allium porrum l.
# Wall time: 9.54 s
# Number of results: 1
# ---- Running query 70/98 - geves_scientific_name = beta vulgaris l. ssp. vulgaris var. flavescens dc. f. crispa
# Wall time: 9.66 s
# Number of results: 0
# ---- Running query 71/98 - geves_scientific_name = cicer arietinum l.
# Wall time: 9.07 s
# Number of results: 1
# ---- Running query 72/98 - geves_scientific_name = pisum sativum l.
# Wall time: 7.73 s
# Number of results: 1
# ---- Running query 73/98 - geves_scientific_name = citrus paradisi macf.
# Wall time: 9.24 s
# Number of results: 0
# ---- Running query 74/98 - geves_scientific_name = solanum tuberosum l.
# Wall time: 9.1 s
# Number of results: 1
# ---- Running query 75/98 - geves_scientific_name = malus domestica borkh.
# Wall time: 9.53 s
# Number of results: 1
# ---- Running query 76/98 - geves_scientific_name = cucurbita maxima duchesne
# Wall time: 10.1 s
# Number of results: 1
# ---- Running query 77/98 - geves_scientific_name = prunus domestica l.
# Wall time: 7.56 s
# Number of results: 1
# ---- Running query 78/98 - geves_scientific_name = raphanus sativus l.
# Wall time: 8.53 s
# Number of results: 1
# ---- Running query 79/98 - geves_scientific_name = raphanus sativus l. var. oleiformis pers.
# Wall time: 10.6 s
# Number of results: 0
# ---- Running query 80/98 - geves_scientific_name = raphanus sativus l. var. niger
# Wall time: 9.92 s
# Number of results: 0
# ---- Running query 81/98 - geves_scientific_name = lolium × boucheanum kunth
# Wall time: 9.21 s
# Number of results: 0
# ---- Running query 82/98 - geves_scientific_name = oryza sativa l.
# Wall time: 9.89 s
# Number of results: 1
# ---- Running query 83/98 - geves_scientific_name = onobrychis viciifolia scop.
# Wall time: 10.4 s
# Number of results: 1
# ---- Running query 84/98 - geves_scientific_name = glycine max (l.) merr.
# Wall time: 8.47 s
# Number of results: 1
# ---- Running query 85/98 - geves_scientific_name = sorghum bicolor (l.) moench
# Wall time: 9.67 s
# Number of results: 1
# ---- Running query 86/98 - geves_scientific_name = sorghum sudanense (piper)
# Wall time: 8.48 s
# Number of results: 1
# ---- Running query 87/98 - geves_scientific_name = sorghum bicolor (l.) x sorghum sudanense (piper)
# Wall time: 7.83 s
# Number of results: 0
# ---- Running query 88/98 - geves_scientific_name = citrus reticulata blanco x citrus sinensis (l.) osb.
# Wall time: 9.57 s
# Number of results: 0
# ---- Running query 89/98 - geves_scientific_name = solanum lycopersicum l.
# Wall time: 9.66 s
# Number of results: 1
# ---- Running query 90/98 - geves_scientific_name = helianthus annuus l.
# Wall time: 9.72 s
# Number of results: 1
# ---- Running query 91/98 - geves_scientific_name = trifolium alexandrinum l.
# Wall time: 7.9 s
# Number of results: 1
# ---- Running query 92/98 - geves_scientific_name = trifolium repens l.
# Wall time: 9.14 s
# Number of results: 1
# ---- Running query 93/98 - geves_scientific_name = trifolium hybridum l.
# Wall time: 9.4 s
# Number of results: 1
# ---- Running query 94/98 - geves_scientific_name = trifolium incarnatum l.
# Wall time: 6.63 s
# Number of results: 1
# ---- Running query 95/98 - geves_scientific_name = trifolium michelianum savi var. balansae (boiss.) azn.
# Wall time: 9.54 s
# Number of results: 0
# ---- Running query 96/98 - geves_scientific_name = trifolium pratense l.
# Wall time: 8.29 s
# Number of results: 1
# ---- Running query 97/98 - geves_scientific_name = ×triticosecale wittm. ex a. camus
# Wall time: 9.46 s
# Number of results: 0
# ---- Running query 98/98 - geves_scientific_name = vicia pannonica crantz
# Wall time: 9.05 s
# Number of results: 1

# %%
df_geves_taxref.to_excel("result2_geves_taxref.xlsx")

# %%
dataframe_preview(df_geves_taxref)
# Out:
# == Number of lines: 100
# == Number of unique values:
# geves_scientific_name    98
# taxref_full_name         72
# taxref_name_type          2
# taxon                    70
# rank                      2
# dtype: int64
#       geves_scientific_name  \
# 0       prunus armeniaca l.
# 1         allium sativum l.
# 2  prunus amygdalus bartock
# 3           cynara scolymus
# 4           cynara scolymus
# 5           cynara scolymus
# 6     cynara cardunculus l.
# 7  asparagus officinalis l.
# 8      solanum melongena l.
# 9           avena sativa l.
#
#                                     taxref_full_name taxref_name_type  \
# 0                          Prunus armeniaca L., 1753             pref
# 1                            Allium sativum L., 1753             pref
# 2                                               None             None
# 3                           Cynara scolymus L., 1753             pref
# 4  Cynara scolymus subsp. cardunculus (L.) Bonnie...              alt
# 5  Cynara scolymus var. redonensis N.H.F.Desp., 1838              alt
# 6                        Cynara cardunculus L., 1753             pref
# 7                     Asparagus officinalis L., 1753             pref
# 8                         Solanum melongena L., 1753             pref
# 9                              Avena sativa L., 1753             pref
#
#                                     taxon  \
# 0  http://taxref.mnhn.fr/lod/taxon/116041
# 1   http://taxref.mnhn.fr/lod/taxon/81505
# 2                                    None
# 3   http://taxref.mnhn.fr/lod/taxon/93795
# 4   http://taxref.mnhn.fr/lod/taxon/93783
# 5   http://taxref.mnhn.fr/lod/taxon/93795
# 6   http://taxref.mnhn.fr/lod/taxon/93783
# 7   http://taxref.mnhn.fr/lod/taxon/84279
# 8  http://taxref.mnhn.fr/lod/taxon/124075
# 9   http://taxref.mnhn.fr/lod/taxon/85357
#
#                                         rank
# 0  http://taxref.mnhn.fr/lod/taxrank/Species
# 1  http://taxref.mnhn.fr/lod/taxrank/Species
# 2                                        NaN
# 3  http://taxref.mnhn.fr/lod/taxrank/Species
# 4  http://taxref.mnhn.fr/lod/taxrank/Species
# 5  http://taxref.mnhn.fr/lod/taxrank/Species
# 6  http://taxref.mnhn.fr/lod/taxrank/Species
# 7  http://taxref.mnhn.fr/lod/taxrank/Species
# 8  http://taxref.mnhn.fr/lod/taxrank/Species
# 9  http://taxref.mnhn.fr/lod/taxrank/Species

# %% [markdown]
# #### Count only matches

# %%
dataframe_preview(df_geves_taxref.dropna())
# Out:
# == Number of lines: 72
# == Number of unique values:
# geves_scientific_name    70
# taxref_full_name         72
# taxref_name_type          2
# taxon                    70
# rank                      2
# dtype: int64
#        geves_scientific_name  \
# 0        prunus armeniaca l.
# 1          allium sativum l.
# 3            cynara scolymus
# 4            cynara scolymus
# 5            cynara scolymus
# 6      cynara cardunculus l.
# 7   asparagus officinalis l.
# 8       solanum melongena l.
# 9            avena sativa l.
# 10             avena nuda l.
#
#                                      taxref_full_name taxref_name_type  \
# 0                           Prunus armeniaca L., 1753             pref
# 1                             Allium sativum L., 1753             pref
# 3                            Cynara scolymus L., 1753             pref
# 4   Cynara scolymus subsp. cardunculus (L.) Bonnie...              alt
# 5   Cynara scolymus var. redonensis N.H.F.Desp., 1838              alt
# 6                         Cynara cardunculus L., 1753             pref
# 7                      Asparagus officinalis L., 1753             pref
# 8                          Solanum melongena L., 1753             pref
# 9                               Avena sativa L., 1753             pref
# 10                                Avena nuda L., 1756             pref
#
#                                      taxon  \
# 0   http://taxref.mnhn.fr/lod/taxon/116041
# 1    http://taxref.mnhn.fr/lod/taxon/81505
# 3    http://taxref.mnhn.fr/lod/taxon/93795
# 4    http://taxref.mnhn.fr/lod/taxon/93783
# 5    http://taxref.mnhn.fr/lod/taxon/93795
# 6    http://taxref.mnhn.fr/lod/taxon/93783
# 7    http://taxref.mnhn.fr/lod/taxon/84279
# 8   http://taxref.mnhn.fr/lod/taxon/124075
# 9    http://taxref.mnhn.fr/lod/taxon/85357
# 10   http://taxref.mnhn.fr/lod/taxon/85323
#
#                                          rank
# 0   http://taxref.mnhn.fr/lod/taxrank/Species
# 1   http://taxref.mnhn.fr/lod/taxrank/Species
# 3   http://taxref.mnhn.fr/lod/taxrank/Species
# 4   http://taxref.mnhn.fr/lod/taxrank/Species
# 5   http://taxref.mnhn.fr/lod/taxrank/Species
# 6   http://taxref.mnhn.fr/lod/taxrank/Species
# 7   http://taxref.mnhn.fr/lod/taxrank/Species
# 8   http://taxref.mnhn.fr/lod/taxrank/Species
# 9   http://taxref.mnhn.fr/lod/taxrank/Species
# 10  http://taxref.mnhn.fr/lod/taxrank/Species

# %% [markdown]
# ### Matches:
# - GEVES: 70 unique scientific names
# - TAXREF-LD: 70 unique taxa
#
# => 28 GEVES names not matched with TAXREF-LD

# %% [markdown]
# ---
# ## Join intermediate results: FCU-GEVES and GEVES-TAXREFLD

# %%
df_merge = pd.merge(df_fcu_geves, df_geves_taxref, on="geves_scientific_name", how='left')
df_merge.drop_duplicates(inplace=True)
dataframe_preview(df_merge)
# Out:
# == Number of lines: 1714
# == Number of unique values:
# fcu_concept               524
# fcu_name                 1656
# fcu_name_type               2
# geves_lab_spe_dus         104
# geves_scientific_name      98
# taxref_full_name           72
# taxref_name_type            2
# taxon                      70
# rank                        2
# dtype: int64
#                                          fcu_concept                 fcu_name  \
# 0  http://ontology.inrae.fr/frenchcropusage/Abric...               abricotier
# 1  http://ontology.inrae.fr/frenchcropusage/Abric...                  abricot
# 2  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier pays
# 3  http://ontology.inrae.fr/frenchcropusage/Abric...             abricot pays
# 4  http://ontology.inrae.fr/frenchcropusage/Abric...  abricotier des antilles
# 5  http://ontology.inrae.fr/frenchcropusage/Abric...                    mamey
# 6  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier-pays
# 7  http://ontology.inrae.fr/frenchcropusage/Actin...                actinidia
# 8  http://ontology.inrae.fr/frenchcropusage/Actin...       groseille de chine
# 9  http://ontology.inrae.fr/frenchcropusage/Actin...                     kiwi
#
#   fcu_name_type geves_lab_spe_dus geves_scientific_name  \
# 0          pref        Abricotier   prunus armeniaca l.
# 1           alt              None                  None
# 2          pref              None                  None
# 3           alt              None                  None
# 4           alt              None                  None
# 5           alt              None                  None
# 6           alt              None                  None
# 7          pref              None                  None
# 8           alt              None                  None
# 9           alt              None                  None
#
#             taxref_full_name taxref_name_type  \
# 0  Prunus armeniaca L., 1753             pref
# 1                        NaN              NaN
# 2                        NaN              NaN
# 3                        NaN              NaN
# 4                        NaN              NaN
# 5                        NaN              NaN
# 6                        NaN              NaN
# 7                        NaN              NaN
# 8                        NaN              NaN
# 9                        NaN              NaN
#
#                                     taxon  \
# 0  http://taxref.mnhn.fr/lod/taxon/116041
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
#
#                                         rank
# 0  http://taxref.mnhn.fr/lod/taxrank/Species
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN

# %% [markdown]
# ### Count only matches

# %%
dataframe_preview(df_merge.dropna())
# Out:
# == Number of lines: 87
# == Number of unique values:
# fcu_concept              81
# fcu_name                 78
# fcu_name_type             2
# geves_lab_spe_dus        78
# geves_scientific_name    70
# taxref_full_name         72
# taxref_name_type          2
# taxon                    70
# rank                      2
# dtype: int64
#                                           fcu_concept            fcu_name  \
# 0   http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier
# 13      http://ontology.inrae.fr/frenchcropusage/Ails                 ail
# 68  http://ontology.inrae.fr/frenchcropusage/Artic...           artichaut
# 69  http://ontology.inrae.fr/frenchcropusage/Artic...           artichaut
# 70  http://ontology.inrae.fr/frenchcropusage/Artic...           artichaut
# 71  http://ontology.inrae.fr/frenchcropusage/Artic...           artichaut
# 73  http://ontology.inrae.fr/frenchcropusage/Asperges             asperge
# 82  http://ontology.inrae.fr/frenchcropusage/Auber...           aubergine
# 88  http://ontology.inrae.fr/frenchcropusage/Avoin...      avoine d'hiver
# 92  http://ontology.inrae.fr/frenchcropusage/Avoin...  avoine nue d'hiver
#
#    fcu_name_type   geves_lab_spe_dus     geves_scientific_name  \
# 0           pref          Abricotier       prunus armeniaca l.
# 13          pref                 Ail         allium sativum l.
# 68          pref           Artichaut           cynara scolymus
# 69          pref           Artichaut           cynara scolymus
# 70          pref           Artichaut           cynara scolymus
# 71          pref           Artichaut     cynara cardunculus l.
# 73          pref             Asperge  asparagus officinalis l.
# 82          pref           Aubergine      solanum melongena l.
# 88          pref      Avoine d'hiver           avena sativa l.
# 92          pref  Avoine nue d'hiver             avena nuda l.
#
#                                      taxref_full_name taxref_name_type  \
# 0                           Prunus armeniaca L., 1753             pref
# 13                            Allium sativum L., 1753             pref
# 68                           Cynara scolymus L., 1753             pref
# 69  Cynara scolymus subsp. cardunculus (L.) Bonnie...              alt
# 70  Cynara scolymus var. redonensis N.H.F.Desp., 1838              alt
# 71                        Cynara cardunculus L., 1753             pref
# 73                     Asparagus officinalis L., 1753             pref
# 82                         Solanum melongena L., 1753             pref
# 88                              Avena sativa L., 1753             pref
# 92                                Avena nuda L., 1756             pref
#
#                                      taxon  \
# 0   http://taxref.mnhn.fr/lod/taxon/116041
# 13   http://taxref.mnhn.fr/lod/taxon/81505
# 68   http://taxref.mnhn.fr/lod/taxon/93795
# 69   http://taxref.mnhn.fr/lod/taxon/93783
# 70   http://taxref.mnhn.fr/lod/taxon/93795
# 71   http://taxref.mnhn.fr/lod/taxon/93783
# 73   http://taxref.mnhn.fr/lod/taxon/84279
# 82  http://taxref.mnhn.fr/lod/taxon/124075
# 88   http://taxref.mnhn.fr/lod/taxon/85357
# 92   http://taxref.mnhn.fr/lod/taxon/85323
#
#                                          rank
# 0   http://taxref.mnhn.fr/lod/taxrank/Species
# 13  http://taxref.mnhn.fr/lod/taxrank/Species
# 68  http://taxref.mnhn.fr/lod/taxrank/Species
# 69  http://taxref.mnhn.fr/lod/taxrank/Species
# 70  http://taxref.mnhn.fr/lod/taxrank/Species
# 71  http://taxref.mnhn.fr/lod/taxrank/Species
# 73  http://taxref.mnhn.fr/lod/taxrank/Species
# 82  http://taxref.mnhn.fr/lod/taxrank/Species
# 88  http://taxref.mnhn.fr/lod/taxrank/Species
# 92  http://taxref.mnhn.fr/lod/taxrank/Species

# %% [markdown]
# ### Matches
# - FCU: 81 unique concepts, 78 unique labels
# - TAXREF-LD: 70 unique taxa from 2 ranks

# %% [markdown]
# ### Exports

# %%
df_merge.to_excel("result3_fcu_geves_taxref.xlsx")

# %%
# Reshape the DataFrame for later merging with other methods
df_merge.dropna(inplace=True)
df_merge.drop(columns=['fcu_name_type', 'fcu_name', 'geves_scientific_name', 'taxref_name_type'], inplace=True)
df_merge.rename(columns={'taxref_full_name': 'taxref_ref_full_name'}, inplace=True)
df_merge.insert(1, 'method', 'geves')
df_merge.rename(columns={"geves_lab_spe_dus": "geves_name"}, inplace=True)
df_merge.insert(3, 'eppo_scientific_name', '')

# %%
dataframe_preview(df_merge)
df_merge.to_excel("result3_fcu_geves_taxref_merge.xlsx", index=False)
df_merge.to_csv("result3_fcu_geves_taxref_merge.csv", index=False)
# Out:
# == Number of lines: 87
# == Number of unique values:
# fcu_concept             81
# method                   1
# geves_name              78
# eppo_scientific_name     1
# taxref_ref_full_name    72
# taxon                   70
# rank                     2
# dtype: int64
#                                           fcu_concept method  \
# 0   http://ontology.inrae.fr/frenchcropusage/Abric...  geves
# 13      http://ontology.inrae.fr/frenchcropusage/Ails  geves
# 68  http://ontology.inrae.fr/frenchcropusage/Artic...  geves
# 69  http://ontology.inrae.fr/frenchcropusage/Artic...  geves
# 70  http://ontology.inrae.fr/frenchcropusage/Artic...  geves
# 71  http://ontology.inrae.fr/frenchcropusage/Artic...  geves
# 73  http://ontology.inrae.fr/frenchcropusage/Asperges  geves
# 82  http://ontology.inrae.fr/frenchcropusage/Auber...  geves
# 88  http://ontology.inrae.fr/frenchcropusage/Avoin...  geves
# 92  http://ontology.inrae.fr/frenchcropusage/Avoin...  geves
#
#             geves_name eppo_scientific_name  \
# 0           Abricotier
# 13                 Ail
# 68           Artichaut
# 69           Artichaut
# 70           Artichaut
# 71           Artichaut
# 73             Asperge
# 82           Aubergine
# 88      Avoine d'hiver
# 92  Avoine nue d'hiver
#
#                                  taxref_ref_full_name  \
# 0                           Prunus armeniaca L., 1753
# 13                            Allium sativum L., 1753
# 68                           Cynara scolymus L., 1753
# 69  Cynara scolymus subsp. cardunculus (L.) Bonnie...
# 70  Cynara scolymus var. redonensis N.H.F.Desp., 1838
# 71                        Cynara cardunculus L., 1753
# 73                     Asparagus officinalis L., 1753
# 82                         Solanum melongena L., 1753
# 88                              Avena sativa L., 1753
# 92                                Avena nuda L., 1756
#
#                                      taxon  \
# 0   http://taxref.mnhn.fr/lod/taxon/116041
# 13   http://taxref.mnhn.fr/lod/taxon/81505
# 68   http://taxref.mnhn.fr/lod/taxon/93795
# 69   http://taxref.mnhn.fr/lod/taxon/93783
# 70   http://taxref.mnhn.fr/lod/taxon/93795
# 71   http://taxref.mnhn.fr/lod/taxon/93783
# 73   http://taxref.mnhn.fr/lod/taxon/84279
# 82  http://taxref.mnhn.fr/lod/taxon/124075
# 88   http://taxref.mnhn.fr/lod/taxon/85357
# 92   http://taxref.mnhn.fr/lod/taxon/85323
#
#                                          rank
# 0   http://taxref.mnhn.fr/lod/taxrank/Species
# 13  http://taxref.mnhn.fr/lod/taxrank/Species
# 68  http://taxref.mnhn.fr/lod/taxrank/Species
# 69  http://taxref.mnhn.fr/lod/taxrank/Species
# 70  http://taxref.mnhn.fr/lod/taxrank/Species
# 71  http://taxref.mnhn.fr/lod/taxrank/Species
# 73  http://taxref.mnhn.fr/lod/taxrank/Species
# 82  http://taxref.mnhn.fr/lod/taxrank/Species
# 88  http://taxref.mnhn.fr/lod/taxrank/Species
# 92  http://taxref.mnhn.fr/lod/taxrank/Species
