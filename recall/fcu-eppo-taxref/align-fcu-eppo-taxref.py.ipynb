# %% [markdown]
# # Join French Crop Usage (FCU) - EPPO - TAXREF-LD - V2
#
# EPPO Global Database: https://gd.eppo.int/
#
# Changeswrt. V1:
# - only consider FCU leaves or their direct parents
# - only consider FCU crops under "usage des plantes cultivées", ignore "multi-usage" which is too ambiguous
# - keep all alignements to TAXREF, do not try to keep only one

# %% [markdown]
# ### Initializations

# %%
import sys
import json
import os
from string import Template
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON, POST
from time import sleep
from math import isnan, nan
import numpy as np
import requests
from http import HTTPStatus

# %%
sys.path.append('../..')
from utils import *

# %%
fcu_endpoint = "http://ontology.inrae.fr/frenchcropusage/sparql"
#fcu_endpoint = "http://localhost:8080/sparql"
taxref_endpoint = "https://taxref.mnhn.fr/sparql"

# %%
# EPPO API endpoint and private key
eppo_url = 'https://data.eppo.int/api/rest/1.0/'
eppo_key = 'f09732fd7fad725157edd884c825e46a'

# %% [markdown]
# ___
# # Get all varieties from FCU

# %%
query =  prefixes + '''
select distinct ?fcu_concept ?fcu_name ?fcu_name_type where {

    # Select cultivated and multi-usage crops
    { <http://ontology.inrae.fr/frenchcropusage/Usages_plantes_cultivees> skos:narrower+ ?fcu_concept. }
    UNION
    { <http://ontology.inrae.fr/frenchcropusage/Multi_usages> skos:narrower+ ?fcu_concept. }

    # Get prefered and alternate labels and keep track of the type of label
    # ?fcu_concept a skos:Concept.
    { ?fcu_concept skos:prefLabel ?lb. bind("pref" as ?fcu_name_type) }
    UNION
    { ?fcu_concept skos:altLabel  ?lb. bind("alt" as ?fcu_name_type) }

    bind(str(lcase(?lb)) as ?fcu_name)

} order by ?fcu_concept
'''

# %%
# %time df_fcu = exec_sparql(fcu_endpoint, query)
# Out:
# Wall time: 252 ms

# %%
# Add empty columns for the next steps
df_fcu["eppo_code"] = None
df_fcu["scientific_name"] = None

# %%
dataframe_preview(df_fcu, end=5)
# Out:
# == Number of lines: 1706
# == Number of unique values:
# fcu_concept         524
# fcu_name           1656
# fcu_name_type         2
# eppo_code             0
# scientific_name       0
# dtype: int64
#                                          fcu_concept                 fcu_name  \
# 0  http://ontology.inrae.fr/frenchcropusage/Abric...                  abricot
# 1  http://ontology.inrae.fr/frenchcropusage/Abric...               abricotier
# 2  http://ontology.inrae.fr/frenchcropusage/Abric...             abricot pays
# 3  http://ontology.inrae.fr/frenchcropusage/Abric...  abricotier des antilles
# 4  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier pays
#
#   fcu_name_type eppo_code scientific_name
# 0           alt      None            None
# 1          pref      None            None
# 2           alt      None            None
# 3           alt      None            None
# 4          pref      None            None

# %% [markdown]
# ____
# # Get EPPO codes and scientific names corresponding to FCU names
#
# EPPO API documentation: https://data.eppo.int/documentation/rest
#
# ## Get EPPO codes of FCU names
#
# EPPO API names2codes takes a pipe-separated list of names and returns a pipe-separated list of pairs 'name;code'.

# %%
# Build the pipe-separated list of FCU names
concat_fcu_concepts = ''
for _index, row in df_fcu.iterrows():
    if concat_fcu_concepts != '':
        concat_fcu_concepts += '|'
    concat_fcu_concepts += row['fcu_name'].strip()

# Query EPPO for codes corresponding to the list of names
eppo_query = eppo_url + 'tools/names2codes'
query = {'intext': concat_fcu_concepts, 'authtoken': eppo_key}
api_response = requests.post(eppo_query, data = query)

response = {}
if (api_response.status_code != HTTPStatus.OK):
    print('Cannot query PDDO API. Reaons: ' + api_response.reason + '. Content: ' + api_response.text)
    exit()

# The API response is formatted as 'name;code|name;code|...'
_response = json.loads(api_response.content)["response"]
_df_index = 0
for _entry in _response.split('|'):
    _y = _entry.split(';')
    #print('EEPO answer: ' + _entry)
    if (_y[1] != "****NOT FOUND*****"):
        if df_fcu.at[_df_index, 'fcu_name'].strip() != _y[0]:
            print('Lines mismatch error. FCU name: ' + df_fcu.at[_df_index, 'fcu_name'].strip() + ', EPPO result name: ' + _y[0])
        else:
            df_fcu.at[_df_index, 'eppo_code'] = _y[1]
    _df_index = _df_index + 1

# %%
dataframe_preview(df_fcu, end=10)
# Out:
# == Number of lines: 1706
# == Number of unique values:
# fcu_concept         524
# fcu_name           1656
# fcu_name_type         2
# eppo_code           355
# scientific_name       0
# dtype: int64
#                                          fcu_concept                 fcu_name  \
# 0  http://ontology.inrae.fr/frenchcropusage/Abric...                  abricot
# 1  http://ontology.inrae.fr/frenchcropusage/Abric...               abricotier
# 2  http://ontology.inrae.fr/frenchcropusage/Abric...             abricot pays
# 3  http://ontology.inrae.fr/frenchcropusage/Abric...  abricotier des antilles
# 4  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier pays
# 5  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier-pays
# 6  http://ontology.inrae.fr/frenchcropusage/Abric...                    mamey
# 7  http://ontology.inrae.fr/frenchcropusage/Actin...                actinidia
# 8  http://ontology.inrae.fr/frenchcropusage/Actin...               actinidier
# 9  http://ontology.inrae.fr/frenchcropusage/Actin...       groseille de chine
#
#   fcu_name_type eppo_code scientific_name
# 0           alt      None            None
# 1          pref     PRNAR            None
# 2           alt      None            None
# 3           alt     MAFAM            None
# 4          pref      None            None
# 5           alt      None            None
# 6           alt     POJSA            None
# 7          pref     ATICH            None
# 8           alt      None            None
# 9           alt      None            None

# %% [markdown]
# ## Get the scientific name of each EPPO code
#
# Query the EPPO API again to get the scientific name corresponding to each of the EPPO codes retrieved.

# %%
# Set a max number of queries to submit. 0 = unlimited.
MAX_QUERIES = 0

eppo_query_tpl =  Template(eppo_url + 'taxon/$EPPOCODE/taxonomy?authtoken=' + eppo_key)

for _index, row in df_fcu.iterrows():
    if row['eppo_code'] is not None:
        print(f"---- Running query {_index + 1}/{len(df_fcu)} - fcu_name = {row['fcu_name']}, EPPO code: {row['eppo_code']}")
        eppo_query = eppo_query_tpl.substitute(EPPOCODE = row['eppo_code'].strip())
        #print(eppo_query)

        api_response = requests.get(eppo_query)
        if (api_response.status_code != HTTPStatus.OK):
            print('Cannot query EPPO API. Reaons: ' + api_response.reason + '. Content: ' + api_response.text)
        else:
            # Parse the result and extract only the name with taxonomic rank 'species' = highest value of 'level', 8 or 9 in general
            _response = json.loads(api_response.content)
            # The response is a JSON array where each element is a document like:
            # { "codeid": 41521,
            #   "eppocode": "PRNAR",
            #   "prefname": "Prunus armeniaca",
            #   "level": 9 }
            #species = list(filter(lambda r: r['level'] == 9, _response))
            species = {'level': 0}
            for r in _response:
                if r['level'] >= species['level']:
                    species = r

            # Get the scientific name of the name with highest rank
            if 'prefname' in species:
                df_fcu.at[_index, 'scientific_name'] = species['prefname']

    if MAX_QUERIES > 0 and (_index + 1) >= MAX_QUERIES:
        break
# Out:
# ---- Running query 2/1706 - fcu_name = abricotier, EPPO code: PRNAR
# ---- Running query 4/1706 - fcu_name = abricotier des antilles, EPPO code: MAFAM
# ---- Running query 7/1706 - fcu_name = mamey, EPPO code: POJSA
# ---- Running query 8/1706 - fcu_name = actinidia, EPPO code: ATICH
# ---- Running query 11/1706 - fcu_name = kiwi, EPPO code: ATICH
# ---- Running query 14/1706 - fcu_name = ail, EPPO code: ALLSA
# ---- Running query 15/1706 - fcu_name = ail commun, EPPO code: ALLSA
# ---- Running query 16/1706 - fcu_name = ail cultivé, EPPO code: ALLSA
# ---- Running query 17/1706 - fcu_name = aillet, EPPO code: ALLVI
# ---- Running query 18/1706 - fcu_name = alpiste, EPPO code: PHABR
# ---- Running query 19/1706 - fcu_name = alpiste des canaries, EPPO code: PHACA
# ---- Running query 24/1706 - fcu_name = amande douce, EPPO code: QPHOV
# ---- Running query 26/1706 - fcu_name = amandier, EPPO code: PRNDU
# ---- Running query 27/1706 - fcu_name = ananas, EPPO code: ANHCO
# ---- Running query 29/1706 - fcu_name = aneth, EPPO code: AFEGR
# ---- Running query 30/1706 - fcu_name = faux anis, EPPO code: AFEGR
# ---- Running query 31/1706 - fcu_name = fenouil bâtard, EPPO code: AFEGR
# ---- Running query 32/1706 - fcu_name = angélique, EPPO code: DJYGU
# ---- Running query 33/1706 - fcu_name = angélique officinale, EPPO code: ANKAR
# ---- Running query 34/1706 - fcu_name = archangélique, EPPO code: ANKAR
# ---- Running query 35/1706 - fcu_name = anis, EPPO code: PIMAN
# ---- Running query 36/1706 - fcu_name = anis vert, EPPO code: PIMAN
# ---- Running query 38/1706 - fcu_name = arachide, EPPO code: ARHHY
# ---- Running query 40/1706 - fcu_name = cacahuète, EPPO code: ARHHY
# ---- Running query 69/1706 - fcu_name = artichaut, EPPO code: CYUSC
# ---- Running query 71/1706 - fcu_name = asperge, EPPO code: HYSOF
# ---- Running query 72/1706 - fcu_name = asperge blanche, EPPO code: ASPAL
# ---- Running query 74/1706 - fcu_name = asperge violette, EPPO code: LDUAB
# ---- Running query 77/1706 - fcu_name = attier, EPPO code: ANUSQ
# ---- Running query 79/1706 - fcu_name = pommier cannelle, EPPO code: ANUSQ
# ---- Running query 80/1706 - fcu_name = aubergine, EPPO code: SOLME
# ---- Running query 82/1706 - fcu_name = avocatier, EPPO code: PEBAM
# ---- Running query 85/1706 - fcu_name = avoine cultivée, EPPO code: AVESA
# ---- Running query 88/1706 - fcu_name = avoine nue, EPPO code: AVENU
# ---- Running query 89/1706 - fcu_name = avoine à gruau, EPPO code: AVENU
# ---- Running query 99/1706 - fcu_name = avoine rude, EPPO code: AVESG
# ---- Running query 100/1706 - fcu_name = anis étoilé, EPPO code: ILLVE
# ---- Running query 102/1706 - fcu_name = badianier de chine, EPPO code: ILLVE
# ---- Running query 107/1706 - fcu_name = bananier, EPPO code: MUBPA
# ---- Running query 121/1706 - fcu_name = plantain, EPPO code: MUBPA
# ---- Running query 123/1706 - fcu_name = grande bardane, EPPO code: ARFLA
# ---- Running query 124/1706 - fcu_name = basilic, EPPO code: OCIBA
# ---- Running query 126/1706 - fcu_name = betterave, EPPO code: BEAVX
# ---- Running query 129/1706 - fcu_name = betterave fourragère, EPPO code: BEAVC
# ---- Running query 131/1706 - fcu_name = betterave potagère, EPPO code: BEAVD
# ---- Running query 140/1706 - fcu_name = bigarade, EPPO code: CIDAU
# ---- Running query 141/1706 - fcu_name = bigaradier, EPPO code: CIDAU
# ---- Running query 145/1706 - fcu_name = orange amère, EPPO code: CIDAU
# ---- Running query 146/1706 - fcu_name = blé, EPPO code: TRZAX
# ---- Running query 147/1706 - fcu_name = froment, EPPO code: TRZAX
# ---- Running query 148/1706 - fcu_name = blé dur, EPPO code: TRZDU
# ---- Running query 151/1706 - fcu_name = semoule, EPPO code: BOMCE
# ---- Running query 156/1706 - fcu_name = blé tendre, EPPO code: TRZAX
# ---- Running query 158/1706 - fcu_name = froment, EPPO code: TRZAX
# ---- Running query 164/1706 - fcu_name = audifoin, EPPO code: CENCY
# ---- Running query 165/1706 - fcu_name = barbeau, EPPO code: CENCY
# ---- Running query 167/1706 - fcu_name = bleuet, EPPO code: VACMY
# ---- Running query 168/1706 - fcu_name = bleuet des champs, EPPO code: CENCY
# ---- Running query 169/1706 - fcu_name = bleuet des montagnes, EPPO code: CENMO
# ---- Running query 170/1706 - fcu_name = bleuet vivace, EPPO code: CENCY
# ---- Running query 172/1706 - fcu_name = jacée des montagnes, EPPO code: CENMO
# ---- Running query 177/1706 - fcu_name = bourrache, EPPO code: BOROF
# ---- Running query 178/1706 - fcu_name = bourrache officinale, EPPO code: BOROF
# ---- Running query 180/1706 - fcu_name = brède mafane, EPPO code: SPLOL
# ---- Running query 184/1706 - fcu_name = rapini, EPPO code: BRSRE
# ---- Running query 190/1706 - fcu_name = bugle rampante, EPPO code: AIURE
# ---- Running query 191/1706 - fcu_name = cacao, EPPO code: THOCA
# ---- Running query 194/1706 - fcu_name = café, EPPO code: COFAR
# ---- Running query 197/1706 - fcu_name = calebasse, EPPO code: LGNSI
# ---- Running query 202/1706 - fcu_name = gourde, EPPO code: CUUPE
# ---- Running query 207/1706 - fcu_name = sésame d'allemagne, EPPO code: CMASA
# ---- Running query 209/1706 - fcu_name = camomille romaine, EPPO code: ANTNO
# ---- Running query 213/1706 - fcu_name = canneberge, EPPO code: VACOX
# ---- Running query 218/1706 - fcu_name = canne à sucre, EPPO code: SACOF
# ---- Running query 219/1706 - fcu_name = câprier, EPPO code: CDBGL
# ---- Running query 220/1706 - fcu_name = carambole, EPPO code: ALLAM
# ---- Running query 221/1706 - fcu_name = carambolier, EPPO code: AVRCA
# ---- Running query 223/1706 - fcu_name = cardamome, EPPO code: ETACA
# ---- Running query 224/1706 - fcu_name = artichaut sauvage, EPPO code: CYUCA
# ---- Running query 225/1706 - fcu_name = carde, EPPO code: BEAVV
# ---- Running query 226/1706 - fcu_name = cardon, EPPO code: CYUCA
# ---- Running query 227/1706 - fcu_name = carotte, EPPO code: DAUCA
# ---- Running query 231/1706 - fcu_name = caroubier, EPPO code: CEQSI
# ---- Running query 234/1706 - fcu_name = anis des vosges, EPPO code: CRYCA
# ---- Running query 235/1706 - fcu_name = carvi, EPPO code: CRYCA
# ---- Running query 237/1706 - fcu_name = cumin des prés, EPPO code: CRYCA
# ---- Running query 238/1706 - fcu_name = cassis, EPPO code: RIBNI
# ---- Running query 239/1706 - fcu_name = cassissier, EPPO code: RIBNI
# ---- Running query 241/1706 - fcu_name = cédratier, EPPO code: CIDME
# ---- Running query 242/1706 - fcu_name = ache des marais, EPPO code: APUGV
# ---- Running query 244/1706 - fcu_name = céleri, EPPO code: APUGV
# ---- Running query 245/1706 - fcu_name = persil des marais, EPPO code: CIUVI
# ---- Running query 250/1706 - fcu_name = céleri à couper, EPPO code: APUGS
# ---- Running query 252/1706 - fcu_name = céleri rave, EPPO code: APUGR
# ---- Running query 254/1706 - fcu_name = céleri-rave, EPPO code: APUGR
# ---- Running query 266/1706 - fcu_name = cerfeuil, EPPO code: ANRCE
# ---- Running query 267/1706 - fcu_name = cerfeuil anisé, EPPO code: MYHOD
# ---- Running query 268/1706 - fcu_name = cerfeuil d'espagne, EPPO code: MYHOD
# ---- Running query 269/1706 - fcu_name = cerfeuil musqué, EPPO code: MYHOD
# ---- Running query 271/1706 - fcu_name = fougère musquée, EPPO code: MYHOD
# ---- Running query 274/1706 - fcu_name = myrrhe, EPPO code: COQAB
# ---- Running query 275/1706 - fcu_name = myrrhis odorant, EPPO code: MYHOD
# ---- Running query 276/1706 - fcu_name = cerfeuil commun, EPPO code: ANRCE
# ---- Running query 277/1706 - fcu_name = cerfeuil cultivé, EPPO code: ANRCE
# ---- Running query 280/1706 - fcu_name = cerfeuil bulbeux, EPPO code: CHPBU
# ---- Running query 281/1706 - fcu_name = cerfeuil tubéreux, EPPO code: CHPBU
# ---- Running query 283/1706 - fcu_name = chérophylle bulbeux, EPPO code: CHPBU
# ---- Running query 292/1706 - fcu_name = cerisier acide, EPPO code: PRNCE
# ---- Running query 295/1706 - fcu_name = guigne, EPPO code: PRNAV
# ---- Running query 296/1706 - fcu_name = guignier, EPPO code: PRNAV
# ---- Running query 298/1706 - fcu_name = merisier, EPPO code: PRNAV
# ---- Running query 302/1706 - fcu_name = cerisier de cayenne, EPPO code: EUEUN
# ---- Running query 303/1706 - fcu_name = champignon, EPPO code: AGARBI
# ---- Running query 304/1706 - fcu_name = champignon de couche, EPPO code: AGARBI
# ---- Running query 305/1706 - fcu_name = champignon de paris, EPPO code: AGARBI
# ---- Running query 307/1706 - fcu_name = cannabis, EPPO code: CNISI
# ---- Running query 308/1706 - fcu_name = chanvre, EPPO code: CNISA
# ---- Running query 309/1706 - fcu_name = chanvre cultivé, EPPO code: CNISA
# ---- Running query 326/1706 - fcu_name = chardon marie, EPPO code: SLYMA
# ---- Running query 330/1706 - fcu_name = châtaignier, EPPO code: CSNSA
# ---- Running query 331/1706 - fcu_name = châtaignier commun, EPPO code: CSNSA
# ---- Running query 336/1706 - fcu_name = chêne pédonculé, EPPO code: QUERO
# ---- Running query 337/1706 - fcu_name = chêne rouvre, EPPO code: QUEPE
# ---- Running query 338/1706 - fcu_name = chicorée, EPPO code: CICIN
# ---- Running query 339/1706 - fcu_name = chicorée sauvage, EPPO code: CICIN
# ---- Running query 344/1706 - fcu_name = endive, EPPO code: CICEN
# ---- Running query 346/1706 - fcu_name = chicorée frisée, EPPO code: CICEC
# ---- Running query 347/1706 - fcu_name = frisée, EPPO code: CICEN
# ---- Running query 354/1706 - fcu_name = chicorée à café, EPPO code: CICIS
# ---- Running query 356/1706 - fcu_name = chicorée, EPPO code: CICIN
# ---- Running query 359/1706 - fcu_name = endive, EPPO code: CICEN
# ---- Running query 361/1706 - fcu_name = chicorée scarole, EPPO code: CICEL
# ---- Running query 365/1706 - fcu_name = scarole, EPPO code: LACSE
# ---- Running query 366/1706 - fcu_name = chou, EPPO code: BRSOX
# ---- Running query 367/1706 - fcu_name = chou de bruxelles, EPPO code: BRSOF
# ---- Running query 369/1706 - fcu_name = chou de milan, EPPO code: BRSOS
# ---- Running query 370/1706 - fcu_name = chou de savoie, EPPO code: BRSOS
# ---- Running query 372/1706 - fcu_name = brocoli, EPPO code: BRSOK
# ---- Running query 373/1706 - fcu_name = chou brocoli, EPPO code: BRSOK
# ---- Running query 375/1706 - fcu_name = chou cabus blanc, EPPO code: BRSOL
# ---- Running query 380/1706 - fcu_name = chou rouge, EPPO code: BRSOR
# ---- Running query 381/1706 - fcu_name = bok choy, EPPO code: BRSCH
# ---- Running query 383/1706 - fcu_name = chou chinois, EPPO code: BRSPK
# ---- Running query 384/1706 - fcu_name = chou de chine, EPPO code: BRSPK
# ---- Running query 386/1706 - fcu_name = chou de shanton, EPPO code: BRSPK
# ---- Running query 392/1706 - fcu_name = chou commun, EPPO code: BRSOM
# ---- Running query 393/1706 - fcu_name = chou vert, EPPO code: BRSOA
# ---- Running query 395/1706 - fcu_name = chou-fleur, EPPO code: BRSOB
# ---- Running query 396/1706 - fcu_name = chou branchu, EPPO code: BRSOQ
# ---- Running query 397/1706 - fcu_name = chou cavalier, EPPO code: BRSOA
# ---- Running query 399/1706 - fcu_name = chou fourrager, EPPO code: BRSOA
# ---- Running query 400/1706 - fcu_name = chou moellier, EPPO code: BRSOM
# ---- Running query 402/1706 - fcu_name = chou frangé, EPPO code: BRSOC
# ---- Running query 403/1706 - fcu_name = chou frisé, EPPO code: BRSOC
# ---- Running query 405/1706 - fcu_name = chou lacinié, EPPO code: BRSOC
# ---- Running query 407/1706 - fcu_name = chou vert, EPPO code: BRSOA
# ---- Running query 408/1706 - fcu_name = chou navet, EPPO code: BRSOG
# ---- Running query 413/1706 - fcu_name = rutabaga, EPPO code: BRSNA
# ---- Running query 415/1706 - fcu_name = chou pommé, EPPO code: BRSOL
# ---- Running query 416/1706 - fcu_name = chou, EPPO code: BRSOX
# ---- Running query 419/1706 - fcu_name = chou potager, EPPO code: BRSOL
# ---- Running query 420/1706 - fcu_name = palmier royal, EPPO code: ROYRE
# ---- Running query 421/1706 - fcu_name = palmiste, EPPO code: DKNNO
# ---- Running query 425/1706 - fcu_name = chou rave, EPPO code: BRSOG
# ---- Running query 426/1706 - fcu_name = chou-rave, EPPO code: BRSRA
# ---- Running query 431/1706 - fcu_name = chou vert, EPPO code: BRSOA
# ---- Running query 433/1706 - fcu_name = chayote, EPPO code: SEHED
# ---- Running query 434/1706 - fcu_name = chayotte, EPPO code: SEHED
# ---- Running query 435/1706 - fcu_name = chouchou, EPPO code: SEHED
# ---- Running query 436/1706 - fcu_name = chouchoute, EPPO code: SEHED
# ---- Running query 437/1706 - fcu_name = christophine, EPPO code: SEHED
# ---- Running query 441/1706 - fcu_name = ail fistuleux, EPPO code: ALLFI
# ---- Running query 444/1706 - fcu_name = ciboule, EPPO code: ALLFI
# ---- Running query 445/1706 - fcu_name = cive, EPPO code: ALLFI
# ---- Running query 446/1706 - fcu_name = oignon d'espagne, EPPO code: ALLFI
# ---- Running query 449/1706 - fcu_name = ciboulette, EPPO code: ALLSC
# ---- Running query 450/1706 - fcu_name = civette, EPPO code: ALLSC
# ---- Running query 451/1706 - fcu_name = citron, EPPO code: CIDLI
# ---- Running query 452/1706 - fcu_name = citronnier, EPPO code: CIDLI
# ---- Running query 453/1706 - fcu_name = citrouille, EPPO code: CUUMA
# ---- Running query 458/1706 - fcu_name = clémentinier, EPPO code: CIDCL
# ---- Running query 462/1706 - fcu_name = cognassier, EPPO code: CYDOB
# ---- Running query 466/1706 - fcu_name = colza, EPPO code: BRSNN
# ---- Running query 482/1706 - fcu_name = combava, EPPO code: CIDHY
# ---- Running query 487/1706 - fcu_name = makrut, EPPO code: CIDHY
# ---- Running query 488/1706 - fcu_name = concombre, EPPO code: CUMSA
# ---- Running query 492/1706 - fcu_name = coqueret du pérou, EPPO code: PHYPE
# ---- Running query 493/1706 - fcu_name = groseille du cap, EPPO code: PHYPR
# ---- Running query 494/1706 - fcu_name = coriandre, EPPO code: CORSA
# ---- Running query 496/1706 - fcu_name = cornichon, EPPO code: CUMSA
# ---- Running query 497/1706 - fcu_name = cornille, EPPO code: VIGSQ
# ---- Running query 498/1706 - fcu_name = dolique de chine, EPPO code: VIGSC
# ---- Running query 505/1706 - fcu_name = mongette, EPPO code: VIGSI
# ---- Running query 506/1706 - fcu_name = niébé, EPPO code: VIGSI
# ---- Running query 512/1706 - fcu_name = corossol épineux, EPPO code: ANUMU
# ---- Running query 514/1706 - fcu_name = courge, EPPO code: CUUPE
# ---- Running query 515/1706 - fcu_name = courge musquée, EPPO code: CUUMO
# ---- Running query 521/1706 - fcu_name = courge musquée, EPPO code: CUUMO
# ---- Running query 523/1706 - fcu_name = courgette, EPPO code: CUUPG
# ---- Running query 526/1706 - fcu_name = crocus cultivé, EPPO code: CVOSA
# ---- Running query 528/1706 - fcu_name = safran, EPPO code: CVOSA
# ---- Running query 529/1706 - fcu_name = safran cultivé, EPPO code: CVOSA
# ---- Running query 531/1706 - fcu_name = crosne du japon, EPPO code: STASB
# ---- Running query 561/1706 - fcu_name = cumin, EPPO code: CVUCY
# ---- Running query 564/1706 - fcu_name = faux anis, EPPO code: AFEGR
# ---- Running query 565/1706 - fcu_name = curcuma, EPPO code: MARAR
# ---- Running query 567/1706 - fcu_name = dactyle aggloméré, EPPO code: DACGL
# ---- Running query 568/1706 - fcu_name = dactyle pelotonné, EPPO code: DACGL
# ---- Running query 569/1706 - fcu_name = dolique asperge, EPPO code: VIGSQ
# ---- Running query 578/1706 - fcu_name = échalote, EPPO code: ALLAS
# ---- Running query 581/1706 - fcu_name = échalote grise, EPPO code: ALLOS
# ---- Running query 583/1706 - fcu_name = cynorhodon, EPPO code: ROSCN
# ---- Running query 584/1706 - fcu_name = cynorrhodon, EPPO code: ROSCN
# ---- Running query 585/1706 - fcu_name = rosier sauvage, EPPO code: ROSCN
# ---- Running query 586/1706 - fcu_name = églantier, EPPO code: ROSCN
# ---- Running query 588/1706 - fcu_name = engrain, EPPO code: TRZMO
# ---- Running query 589/1706 - fcu_name = petit épeautre, EPPO code: TRZMO
# ---- Running query 600/1706 - fcu_name = grand épeautre, EPPO code: TRZSP
# ---- Running query 601/1706 - fcu_name = épeautre, EPPO code: TRZSP
# ---- Running query 602/1706 - fcu_name = épinard, EPPO code: SPQOL
# ---- Running query 605/1706 - fcu_name = sycomore, EPPO code: ACRPP
# ---- Running query 606/1706 - fcu_name = érable sycomore, EPPO code: ACRPP
# ---- Running query 607/1706 - fcu_name = estragon, EPPO code: ARTDR
# ---- Running query 608/1706 - fcu_name = fenouil, EPPO code: FOEVU
# ---- Running query 610/1706 - fcu_name = fenugrec, EPPO code: TRKFG
# ---- Running query 613/1706 - fcu_name = trigonelle fenugrec, EPPO code: TRKFG
# ---- Running query 616/1706 - fcu_name = fenugrec, EPPO code: TRKFG
# ---- Running query 620/1706 - fcu_name = fétuque élevée, EPPO code: FESPR
# ---- Running query 625/1706 - fcu_name = féverole, EPPO code: VICFM
# ---- Running query 626/1706 - fcu_name = féverolle, EPPO code: VICFM
# ---- Running query 630/1706 - fcu_name = féverole fourragère, EPPO code: VICFM
# ---- Running query 642/1706 - fcu_name = fève, EPPO code: VICFX
# ---- Running query 645/1706 - fcu_name = grosse fève, EPPO code: VICFX
# ---- Running query 650/1706 - fcu_name = figuier, EPPO code: FIUCA
# ---- Running query 664/1706 - fcu_name = framboisier, EPPO code: RUBID
# ---- Running query 667/1706 - fcu_name = gaillet gratteron, EPPO code: GALAP
# ---- Running query 676/1706 - fcu_name = genêt des teinturiers, EPPO code: GENTI
# ---- Running query 678/1706 - fcu_name = gentiane jaune, EPPO code: GETLU
# ---- Running query 679/1706 - fcu_name = grande gentiane, EPPO code: GETLU
# ---- Running query 681/1706 - fcu_name = géranium, EPPO code: PELZO
# ---- Running query 683/1706 - fcu_name = gerbera, EPPO code: 1GEBG
# ---- Running query 685/1706 - fcu_name = gesse chiche, EPPO code: LTHCI
# ---- Running query 686/1706 - fcu_name = gesse cultivée, EPPO code: LTHSA
# ---- Running query 688/1706 - fcu_name = jarosse, EPPO code: LTHCI
# ---- Running query 690/1706 - fcu_name = gesse odorante, EPPO code: LTHOD
# ---- Running query 691/1706 - fcu_name = pois de senteur, EPPO code: LTHOD
# ---- Running query 694/1706 - fcu_name = gesse commune, EPPO code: LTHSA
# ---- Running query 697/1706 - fcu_name = pois carré, EPPO code: PSHTE
# ---- Running query 700/1706 - fcu_name = ginkgo biloba, EPPO code: GIKBI
# ---- Running query 704/1706 - fcu_name = gombo, EPPO code: ABMES
# ---- Running query 705/1706 - fcu_name = okura, EPPO code: ABMES
# ---- Running query 711/1706 - fcu_name = goyavier, EPPO code: PSIGU
# ---- Running query 713/1706 - fcu_name = goyavier fraise, EPPO code: PSILO
# ---- Running query 718/1706 - fcu_name = grenadier, EPPO code: PUNGR
# ---- Running query 720/1706 - fcu_name = fruit de la passion, EPPO code: PAQED
# ---- Running query 725/1706 - fcu_name = maracudja, EPPO code: PAQED
# ---- Running query 726/1706 - fcu_name = maracuja, EPPO code: PAQEF
# ---- Running query 736/1706 - fcu_name = haricot, EPPO code: PHSVX
# ---- Running query 737/1706 - fcu_name = haricot commun, EPPO code: PHSVX
# ---- Running query 738/1706 - fcu_name = haricot nain, EPPO code: PHSVN
# ---- Running query 739/1706 - fcu_name = haricot à rames, EPPO code: PHSVX
# ---- Running query 740/1706 - fcu_name = haricot d'espagne, EPPO code: PHSCO
# ---- Running query 743/1706 - fcu_name = haricot écarlate, EPPO code: PHSCO
# ---- Running query 744/1706 - fcu_name = haricot-fleur, EPPO code: PHSCO
# ---- Running query 745/1706 - fcu_name = flageolet, EPPO code: PHSVX
# ---- Running query 751/1706 - fcu_name = haricot sabre, EPPO code: CNAEN
# ---- Running query 762/1706 - fcu_name = haricot nain, EPPO code: PHSVN
# ---- Running query 764/1706 - fcu_name = haricot vert, EPPO code: PHSVX
# ---- Running query 765/1706 - fcu_name = haricot à rames, EPPO code: PHSVX
# ---- Running query 768/1706 - fcu_name = immortelle, EPPO code: HECBR
# ---- Running query 771/1706 - fcu_name = hellébore noir, EPPO code: HLLNI
# ---- Running query 772/1706 - fcu_name = rose de noël, EPPO code: EPHPU
# ---- Running query 774/1706 - fcu_name = hêtre, EPPO code: FAUSY
# ---- Running query 775/1706 - fcu_name = hêtre commun, EPPO code: FAUSY
# ---- Running query 776/1706 - fcu_name = hibiscus, EPPO code: HIBTR
# ---- Running query 780/1706 - fcu_name = rose de chine, EPPO code: HIBRS
# ---- Running query 789/1706 - fcu_name = couleuvrée septentrionale, EPPO code: HUMLU
# ---- Running query 790/1706 - fcu_name = houblon, EPPO code: HUMLU
# ---- Running query 791/1706 - fcu_name = houblon grimpant, EPPO code: HUMLU
# ---- Running query 793/1706 - fcu_name = salsepareille indigène, EPPO code: SMIKR
# ---- Running query 794/1706 - fcu_name = vigne du nord, EPPO code: HUMLU
# ---- Running query 812/1706 - fcu_name = laitue cultivée, EPPO code: LACSA
# ---- Running query 825/1706 - fcu_name = laitue frisée, EPPO code: LACSP
# ---- Running query 826/1706 - fcu_name = laitue à couper, EPPO code: LACSP
# ---- Running query 835/1706 - fcu_name = laitue pommée, EPPO code: LACSC
# ---- Running query 843/1706 - fcu_name = laitue romaine, EPPO code: LACSO
# ---- Running query 848/1706 - fcu_name = laurier sauce, EPPO code: LURNO
# ---- Running query 851/1706 - fcu_name = laurier tin, EPPO code: VIBTI
# ---- Running query 852/1706 - fcu_name = laurier-cerise, EPPO code: PRNLR
# ---- Running query 857/1706 - fcu_name = lavandin, EPPO code: LAVIN
# ---- Running query 882/1706 - fcu_name = lentille, EPPO code: LENCU
# ---- Running query 883/1706 - fcu_name = lentille comestible, EPPO code: LENCU
# ---- Running query 884/1706 - fcu_name = lentille cultivée, EPPO code: LENCU
# ---- Running query 887/1706 - fcu_name = lentille noirâtre, EPPO code: LENNI
# ---- Running query 895/1706 - fcu_name = citron vert, EPPO code: CIDAF
# ---- Running query 896/1706 - fcu_name = lime, EPPO code: CIDAF
# ---- Running query 897/1706 - fcu_name = limette, EPPO code: CIDAF
# ---- Running query 898/1706 - fcu_name = limettier, EPPO code: CIDLM
# ---- Running query 899/1706 - fcu_name = limonium, EPPO code: 1LIIG
# ---- Running query 900/1706 - fcu_name = statice, EPPO code: 1LIIG
# ---- Running query 901/1706 - fcu_name = lin, EPPO code: LIUUT
# ---- Running query 902/1706 - fcu_name = lin cultivé, EPPO code: LIUUT
# ---- Running query 922/1706 - fcu_name = litchi, EPPO code: LIHCH
# ---- Running query 923/1706 - fcu_name = litchi chinensis, EPPO code: LIHCH
# ---- Running query 925/1706 - fcu_name = céleri perpétuel, EPPO code: LEWOF
# ---- Running query 926/1706 - fcu_name = lavas, EPPO code: LEWOF
# ---- Running query 927/1706 - fcu_name = livèche, EPPO code: LEWOF
# ---- Running query 928/1706 - fcu_name = longane, EPPO code: DMCLO
# ---- Running query 929/1706 - fcu_name = longani, EPPO code: DMCLO
# ---- Running query 930/1706 - fcu_name = longanier, EPPO code: DMCLO
# ---- Running query 932/1706 - fcu_name = lotier corniculé, EPPO code: LOTCO
# ---- Running query 933/1706 - fcu_name = lotier des marais, EPPO code: LOTUL
# ---- Running query 935/1706 - fcu_name = lupin, EPPO code: LUPMI
# ---- Running query 936/1706 - fcu_name = lupin blanc, EPPO code: LUPAL
# ---- Running query 938/1706 - fcu_name = lupin bleu, EPPO code: LUPAN
# ---- Running query 942/1706 - fcu_name = lupin jaune, EPPO code: LUPLU
# ---- Running query 946/1706 - fcu_name = lupin bleu, EPPO code: LUPAN
# ---- Running query 953/1706 - fcu_name = lupin bleu, EPPO code: LUPAN
# ---- Running query 955/1706 - fcu_name = lupin jaune, EPPO code: LUPLU
# ---- Running query 958/1706 - fcu_name = lupin réticulé, EPPO code: LUPAN
# ---- Running query 960/1706 - fcu_name = lupin blanc, EPPO code: LUPAL
# ---- Running query 966/1706 - fcu_name = lupuline, EPPO code: MEDLU
# ---- Running query 967/1706 - fcu_name = luzerne lupuline, EPPO code: MEDLU
# ---- Running query 968/1706 - fcu_name = mignonette, EPPO code: RESME
# ---- Running query 969/1706 - fcu_name = minette, EPPO code: MEDLU
# ---- Running query 970/1706 - fcu_name = petit trèfle jaune, EPPO code: TRFDU
# ---- Running query 972/1706 - fcu_name = alfalfa, EPPO code: MEDSA
# ---- Running query 975/1706 - fcu_name = luzerne, EPPO code: MEDSA
# ---- Running query 976/1706 - fcu_name = luzerne cultivée, EPPO code: MEDSA
# ---- Running query 983/1706 - fcu_name = blanchette, EPPO code: SUEMA
# ---- Running query 984/1706 - fcu_name = boursette, EPPO code: CAPBP
# ---- Running query 986/1706 - fcu_name = doucette, EPPO code: VLLER
# ---- Running query 987/1706 - fcu_name = mâche, EPPO code: VLLER
# ---- Running query 988/1706 - fcu_name = oreillette, EPPO code: ASUEU
# ---- Running query 989/1706 - fcu_name = raiponce, EPPO code: CMPRP
# ---- Running query 993/1706 - fcu_name = maïs, EPPO code: ZEAMX
# ---- Running query 995/1706 - fcu_name = maïs doux, EPPO code: ZEAMS
# ---- Running query 996/1706 - fcu_name = maïs sucré, EPPO code: ZEAMS
# ---- Running query 1008/1706 - fcu_name = maïs éclaté, EPPO code: ZEAME
# ---- Running query 1010/1706 - fcu_name = popcorn, EPPO code: ZEAME
# ---- Running query 1013/1706 - fcu_name = mandarinier, EPPO code: CIDRE
# ---- Running query 1014/1706 - fcu_name = tangerine, EPPO code: CIDRE
# ---- Running query 1016/1706 - fcu_name = mangostan, EPPO code: GANMA
# ---- Running query 1018/1706 - fcu_name = mangoustan, EPPO code: GANMA
# ---- Running query 1023/1706 - fcu_name = mangue, EPPO code: MNGIN
# ---- Running query 1024/1706 - fcu_name = manguier, EPPO code: MNGIN
# ---- Running query 1027/1706 - fcu_name = manioc, EPPO code: MANES
# ---- Running query 1032/1706 - fcu_name = marguerite, EPPO code: CHYFR
# ---- Running query 1033/1706 - fcu_name = marguerite commune, EPPO code: CHYLE
# ---- Running query 1034/1706 - fcu_name = marjolaine, EPPO code: ORIVU
# ---- Running query 1038/1706 - fcu_name = grande mauve, EPPO code: MALSI
# ---- Running query 1039/1706 - fcu_name = mauve, EPPO code: ABUHU
# ---- Running query 1040/1706 - fcu_name = mauve des bois, EPPO code: MALSI
# ---- Running query 1041/1706 - fcu_name = mauve sylvestre, EPPO code: MALSI
# ---- Running query 1042/1706 - fcu_name = mélilot, EPPO code: MEUOF
# ---- Running query 1043/1706 - fcu_name = couronne royale, EPPO code: MEUOF
# ---- Running query 1044/1706 - fcu_name = herbe aux puces, EPPO code: PLASV
# ---- Running query 1046/1706 - fcu_name = mélilot blanc, EPPO code: MEUAL
# ---- Running query 1050/1706 - fcu_name = mélilot jaune, EPPO code: MEUOF
# ---- Running query 1051/1706 - fcu_name = petit trèfle jaune, EPPO code: TRFDU
# ---- Running query 1052/1706 - fcu_name = trèfle de bokhara, EPPO code: MEUAL
# ---- Running query 1053/1706 - fcu_name = trèfle des mouches, EPPO code: MEUOF
# ---- Running query 1054/1706 - fcu_name = mélilot jaune, EPPO code: MEUOF
# ---- Running query 1055/1706 - fcu_name = mélilot officinal, EPPO code: MEUOF
# ---- Running query 1056/1706 - fcu_name = mélilot jaune, EPPO code: MEUOF
# ---- Running query 1057/1706 - fcu_name = mélilot officinal, EPPO code: MEUOF
# ---- Running query 1060/1706 - fcu_name = mélisse officinale, EPPO code: MLSOF
# ---- Running query 1064/1706 - fcu_name = melon, EPPO code: CUMME
# ---- Running query 1068/1706 - fcu_name = menthe poivrée, EPPO code: MENPI
# ---- Running query 1069/1706 - fcu_name = menthe verte, EPPO code: MENSP
# ---- Running query 1073/1706 - fcu_name = millepertuis, EPPO code: HYPPE
# ---- Running query 1074/1706 - fcu_name = millepertuis commun, EPPO code: HYPPE
# ---- Running query 1076/1706 - fcu_name = millepertuis perforé, EPPO code: HYPPE
# ---- Running query 1077/1706 - fcu_name = mil, EPPO code: PANMI
# ---- Running query 1078/1706 - fcu_name = millet, EPPO code: SORVU
# ---- Running query 1079/1706 - fcu_name = millet commun, EPPO code: PANMI
# ---- Running query 1081/1706 - fcu_name = millet perle, EPPO code: PESGL
# ---- Running query 1082/1706 - fcu_name = millet à grappes, EPPO code: SETIT
# ---- Running query 1085/1706 - fcu_name = herbe à éléphant, EPPO code: PESPU
# ---- Running query 1086/1706 - fcu_name = miscanthus, EPPO code: MISFL
# ---- Running query 1087/1706 - fcu_name = miscanthus géant, EPPO code: MISGI
# ---- Running query 1088/1706 - fcu_name = millet des oiseaux, EPPO code: PANMI
# ---- Running query 1089/1706 - fcu_name = moha, EPPO code: SETIM
# ---- Running query 1094/1706 - fcu_name = moutarde brune, EPPO code: BRSJU
# ---- Running query 1096/1706 - fcu_name = moutarde noire, EPPO code: BRSNI
# ---- Running query 1099/1706 - fcu_name = mûre, EPPO code: MORNI
# ---- Running query 1101/1706 - fcu_name = mûrier blanc, EPPO code: MORAL
# ---- Running query 1102/1706 - fcu_name = mûrier noir, EPPO code: MORNI
# ---- Running query 1103/1706 - fcu_name = myrtille, EPPO code: VACMY
# ---- Running query 1104/1706 - fcu_name = navet, EPPO code: BRSRR
# ---- Running query 1105/1706 - fcu_name = navet fourrager, EPPO code: BRSNA
# ---- Running query 1109/1706 - fcu_name = navette, EPPO code: BRSRO
# ---- Running query 1119/1706 - fcu_name = bibacier, EPPO code: EIOJA
# ---- Running query 1122/1706 - fcu_name = néflier du japon, EPPO code: EIOJA
# ---- Running query 1123/1706 - fcu_name = niger, EPPO code: GUIAB
# ---- Running query 1125/1706 - fcu_name = guizotia d'abyssinie, EPPO code: GUIAB
# ---- Running query 1126/1706 - fcu_name = guizotia oléifère, EPPO code: GUIAB
# ---- Running query 1127/1706 - fcu_name = niger, EPPO code: GUIAB
# ---- Running query 1131/1706 - fcu_name = coudrier, EPPO code: CYLAV
# ---- Running query 1132/1706 - fcu_name = noisetier, EPPO code: CYLAV
# ---- Running query 1136/1706 - fcu_name = noyer, EPPO code: IUGRE
# ---- Running query 1140/1706 - fcu_name = oeillette, EPPO code: PAPSO
# ---- Running query 1141/1706 - fcu_name = pavot bleu, EPPO code: MEPGR
# ---- Running query 1147/1706 - fcu_name = oignon, EPPO code: ALLCE
# ---- Running query 1159/1706 - fcu_name = olivier, EPPO code: OLVEU
# ---- Running query 1160/1706 - fcu_name = olive, EPPO code: OLVEU
# ---- Running query 1169/1706 - fcu_name = bigaradier, EPPO code: CIDAU
# ---- Running query 1175/1706 - fcu_name = oranger, EPPO code: CIDSI
# ---- Running query 1177/1706 - fcu_name = sanguine, EPPO code: CRWSA
# ---- Running query 1178/1706 - fcu_name = oranger du mexique, EPPO code: COATE
# ---- Running query 1180/1706 - fcu_name = orge à deux rangs, EPPO code: HORDI
# ---- Running query 1190/1706 - fcu_name = orge à six rangs, EPPO code: HORVX
# ---- Running query 1193/1706 - fcu_name = marjolaine sauvage, EPPO code: ORIVU
# ---- Running query 1194/1706 - fcu_name = marjolaine vivace, EPPO code: ORIVU
# ---- Running query 1195/1706 - fcu_name = origan, EPPO code: ORIVU
# ---- Running query 1196/1706 - fcu_name = origan commun, EPPO code: ORIVU
# ---- Running query 1197/1706 - fcu_name = grande ortie, EPPO code: BOHST
# ---- Running query 1198/1706 - fcu_name = ortie, EPPO code: URTDI
# ---- Running query 1199/1706 - fcu_name = ortie commune, EPPO code: URTDI
# ---- Running query 1200/1706 - fcu_name = petite ortie, EPPO code: URTUR
# ---- Running query 1202/1706 - fcu_name = rumex, EPPO code: 1RUMG
# ---- Running query 1204/1706 - fcu_name = coeur de palmier, EPPO code: ETQED
# ---- Running query 1206/1706 - fcu_name = pamplemousse, EPPO code: CIDPA
# ---- Running query 1207/1706 - fcu_name = pamplemoussier, EPPO code: CIDPA
# ---- Running query 1208/1706 - fcu_name = panais, EPPO code: PAVSA
# ---- Running query 1211/1706 - fcu_name = papayer, EPPO code: CIAPA
# ---- Running query 1212/1706 - fcu_name = pâquerette, EPPO code: BELPE
# ---- Running query 1213/1706 - fcu_name = pâquerette vivace, EPPO code: BELPE
# ---- Running query 1219/1706 - fcu_name = passiflore bleue, EPPO code: PAQCO
# ---- Running query 1221/1706 - fcu_name = melon d'eau, EPPO code: CITLA
# ---- Running query 1222/1706 - fcu_name = pastèque, EPPO code: CITLA
# ---- Running query 1223/1706 - fcu_name = patate douce, EPPO code: IPOBA
# ---- Running query 1228/1706 - fcu_name = couronne impériale, EPPO code: FRIIM
# ---- Running query 1229/1706 - fcu_name = pâtisson, EPPO code: CUUPM
# ---- Running query 1236/1706 - fcu_name = pavot blanc, EPPO code: PAPSO
# ---- Running query 1239/1706 - fcu_name = pavot somnifère, EPPO code: PAPSO
# ---- Running query 1240/1706 - fcu_name = pavot à opium, EPPO code: PAPSO
# ---- Running query 1242/1706 - fcu_name = nectarine, EPPO code: PRNPN
# ---- Running query 1243/1706 - fcu_name = pavie, EPPO code: AECPV
# ---- Running query 1247/1706 - fcu_name = pêcher, EPPO code: PRNPS
# ---- Running query 1251/1706 - fcu_name = violette, EPPO code: VIOOD
# ---- Running query 1252/1706 - fcu_name = persil, EPPO code: PARCR
# ---- Running query 1254/1706 - fcu_name = persil cultivé, EPPO code: PARCR
# ---- Running query 1255/1706 - fcu_name = persil frisé, EPPO code: PARCC
# ---- Running query 1271/1706 - fcu_name = phacélie à feuilles de tanaisie, EPPO code: PHCTA
# ---- Running query 1272/1706 - fcu_name = photinia, EPPO code: 1PHNG
# ---- Running query 1274/1706 - fcu_name = piment, EPPO code: CPSAN
# ---- Running query 1279/1706 - fcu_name = pissenlit, EPPO code: TAROF
# ---- Running query 1280/1706 - fcu_name = pistache, EPPO code: PIAVE
# ---- Running query 1281/1706 - fcu_name = pistachier, EPPO code: PIAVE
# ---- Running query 1291/1706 - fcu_name = plantain pucier, EPPO code: PLAAF
# ---- Running query 1305/1706 - fcu_name = kaki, EPPO code: DOSKA
# ---- Running query 1307/1706 - fcu_name = plaqueminier du japon, EPPO code: DOSLO
# ---- Running query 1308/1706 - fcu_name = poinsettia, EPPO code: EPHPU
# ---- Running query 1309/1706 - fcu_name = étoile de noël, EPPO code: EPHPU
# ---- Running query 1310/1706 - fcu_name = poireau, EPPO code: ALLPO
# ---- Running query 1311/1706 - fcu_name = bette, EPPO code: BEAMA
# ---- Running query 1315/1706 - fcu_name = blette, EPPO code: BEAVV
# ---- Running query 1316/1706 - fcu_name = carde, EPPO code: BEAVV
# ---- Running query 1319/1706 - fcu_name = jotte, EPPO code: BEAVV
# ---- Running query 1321/1706 - fcu_name = poirée, EPPO code: BEAVV
# ---- Running query 1330/1706 - fcu_name = poirier, EPPO code: PYUCO
# ---- Running query 1333/1706 - fcu_name = pois cultivé, EPPO code: PIBSX
# ---- Running query 1335/1706 - fcu_name = pois chiche, EPPO code: CIEAR
# ---- Running query 1337/1706 - fcu_name = pois fourrager, EPPO code: PIBSA
# ---- Running query 1343/1706 - fcu_name = pois potager, EPPO code: PIBSX
# ---- Running query 1356/1706 - fcu_name = poivron, EPPO code: CPSAN
# ---- Running query 1361/1706 - fcu_name = pamplemousse, EPPO code: CIDPA
# ---- Running query 1362/1706 - fcu_name = pomelo, EPPO code: CIDGR
# ---- Running query 1363/1706 - fcu_name = pomme de terre, EPPO code: SOLTU
# ---- Running query 1383/1706 - fcu_name = pommier, EPPO code: MABSD
# ---- Running query 1385/1706 - fcu_name = potiron, EPPO code: CUUMA
# ---- Running query 1386/1706 - fcu_name = porcelane, EPPO code: POROL
# ---- Running query 1399/1706 - fcu_name = primevère, EPPO code: PRIVU
# ---- Running query 1402/1706 - fcu_name = mirabelle, EPPO code: PRNDS
# ---- Running query 1407/1706 - fcu_name = prunier, EPPO code: PRNDO
# ---- Running query 1410/1706 - fcu_name = quetschier, EPPO code: PRNDO
# ---- Running query 1411/1706 - fcu_name = reine-claude, EPPO code: PRNDI
# ---- Running query 1414/1706 - fcu_name = guinep, EPPO code: MLCBI
# ---- Running query 1416/1706 - fcu_name = limoncillo, EPPO code: MLSOF
# ---- Running query 1417/1706 - fcu_name = mamoncillo, EPPO code: MLCBI
# ---- Running query 1419/1706 - fcu_name = quenettier, EPPO code: MLCBI
# ---- Running query 1420/1706 - fcu_name = quinoa, EPPO code: CHEQU
# ---- Running query 1421/1706 - fcu_name = radis, EPPO code: RAPSR
# ---- Running query 1426/1706 - fcu_name = radis d'espagne, EPPO code: RAPSN
# ---- Running query 1427/1706 - fcu_name = radis d'hiver, EPPO code: RAPSN
# ---- Running query 1429/1706 - fcu_name = raifort cultivé, EPPO code: RAPSN
# ---- Running query 1430/1706 - fcu_name = raifort des parisiens, EPPO code: RAPSN
# ---- Running query 1439/1706 - fcu_name = cranson, EPPO code: ARWLA
# ---- Running query 1440/1706 - fcu_name = herbe au scorbut, EPPO code: CCLOF
# ---- Running query 1441/1706 - fcu_name = herbe aux cuillers, EPPO code: CCLOF
# ---- Running query 1444/1706 - fcu_name = raifort, EPPO code: ARWLA
# ---- Running query 1445/1706 - fcu_name = raifort sauvage, EPPO code: RAPRA
# ---- Running query 1448/1706 - fcu_name = ramboutan, EPPO code: NEELA
# ---- Running query 1451/1706 - fcu_name = lolium, EPPO code: 1LOLG
# ---- Running query 1453/1706 - fcu_name = ray-grass, EPPO code: LOLPE
# ---- Running query 1456/1706 - fcu_name = ivraie vivace, EPPO code: LOLPE
# ---- Running query 1458/1706 - fcu_name = ray-grass anglais, EPPO code: LOLPE
# ---- Running query 1465/1706 - fcu_name = ivraie multiflore, EPPO code: LOLMU
# ---- Running query 1468/1706 - fcu_name = ray-grass d'italie, EPPO code: LOLMU
# ---- Running query 1473/1706 - fcu_name = renoncule des fleuristes, EPPO code: RANAS
# ---- Running query 1475/1706 - fcu_name = rhubarbe, EPPO code: RHERH
# ---- Running query 1479/1706 - fcu_name = ricin, EPPO code: RIICO
# ---- Running query 1481/1706 - fcu_name = riz, EPPO code: ORYSA
# ---- Running query 1483/1706 - fcu_name = romarin, EPPO code: RMSOF
# ---- Running query 1484/1706 - fcu_name = mûre, EPPO code: MORNI
# ---- Running query 1485/1706 - fcu_name = mûrier des haies, EPPO code: RUBFR
# ---- Running query 1486/1706 - fcu_name = ronce, EPPO code: RUBFR
# ---- Running query 1488/1706 - fcu_name = roquette, EPPO code: ERUVV
# ---- Running query 1490/1706 - fcu_name = églantier, EPPO code: ROSCN
# ---- Running query 1497/1706 - fcu_name = esparcette, EPPO code: ONBVI
# ---- Running query 1498/1706 - fcu_name = esparsette, EPPO code: ONBVI
# ---- Running query 1500/1706 - fcu_name = sainfoin, EPPO code: ONBVI
# ---- Running query 1506/1706 - fcu_name = salade, EPPO code: LACSA
# ---- Running query 1507/1706 - fcu_name = barbe de bouc, EPPO code: TROPR
# ---- Running query 1508/1706 - fcu_name = cercifis commun, EPPO code: TROPS
# ---- Running query 1509/1706 - fcu_name = salsifis, EPPO code: TROPS
# ---- Running query 1510/1706 - fcu_name = salsifis austral, EPPO code: TROPA
# ---- Running query 1511/1706 - fcu_name = salsifis blanc, EPPO code: TROPS
# ---- Running query 1512/1706 - fcu_name = salsifis à feuilles de poireau, EPPO code: TROPS
# ---- Running query 1514/1706 - fcu_name = sarriette, EPPO code: STIMO
# ---- Running query 1516/1706 - fcu_name = blé noir, EPPO code: FAGES
# ---- Running query 1520/1706 - fcu_name = renouée sarrasin, EPPO code: FAGES
# ---- Running query 1521/1706 - fcu_name = sarrasin, EPPO code: FAGES
# ---- Running query 1522/1706 - fcu_name = sauge, EPPO code: SALDC
# ---- Running query 1523/1706 - fcu_name = sauge officinale, EPPO code: SALOF
# ---- Running query 1524/1706 - fcu_name = sauge sclarée, EPPO code: SALSC
# ---- Running query 1531/1706 - fcu_name = scorsonère, EPPO code: SCVHI
# ---- Running query 1532/1706 - fcu_name = scorsonère d'espagne, EPPO code: SCVHI
# ---- Running query 1534/1706 - fcu_name = seigle, EPPO code: SECCE
# ---- Running query 1541/1706 - fcu_name = ornithope cultivé, EPPO code: OROSA
# ---- Running query 1543/1706 - fcu_name = serradelle, EPPO code: OROSA
# ---- Running query 1547/1706 - fcu_name = sésame, EPPO code: SEGIN
# ---- Running query 1549/1706 - fcu_name = soja, EPPO code: GLXMA
# ---- Running query 1562/1706 - fcu_name = soya, EPPO code: GLXMA
# ---- Running query 1567/1706 - fcu_name = haricot mungo, EPPO code: PHSAU
# ---- Running query 1571/1706 - fcu_name = sorgho, EPPO code: SORVU
# ---- Running query 1575/1706 - fcu_name = sorgho, EPPO code: SORVU
# ---- Running query 1579/1706 - fcu_name = lande, EPPO code: ULEEU
# ---- Running query 1584/1706 - fcu_name = bois, EPPO code: BUXSE
# ---- Running query 1588/1706 - fcu_name = grand tabac, EPPO code: NIOTA
# ---- Running query 1589/1706 - fcu_name = herbe à nicot, EPPO code: NIOTA
# ---- Running query 1590/1706 - fcu_name = tabac, EPPO code: NIOTA
# ---- Running query 1594/1706 - fcu_name = tangor, EPPO code: CIDNO
# ---- Running query 1599/1706 - fcu_name = farigoule, EPPO code: THYVU
# ---- Running query 1600/1706 - fcu_name = thym, EPPO code: THYVU
# ---- Running query 1602/1706 - fcu_name = tomate, EPPO code: LYPES
# ---- Running query 1605/1706 - fcu_name = artichaut de jérusalem, EPPO code: HELTU
# ---- Running query 1607/1706 - fcu_name = topinambour, EPPO code: HELTU
# ---- Running query 1615/1706 - fcu_name = héliotrope, EPPO code: HEOEU
# ---- Running query 1616/1706 - fcu_name = maurelle, EPPO code: CRZTI
# ---- Running query 1620/1706 - fcu_name = tournesol, EPPO code: CRZTI
# ---- Running query 1625/1706 - fcu_name = trèfle d'alexandrie, EPPO code: TRFAL
# ---- Running query 1626/1706 - fcu_name = trèfle de perse, EPPO code: TRFRS
# ---- Running query 1628/1706 - fcu_name = petit trèfle, EPPO code: DEDHE
# ---- Running query 1629/1706 - fcu_name = trèfle blanc, EPPO code: TRFRE
# ---- Running query 1631/1706 - fcu_name = trèfle rampant, EPPO code: TRFRE
# ---- Running query 1632/1706 - fcu_name = trèfle hybride, EPPO code: TRFHY
# ---- Running query 1635/1706 - fcu_name = trèfle incarnat, EPPO code: TRFIN
# ---- Running query 1636/1706 - fcu_name = trèfle de micheli, EPPO code: TRFMI
# ---- Running query 1637/1706 - fcu_name = trèfle de perse, EPPO code: TRFRS
# ---- Running query 1638/1706 - fcu_name = trèfle des prés, EPPO code: TRFPR
# ---- Running query 1639/1706 - fcu_name = trèfle violet, EPPO code: TRFPR
# ---- Running query 1640/1706 - fcu_name = triticale, EPPO code: TTLRI
# ---- Running query 1648/1706 - fcu_name = valériane officinale, EPPO code: VALOF
# ---- Running query 1649/1706 - fcu_name = vanille, EPPO code: VANPL
# ---- Running query 1651/1706 - fcu_name = vanillier, EPPO code: VANPL
# ---- Running query 1653/1706 - fcu_name = véronique officinale, EPPO code: VEROF
# ---- Running query 1654/1706 - fcu_name = verveine, EPPO code: VEBOF
# ---- Running query 1656/1706 - fcu_name = vesce commune, EPPO code: VICSA
# ---- Running query 1657/1706 - fcu_name = vesce cultivée, EPPO code: VICSA
# ---- Running query 1659/1706 - fcu_name = vesce de cerdagne, EPPO code: VICVV
# ---- Running query 1660/1706 - fcu_name = vesce de hongrie, EPPO code: VICPA
# ---- Running query 1661/1706 - fcu_name = vesce de pannonie, EPPO code: VICPA
# ---- Running query 1664/1706 - fcu_name = vesce fourragère, EPPO code: VICSA
# ---- Running query 1668/1706 - fcu_name = vétiver, EPPO code: VEIZI
# ---- Running query 1672/1706 - fcu_name = vigne vierge, EPPO code: PRTQU
# ---- Running query 1674/1706 - fcu_name = vigne cultivée, EPPO code: VITVI
# ---- Running query 1690/1706 - fcu_name = violette odorante, EPPO code: VIOOD
# ---- Running query 1695/1706 - fcu_name = ylang-ylang, EPPO code: CANOD

# %%
dataframe_preview(df_fcu, end=10)
# Out:
# == Number of lines: 1706
# == Number of unique values:
# fcu_concept         524
# fcu_name           1656
# fcu_name_type         2
# eppo_code           355
# scientific_name     355
# dtype: int64
#                                          fcu_concept                 fcu_name  \
# 0  http://ontology.inrae.fr/frenchcropusage/Abric...                  abricot
# 1  http://ontology.inrae.fr/frenchcropusage/Abric...               abricotier
# 2  http://ontology.inrae.fr/frenchcropusage/Abric...             abricot pays
# 3  http://ontology.inrae.fr/frenchcropusage/Abric...  abricotier des antilles
# 4  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier pays
# 5  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier-pays
# 6  http://ontology.inrae.fr/frenchcropusage/Abric...                    mamey
# 7  http://ontology.inrae.fr/frenchcropusage/Actin...                actinidia
# 8  http://ontology.inrae.fr/frenchcropusage/Actin...               actinidier
# 9  http://ontology.inrae.fr/frenchcropusage/Actin...       groseille de chine
#
#   fcu_name_type eppo_code      scientific_name
# 0           alt      None                 None
# 1          pref     PRNAR     Prunus armeniaca
# 2           alt      None                 None
# 3           alt     MAFAM     Mammea americana
# 4          pref      None                 None
# 5           alt      None                 None
# 6           alt     POJSA      Pouteria sapota
# 7          pref     ATICH  Actinidia chinensis
# 8           alt      None                 None
# 9           alt      None                 None

# %%
df_fcu.to_excel("result1_fcu_eppo.xlsx")

# %% [markdown]
# #### Count only matches

# %%
dataframe_preview(df_fcu.dropna(), end=10)
# Out:
# == Number of lines: 580
# == Number of unique values:
# fcu_concept        317
# fcu_name           553
# fcu_name_type        2
# eppo_code          355
# scientific_name    355
# dtype: int64
#                                           fcu_concept  \
# 1   http://ontology.inrae.fr/frenchcropusage/Abric...
# 3   http://ontology.inrae.fr/frenchcropusage/Abric...
# 6   http://ontology.inrae.fr/frenchcropusage/Abric...
# 7   http://ontology.inrae.fr/frenchcropusage/Actin...
# 10  http://ontology.inrae.fr/frenchcropusage/Actin...
# 13      http://ontology.inrae.fr/frenchcropusage/Ails
# 14      http://ontology.inrae.fr/frenchcropusage/Ails
# 15      http://ontology.inrae.fr/frenchcropusage/Ails
# 16      http://ontology.inrae.fr/frenchcropusage/Ails
# 17  http://ontology.inrae.fr/frenchcropusage/Alpistes
#
#                    fcu_name fcu_name_type eppo_code         scientific_name
# 1                abricotier          pref     PRNAR        Prunus armeniaca
# 3   abricotier des antilles           alt     MAFAM        Mammea americana
# 6                     mamey           alt     POJSA         Pouteria sapota
# 7                 actinidia          pref     ATICH     Actinidia chinensis
# 10                     kiwi           alt     ATICH     Actinidia chinensis
# 13                      ail          pref     ALLSA          Allium sativum
# 14               ail commun           alt     ALLSA          Allium sativum
# 15              ail cultivé           alt     ALLSA          Allium sativum
# 16                   aillet           alt     ALLVI          Allium vineale
# 17                  alpiste          pref     PHABR  Phalaris brachystachys

# %% [markdown]
# ____
# # Query TAXREF-LD with EPPO scientific names

# %% [markdown]
# EPPO provides short scientific names of species: genus + epythet, which may correspond to several full scientific names (with authority and date) in TAXREF-LD, e.g.: *Prunus armeniaca L., 1753* and *Prunus armeniaca Chevall., 1827*.
#
# Besides, each name in TAXREF-LD could be either a reference name (the name used to denote the taxon) or a synonym of the reference name. The query below keeps track of all the matching names and wether these are reference or synonym names.
#
# The SPARQL endpoint of TAXREF-LD does not support passing all scientific names at once in a VALUES clause (ends up with a timeout).
# To avoid this, we make a SPARQL query for each FCU variety.

# %%
queryTpl = Template(prefixes + '''
select distinct ("$fcu_name" as ?fcu_name) ("$eppo_code" as ?eppo_code) ("$scientific_name" as ?scientific_name) ?taxref_name_type ?taxref_full_name ?taxref_ref_full_name ?taxon ?rank 
from <http://taxref.mnhn.fr/lod/graph/classes/15.0>
from <http://taxref.mnhn.fr/lod/graph/vernacular/15.0>
from <http://taxref.mnhn.fr/lod/graph/concepts>
where {
    # ?name
       a                      skos:Concept;
       skos:prefLabel         "$scientific_name";
       rdfs:label             ?taxref_full_name. # scientific name + authority
    
    { ?name taxrefp:isReferenceNameOf ?taxon. bind("pref" as ?taxref_name_type) }
    union
    { ?name taxrefp:isSynonymOf       ?taxon. bind("alt" as ?taxref_name_type) }
    
    # ?taxon
       taxrefp:hasRank        ?rank;
       taxrefp:hasReferenceName [ rdfs:label ?taxref_ref_full_name ].

    # All ranks up to spcecies but not above
    filter (?rank in (
        taxrefrk:Species,  taxrefrk:SemiSpecies, taxrefrk:MicroSpecies, taxrefrk:SubSpecies, taxrefrk:Natio, 
        taxrefrk:Varietas, taxrefrk:SubVarietas, taxrefrk:Forma,        taxrefrk:SubForma,   taxrefrk:FormaSpecies,
        taxrefrk:Linea,    taxrefrk:Clone,       taxrefrk:Race,         taxrefrk:Cultivar,   taxrefrk:Morpha,
        taxrefrk:Abberatio ))
}''')

# %%
# Set a max number of queries to submit. 0 = unlimited.
MAX_QUERIES = 0

# Result DataFrame
df_fcu_taxref = pd.DataFrame()

for _index, row in df_fcu.iterrows():
    if row['scientific_name'] is not None:
        query = queryTpl.substitute(
            scientific_name = row['scientific_name'].strip(), 
            fcu_name = row['fcu_name'].strip().lower(),
            eppo_code = row['eppo_code']
        )
        #print(query)

        print(f"---- Running query {_index + 1}/{len(df_fcu)} - fcu_name = {row['fcu_name']}, scientific name: {row['scientific_name']}")
        # %time _df = exec_sparql(taxref_endpoint, query)
        print(f'Number of results: {_df.shape[0]}')
        df_fcu_taxref = df_fcu_taxref.append(_df)

        # Keep track of the names not matched with TAXREF
        if _df.shape[0] == 0:
            nomatch_row = {'fcu_name': row['fcu_name'].strip(), 'eppo_code': row['eppo_code'], 'scientific_name': row['scientific_name'] }
            df_fcu_taxref = df_fcu_taxref.append(nomatch_row, ignore_index=True)

    if MAX_QUERIES > 0 and (_index + 1) >= MAX_QUERIES:
        break
# Out:
# ---- Running query 2/1706 - fcu_name = abricotier, scientific name: Prunus armeniaca
# Wall time: 349 ms
# Number of results: 2
# ---- Running query 4/1706 - fcu_name = abricotier des antilles, scientific name: Mammea americana
# Wall time: 359 ms
# Number of results: 1
# ---- Running query 7/1706 - fcu_name = mamey, scientific name: Pouteria sapota
# Wall time: 283 ms
# Number of results: 1
# ---- Running query 8/1706 - fcu_name = actinidia, scientific name: Actinidia chinensis
# Wall time: 570 ms
# Number of results: 2
# ---- Running query 11/1706 - fcu_name = kiwi, scientific name: Actinidia chinensis
# Wall time: 259 ms
# Number of results: 2
# ---- Running query 14/1706 - fcu_name = ail, scientific name: Allium sativum
# Wall time: 256 ms
# Number of results: 1
# ---- Running query 15/1706 - fcu_name = ail commun, scientific name: Allium sativum
# Wall time: 251 ms
# Number of results: 1
# ---- Running query 16/1706 - fcu_name = ail cultivé, scientific name: Allium sativum
# Wall time: 465 ms
# Number of results: 1
# ---- Running query 17/1706 - fcu_name = aillet, scientific name: Allium vineale
# Wall time: 504 ms
# Number of results: 1
# ---- Running query 18/1706 - fcu_name = alpiste, scientific name: Phalaris brachystachys
# Wall time: 265 ms
# Number of results: 1
# ---- Running query 19/1706 - fcu_name = alpiste des canaries, scientific name: Phalaris canariensis
# Wall time: 237 ms
# Number of results: 2
# ---- Running query 24/1706 - fcu_name = amande douce, scientific name: Pachyphytum oviferum
# Wall time: 259 ms
# Number of results: 0
# ---- Running query 26/1706 - fcu_name = amandier, scientific name: Prunus dulcis
# Wall time: 262 ms
# Number of results: 1
# ---- Running query 27/1706 - fcu_name = ananas, scientific name: Ananas comosus
# Wall time: 251 ms
# Number of results: 1
# ---- Running query 29/1706 - fcu_name = aneth, scientific name: Anethum graveolens
# Wall time: 509 ms
# Number of results: 1
# ---- Running query 30/1706 - fcu_name = faux anis, scientific name: Anethum graveolens
# Wall time: 282 ms
# Number of results: 1
# ---- Running query 31/1706 - fcu_name = fenouil bâtard, scientific name: Anethum graveolens
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 32/1706 - fcu_name = angélique, scientific name: Dicorynia guianensis
# Wall time: 255 ms
# Number of results: 1
# ---- Running query 33/1706 - fcu_name = angélique officinale, scientific name: Angelica archangelica
# Wall time: 262 ms
# Number of results: 1
# ---- Running query 34/1706 - fcu_name = archangélique, scientific name: Angelica archangelica
# Wall time: 275 ms
# Number of results: 1
# ---- Running query 35/1706 - fcu_name = anis, scientific name: Pimpinella anisum
# Wall time: 1.26 s
# Number of results: 1
# ---- Running query 36/1706 - fcu_name = anis vert, scientific name: Pimpinella anisum
# Wall time: 253 ms
# Number of results: 1
# ---- Running query 38/1706 - fcu_name = arachide, scientific name: Arachis hypogaea
# Wall time: 255 ms
# Number of results: 1
# ---- Running query 40/1706 - fcu_name = cacahuète, scientific name: Arachis hypogaea
# Wall time: 227 ms
# Number of results: 1
# ---- Running query 69/1706 - fcu_name = artichaut, scientific name: Cynara scolymus
# Wall time: 261 ms
# Number of results: 1
# ---- Running query 71/1706 - fcu_name = asperge, scientific name: Hyssopus officinalis
# Wall time: 260 ms
# Number of results: 1
# ---- Running query 72/1706 - fcu_name = asperge blanche, scientific name: Asparagus albus
# Wall time: 247 ms
# Number of results: 1
# ---- Running query 74/1706 - fcu_name = asperge violette, scientific name: Limodorum abortivum
# Wall time: 248 ms
# Number of results: 1
# ---- Running query 77/1706 - fcu_name = attier, scientific name: Annona squamosa
# Wall time: 254 ms
# Number of results: 1
# ---- Running query 79/1706 - fcu_name = pommier cannelle, scientific name: Annona squamosa
# Wall time: 251 ms
# Number of results: 1
# ---- Running query 80/1706 - fcu_name = aubergine, scientific name: Solanum melongena
# Wall time: 252 ms
# Number of results: 1
# ---- Running query 82/1706 - fcu_name = avocatier, scientific name: Persea americana
# Wall time: 260 ms
# Number of results: 1
# ---- Running query 85/1706 - fcu_name = avoine cultivée, scientific name: Avena sativa
# Wall time: 250 ms
# Number of results: 1
# ---- Running query 88/1706 - fcu_name = avoine nue, scientific name: Avena nuda
# Wall time: 290 ms
# Number of results: 1
# ---- Running query 89/1706 - fcu_name = avoine à gruau, scientific name: Avena nuda
# Wall time: 243 ms
# Number of results: 1
# ---- Running query 99/1706 - fcu_name = avoine rude, scientific name: Avena strigosa
# Wall time: 254 ms
# Number of results: 2
# ---- Running query 100/1706 - fcu_name = anis étoilé, scientific name: Illicium verum
# Wall time: 293 ms
# Number of results: 1
# ---- Running query 102/1706 - fcu_name = badianier de chine, scientific name: Illicium verum
# Wall time: 508 ms
# Number of results: 1
# ---- Running query 107/1706 - fcu_name = bananier, scientific name: Musa x paradisiaca
# Wall time: 208 ms
# Number of results: 1
# ---- Running query 121/1706 - fcu_name = plantain, scientific name: Musa x paradisiaca
# Wall time: 267 ms
# Number of results: 1
# ---- Running query 123/1706 - fcu_name = grande bardane, scientific name: Arctium lappa
# Wall time: 281 ms
# Number of results: 1
# ---- Running query 124/1706 - fcu_name = basilic, scientific name: Ocimum basilicum
# Wall time: 267 ms
# Number of results: 1
# ---- Running query 126/1706 - fcu_name = betterave, scientific name: Beta vulgaris
# Wall time: 246 ms
# Number of results: 1
# ---- Running query 129/1706 - fcu_name = betterave fourragère, scientific name: Beta vulgaris subsp. vulgaris var. crassa
# Wall time: 239 ms
# Number of results: 0
# ---- Running query 131/1706 - fcu_name = betterave potagère, scientific name: Beta vulgaris subsp. vulgaris var. conditiva
# Wall time: 271 ms
# Number of results: 0
# ---- Running query 140/1706 - fcu_name = bigarade, scientific name: Citrus aurantium
# Wall time: 257 ms
# Number of results: 2
# ---- Running query 141/1706 - fcu_name = bigaradier, scientific name: Citrus aurantium
# Wall time: 243 ms
# Number of results: 2
# ---- Running query 145/1706 - fcu_name = orange amère, scientific name: Citrus aurantium
# Wall time: 241 ms
# Number of results: 2
# ---- Running query 146/1706 - fcu_name = blé, scientific name: Triticum aestivum
# Wall time: 250 ms
# Number of results: 2
# ---- Running query 147/1706 - fcu_name = froment, scientific name: Triticum aestivum
# Wall time: 250 ms
# Number of results: 2
# ---- Running query 148/1706 - fcu_name = blé dur, scientific name: Triticum durum
# Wall time: 248 ms
# Number of results: 1
# ---- Running query 151/1706 - fcu_name = semoule, scientific name: Bombax ceiba
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 156/1706 - fcu_name = blé tendre, scientific name: Triticum aestivum
# Wall time: 255 ms
# Number of results: 2
# ---- Running query 158/1706 - fcu_name = froment, scientific name: Triticum aestivum
# Wall time: 178 ms
# Number of results: 2
# ---- Running query 164/1706 - fcu_name = audifoin, scientific name: Centaurea cyanus
# Wall time: 208 ms
# Number of results: 1
# ---- Running query 165/1706 - fcu_name = barbeau, scientific name: Centaurea cyanus
# Wall time: 294 ms
# Number of results: 1
# ---- Running query 167/1706 - fcu_name = bleuet, scientific name: Vaccinium myrtillus
# Wall time: 245 ms
# Number of results: 1
# ---- Running query 168/1706 - fcu_name = bleuet des champs, scientific name: Centaurea cyanus
# Wall time: 240 ms
# Number of results: 1
# ---- Running query 169/1706 - fcu_name = bleuet des montagnes, scientific name: Cyanus montanus
# Wall time: 253 ms
# Number of results: 2
# ---- Running query 170/1706 - fcu_name = bleuet vivace, scientific name: Centaurea cyanus
# Wall time: 250 ms
# Number of results: 1
# ---- Running query 172/1706 - fcu_name = jacée des montagnes, scientific name: Cyanus montanus
# Wall time: 246 ms
# Number of results: 2
# ---- Running query 177/1706 - fcu_name = bourrache, scientific name: Borago officinalis
# Wall time: 235 ms
# Number of results: 1
# ---- Running query 178/1706 - fcu_name = bourrache officinale, scientific name: Borago officinalis
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 180/1706 - fcu_name = brède mafane, scientific name: Acmella oleracea
# Wall time: 294 ms
# Number of results: 1
# ---- Running query 184/1706 - fcu_name = rapini, scientific name: Brassica rapa var. esculenta
# Wall time: 254 ms
# Number of results: 0
# ---- Running query 190/1706 - fcu_name = bugle rampante, scientific name: Ajuga reptans
# Wall time: 253 ms
# Number of results: 1
# ---- Running query 191/1706 - fcu_name = cacao, scientific name: Theobroma cacao
# Wall time: 258 ms
# Number of results: 1
# ---- Running query 194/1706 - fcu_name = café, scientific name: Coffea arabica
# Wall time: 266 ms
# Number of results: 1
# ---- Running query 197/1706 - fcu_name = calebasse, scientific name: Lagenaria siceraria
# Wall time: 246 ms
# Number of results: 1
# ---- Running query 202/1706 - fcu_name = gourde, scientific name: Cucurbita pepo
# Wall time: 259 ms
# Number of results: 1
# ---- Running query 207/1706 - fcu_name = sésame d'allemagne, scientific name: Camelina sativa
# Wall time: 254 ms
# Number of results: 1
# ---- Running query 209/1706 - fcu_name = camomille romaine, scientific name: Chamaemelum nobile
# Wall time: 259 ms
# Number of results: 1
# ---- Running query 213/1706 - fcu_name = canneberge, scientific name: Vaccinium oxycoccos
# Wall time: 244 ms
# Number of results: 1
# ---- Running query 218/1706 - fcu_name = canne à sucre, scientific name: Saccharum officinarum
# Wall time: 212 ms
# Number of results: 1
# ---- Running query 219/1706 - fcu_name = câprier, scientific name: Cadaba glandulosa
# Wall time: 245 ms
# Number of results: 0
# ---- Running query 220/1706 - fcu_name = carambole, scientific name: Allium ampeloprasum
# Wall time: 258 ms
# Number of results: 1
# ---- Running query 221/1706 - fcu_name = carambolier, scientific name: Averrhoa carambola
# Wall time: 257 ms
# Number of results: 1
# ---- Running query 223/1706 - fcu_name = cardamome, scientific name: Elettaria cardamomum
# Wall time: 235 ms
# Number of results: 1
# ---- Running query 224/1706 - fcu_name = artichaut sauvage, scientific name: Cynara cardunculus
# Wall time: 248 ms
# Number of results: 1
# ---- Running query 225/1706 - fcu_name = carde, scientific name: Beta vulgaris subsp. vulgaris var. cicla
# Wall time: 247 ms
# Number of results: 0
# ---- Running query 226/1706 - fcu_name = cardon, scientific name: Cynara cardunculus
# Wall time: 289 ms
# Number of results: 1
# ---- Running query 227/1706 - fcu_name = carotte, scientific name: Daucus carota
# Wall time: 306 ms
# Number of results: 2
# ---- Running query 231/1706 - fcu_name = caroubier, scientific name: Ceratonia siliqua
# Wall time: 258 ms
# Number of results: 1
# ---- Running query 234/1706 - fcu_name = anis des vosges, scientific name: Carum carvi
# Wall time: 262 ms
# Number of results: 1
# ---- Running query 235/1706 - fcu_name = carvi, scientific name: Carum carvi
# Wall time: 223 ms
# Number of results: 1
# ---- Running query 237/1706 - fcu_name = cumin des prés, scientific name: Carum carvi
# Wall time: 300 ms
# Number of results: 1
# ---- Running query 238/1706 - fcu_name = cassis, scientific name: Ribes nigrum
# Wall time: 281 ms
# Number of results: 1
# ---- Running query 239/1706 - fcu_name = cassissier, scientific name: Ribes nigrum
# Wall time: 225 ms
# Number of results: 1
# ---- Running query 241/1706 - fcu_name = cédratier, scientific name: Citrus medica
# Wall time: 260 ms
# Number of results: 1
# ---- Running query 242/1706 - fcu_name = ache des marais, scientific name: Apium graveolens
# Wall time: 483 ms
# Number of results: 1
# ---- Running query 244/1706 - fcu_name = céleri, scientific name: Apium graveolens
# Wall time: 275 ms
# Number of results: 1
# ---- Running query 245/1706 - fcu_name = persil des marais, scientific name: Cicuta virosa
# Wall time: 214 ms
# Number of results: 1
# ---- Running query 250/1706 - fcu_name = céleri à couper, scientific name: Apium graveolens var. secalinum
# Wall time: 253 ms
# Number of results: 1
# ---- Running query 252/1706 - fcu_name = céleri rave, scientific name: Apium graveolens var. rapaceum
# Wall time: 251 ms
# Number of results: 2
# ---- Running query 254/1706 - fcu_name = céleri-rave, scientific name: Apium graveolens var. rapaceum
# Wall time: 202 ms
# Number of results: 2
# ---- Running query 266/1706 - fcu_name = cerfeuil, scientific name: Anthriscus cerefolium
# Wall time: 254 ms
# Number of results: 1
# ---- Running query 267/1706 - fcu_name = cerfeuil anisé, scientific name: Myrrhis odorata
# Wall time: 293 ms
# Number of results: 1
# ---- Running query 268/1706 - fcu_name = cerfeuil d'espagne, scientific name: Myrrhis odorata
# Wall time: 249 ms
# Number of results: 1
# ---- Running query 269/1706 - fcu_name = cerfeuil musqué, scientific name: Myrrhis odorata
# Wall time: 283 ms
# Number of results: 1
# ---- Running query 271/1706 - fcu_name = fougère musquée, scientific name: Myrrhis odorata
# Wall time: 297 ms
# Number of results: 1
# ---- Running query 274/1706 - fcu_name = myrrhe, scientific name: Commiphora kua
# Wall time: 250 ms
# Number of results: 0
# ---- Running query 275/1706 - fcu_name = myrrhis odorant, scientific name: Myrrhis odorata
# Wall time: 1.63 s
# Number of results: 1
# ---- Running query 276/1706 - fcu_name = cerfeuil commun, scientific name: Anthriscus cerefolium
# Wall time: 292 ms
# Number of results: 1
# ---- Running query 277/1706 - fcu_name = cerfeuil cultivé, scientific name: Anthriscus cerefolium
# Wall time: 263 ms
# Number of results: 1
# ---- Running query 280/1706 - fcu_name = cerfeuil bulbeux, scientific name: Chaerophyllum bulbosum
# Wall time: 212 ms
# Number of results: 1
# ---- Running query 281/1706 - fcu_name = cerfeuil tubéreux, scientific name: Chaerophyllum bulbosum
# Wall time: 281 ms
# Number of results: 1
# ---- Running query 283/1706 - fcu_name = chérophylle bulbeux, scientific name: Chaerophyllum bulbosum
# Wall time: 260 ms
# Number of results: 1
# ---- Running query 292/1706 - fcu_name = cerisier acide, scientific name: Prunus cerasus
# Wall time: 263 ms
# Number of results: 1
# ---- Running query 295/1706 - fcu_name = guigne, scientific name: Prunus avium
# Wall time: 213 ms
# Number of results: 1
# ---- Running query 296/1706 - fcu_name = guignier, scientific name: Prunus avium
# Wall time: 288 ms
# Number of results: 1
# ---- Running query 298/1706 - fcu_name = merisier, scientific name: Prunus avium
# Wall time: 243 ms
# Number of results: 1
# ---- Running query 302/1706 - fcu_name = cerisier de cayenne, scientific name: Eugenia uniflora
# Wall time: 196 ms
# Number of results: 1
# ---- Running query 303/1706 - fcu_name = champignon, scientific name: Agaricus bisporus
# Wall time: 257 ms
# Number of results: 1
# ---- Running query 304/1706 - fcu_name = champignon de couche, scientific name: Agaricus bisporus
# Wall time: 237 ms
# Number of results: 1
# ---- Running query 305/1706 - fcu_name = champignon de paris, scientific name: Agaricus bisporus
# Wall time: 240 ms
# Number of results: 1
# ---- Running query 307/1706 - fcu_name = cannabis, scientific name: Cannabis sativa subsp. indica
# Wall time: 254 ms
# Number of results: 1
# ---- Running query 308/1706 - fcu_name = chanvre, scientific name: Cannabis sativa
# Wall time: 241 ms
# Number of results: 1
# ---- Running query 309/1706 - fcu_name = chanvre cultivé, scientific name: Cannabis sativa
# Wall time: 226 ms
# Number of results: 1
# ---- Running query 326/1706 - fcu_name = chardon marie, scientific name: Silybum marianum
# Wall time: 305 ms
# Number of results: 1
# ---- Running query 330/1706 - fcu_name = châtaignier, scientific name: Castanea sativa
# Wall time: 294 ms
# Number of results: 1
# ---- Running query 331/1706 - fcu_name = châtaignier commun, scientific name: Castanea sativa
# Wall time: 236 ms
# Number of results: 1
# ---- Running query 336/1706 - fcu_name = chêne pédonculé, scientific name: Quercus robur
# Wall time: 295 ms
# Number of results: 1
# ---- Running query 337/1706 - fcu_name = chêne rouvre, scientific name: Quercus petraea
# Wall time: 278 ms
# Number of results: 1
# ---- Running query 338/1706 - fcu_name = chicorée, scientific name: Cichorium intybus
# Wall time: 258 ms
# Number of results: 1
# ---- Running query 339/1706 - fcu_name = chicorée sauvage, scientific name: Cichorium intybus
# Wall time: 221 ms
# Number of results: 1
# ---- Running query 344/1706 - fcu_name = endive, scientific name: Cichorium endivia
# Wall time: 292 ms
# Number of results: 1
# ---- Running query 346/1706 - fcu_name = chicorée frisée, scientific name: Cichorium endivia var. crispum
# Wall time: 283 ms
# Number of results: 2
# ---- Running query 347/1706 - fcu_name = frisée, scientific name: Cichorium endivia
# Wall time: 286 ms
# Number of results: 1
# ---- Running query 354/1706 - fcu_name = chicorée à café, scientific name: Cichorium intybus var. sativum
# Wall time: 259 ms
# Number of results: 1
# ---- Running query 356/1706 - fcu_name = chicorée, scientific name: Cichorium intybus
# Wall time: 149 ms
# Number of results: 1
# ---- Running query 359/1706 - fcu_name = endive, scientific name: Cichorium endivia
# Wall time: 173 ms
# Number of results: 1
# ---- Running query 361/1706 - fcu_name = chicorée scarole, scientific name: Cichorium endivia var. latifolia
# Wall time: 246 ms
# Number of results: 0
# ---- Running query 365/1706 - fcu_name = scarole, scientific name: Lactuca serriola
# Wall time: 252 ms
# Number of results: 1
# ---- Running query 366/1706 - fcu_name = chou, scientific name: Brassica oleracea
# Wall time: 239 ms
# Number of results: 1
# ---- Running query 367/1706 - fcu_name = chou de bruxelles, scientific name: Brassica oleracea var. gemmifera
# Wall time: 240 ms
# Number of results: 3
# ---- Running query 369/1706 - fcu_name = chou de milan, scientific name: Brassica oleracea var. sabauda
# Wall time: 260 ms
# Number of results: 2
# ---- Running query 370/1706 - fcu_name = chou de savoie, scientific name: Brassica oleracea var. sabauda
# Wall time: 785 ms
# Number of results: 2
# ---- Running query 372/1706 - fcu_name = brocoli, scientific name: Brassica oleracea var. italica
# Wall time: 286 ms
# Number of results: 1
# ---- Running query 373/1706 - fcu_name = chou brocoli, scientific name: Brassica oleracea var. italica
# Wall time: 251 ms
# Number of results: 1
# ---- Running query 375/1706 - fcu_name = chou cabus blanc, scientific name: Brassica oleracea var. capitata
# Wall time: 230 ms
# Number of results: 2
# ---- Running query 380/1706 - fcu_name = chou rouge, scientific name: Brassica oleracea var. capitata f. rubra
# Wall time: 293 ms
# Number of results: 0
# ---- Running query 381/1706 - fcu_name = bok choy, scientific name: Brassica rapa subsp. chinensis
# Wall time: 256 ms
# Number of results: 1
# ---- Running query 383/1706 - fcu_name = chou chinois, scientific name: Brassica rapa subsp. pekinensis
# Wall time: 216 ms
# Number of results: 1
# ---- Running query 384/1706 - fcu_name = chou de chine, scientific name: Brassica rapa subsp. pekinensis
# Wall time: 245 ms
# Number of results: 1
# ---- Running query 386/1706 - fcu_name = chou de shanton, scientific name: Brassica rapa subsp. pekinensis
# Wall time: 263 ms
# Number of results: 1
# ---- Running query 392/1706 - fcu_name = chou commun, scientific name: Brassica oleracea var. medullosa
# Wall time: 254 ms
# Number of results: 2
# ---- Running query 393/1706 - fcu_name = chou vert, scientific name: Brassica oleracea var. viridis
# Wall time: 242 ms
# Number of results: 2
# ---- Running query 395/1706 - fcu_name = chou-fleur, scientific name: Brassica oleracea var. botrytis
# Wall time: 215 ms
# Number of results: 1
# ---- Running query 396/1706 - fcu_name = chou branchu, scientific name: Brassica oleracea var. ramosa
# Wall time: 814 ms
# Number of results: 1
# ---- Running query 397/1706 - fcu_name = chou cavalier, scientific name: Brassica oleracea var. viridis
# Wall time: 207 ms
# Number of results: 2
# ---- Running query 399/1706 - fcu_name = chou fourrager, scientific name: Brassica oleracea var. viridis
# Wall time: 276 ms
# Number of results: 2
# ---- Running query 400/1706 - fcu_name = chou moellier, scientific name: Brassica oleracea var. medullosa
# Wall time: 244 ms
# Number of results: 2
# ---- Running query 402/1706 - fcu_name = chou frangé, scientific name: Brassica oleracea var. sabellica
# Wall time: 558 ms
# Number of results: 2
# ---- Running query 403/1706 - fcu_name = chou frisé, scientific name: Brassica oleracea var. sabellica
# Wall time: 296 ms
# Number of results: 2
# ---- Running query 405/1706 - fcu_name = chou lacinié, scientific name: Brassica oleracea var. sabellica
# Wall time: 260 ms
# Number of results: 2
# ---- Running query 407/1706 - fcu_name = chou vert, scientific name: Brassica oleracea var. viridis
# Wall time: 250 ms
# Number of results: 2
# ---- Running query 408/1706 - fcu_name = chou navet, scientific name: Brassica oleracea var. gongylodes
# Wall time: 195 ms
# Number of results: 2
# ---- Running query 413/1706 - fcu_name = rutabaga, scientific name: Brassica napus subsp. rapifera
# Wall time: 636 ms
# Number of results: 1
# ---- Running query 415/1706 - fcu_name = chou pommé, scientific name: Brassica oleracea var. capitata
# Wall time: 281 ms
# Number of results: 2
# ---- Running query 416/1706 - fcu_name = chou, scientific name: Brassica oleracea
# Wall time: 252 ms
# Number of results: 1
# ---- Running query 419/1706 - fcu_name = chou potager, scientific name: Brassica oleracea var. capitata
# Wall time: 254 ms
# Number of results: 2
# ---- Running query 420/1706 - fcu_name = palmier royal, scientific name: Roystonea regia
# Wall time: 256 ms
# Number of results: 1
# ---- Running query 421/1706 - fcu_name = palmiste, scientific name: Deckenia nobilis
# Wall time: 257 ms
# Number of results: 1
# ---- Running query 425/1706 - fcu_name = chou rave, scientific name: Brassica oleracea var. gongylodes
# Wall time: 257 ms
# Number of results: 2
# ---- Running query 426/1706 - fcu_name = chou-rave, scientific name: Brassica rapa subsp. sylvestris
# Wall time: 258 ms
# Number of results: 0
# ---- Running query 431/1706 - fcu_name = chou vert, scientific name: Brassica oleracea var. viridis
# Wall time: 178 ms
# Number of results: 2
# ---- Running query 433/1706 - fcu_name = chayote, scientific name: Sechium edule
# Wall time: 1.29 s
# Number of results: 1
# ---- Running query 434/1706 - fcu_name = chayotte, scientific name: Sechium edule
# Wall time: 270 ms
# Number of results: 1
# ---- Running query 435/1706 - fcu_name = chouchou, scientific name: Sechium edule
# Wall time: 231 ms
# Number of results: 1
# ---- Running query 436/1706 - fcu_name = chouchoute, scientific name: Sechium edule
# Wall time: 229 ms
# Number of results: 1
# ---- Running query 437/1706 - fcu_name = christophine, scientific name: Sechium edule
# Wall time: 221 ms
# Number of results: 1
# ---- Running query 441/1706 - fcu_name = ail fistuleux, scientific name: Allium fistulosum
# Wall time: 249 ms
# Number of results: 1
# ---- Running query 444/1706 - fcu_name = ciboule, scientific name: Allium fistulosum
# Wall time: 290 ms
# Number of results: 1
# ---- Running query 445/1706 - fcu_name = cive, scientific name: Allium fistulosum
# Wall time: 240 ms
# Number of results: 1
# ---- Running query 446/1706 - fcu_name = oignon d'espagne, scientific name: Allium fistulosum
# Wall time: 241 ms
# Number of results: 1
# ---- Running query 449/1706 - fcu_name = ciboulette, scientific name: Allium schoenoprasum
# Wall time: 251 ms
# Number of results: 1
# ---- Running query 450/1706 - fcu_name = civette, scientific name: Allium schoenoprasum
# Wall time: 292 ms
# Number of results: 1
# ---- Running query 451/1706 - fcu_name = citron, scientific name: Citrus limon
# Wall time: 285 ms
# Number of results: 1
# ---- Running query 452/1706 - fcu_name = citronnier, scientific name: Citrus limon
# Wall time: 246 ms
# Number of results: 1
# ---- Running query 453/1706 - fcu_name = citrouille, scientific name: Cucurbita maxima
# Wall time: 243 ms
# Number of results: 1
# ---- Running query 458/1706 - fcu_name = clémentinier, scientific name: Citrus clementina
# Wall time: 249 ms
# Number of results: 0
# ---- Running query 462/1706 - fcu_name = cognassier, scientific name: Cydonia oblonga
# Wall time: 255 ms
# Number of results: 1
# ---- Running query 466/1706 - fcu_name = colza, scientific name: Brassica napus
# Wall time: 223 ms
# Number of results: 1
# ---- Running query 482/1706 - fcu_name = combava, scientific name: Citrus hystrix
# Wall time: 252 ms
# Number of results: 1
# ---- Running query 487/1706 - fcu_name = makrut, scientific name: Citrus hystrix
# Wall time: 233 ms
# Number of results: 1
# ---- Running query 488/1706 - fcu_name = concombre, scientific name: Cucumis sativus
# Wall time: 233 ms
# Number of results: 1
# ---- Running query 492/1706 - fcu_name = coqueret du pérou, scientific name: Physalis peruviana
# Wall time: 240 ms
# Number of results: 2
# ---- Running query 493/1706 - fcu_name = groseille du cap, scientific name: Physalis pruinosa
# Wall time: 234 ms
# Number of results: 0
# ---- Running query 494/1706 - fcu_name = coriandre, scientific name: Coriandrum sativum
# Wall time: 207 ms
# Number of results: 1
# ---- Running query 496/1706 - fcu_name = cornichon, scientific name: Cucumis sativus
# Wall time: 260 ms
# Number of results: 1
# ---- Running query 497/1706 - fcu_name = cornille, scientific name: Vigna unguiculata subsp. sesquipedalis
# Wall time: 231 ms
# Number of results: 1
# ---- Running query 498/1706 - fcu_name = dolique de chine, scientific name: Vigna unguiculata subsp. unguiculata
# Wall time: 273 ms
# Number of results: 1
# ---- Running query 505/1706 - fcu_name = mongette, scientific name: Vigna unguiculata
# Wall time: 301 ms
# Number of results: 1
# ---- Running query 506/1706 - fcu_name = niébé, scientific name: Vigna unguiculata
# Wall time: 230 ms
# Number of results: 1
# ---- Running query 512/1706 - fcu_name = corossol épineux, scientific name: Annona muricata
# Wall time: 265 ms
# Number of results: 1
# ---- Running query 514/1706 - fcu_name = courge, scientific name: Cucurbita pepo
# Wall time: 222 ms
# Number of results: 1
# ---- Running query 515/1706 - fcu_name = courge musquée, scientific name: Cucurbita moschata
# Wall time: 286 ms
# Number of results: 1
# ---- Running query 521/1706 - fcu_name = courge musquée, scientific name: Cucurbita moschata
# Wall time: 184 ms
# Number of results: 1
# ---- Running query 523/1706 - fcu_name = courgette, scientific name: Cucurbita pepo var. giromontiina
# Wall time: 249 ms
# Number of results: 0
# ---- Running query 526/1706 - fcu_name = crocus cultivé, scientific name: Crocus sativus
# Wall time: 252 ms
# Number of results: 1
# ---- Running query 528/1706 - fcu_name = safran, scientific name: Crocus sativus
# Wall time: 248 ms
# Number of results: 1
# ---- Running query 529/1706 - fcu_name = safran cultivé, scientific name: Crocus sativus
# Wall time: 249 ms
# Number of results: 1
# ---- Running query 531/1706 - fcu_name = crosne du japon, scientific name: Stachys affinis
# Wall time: 247 ms
# Number of results: 1
# ---- Running query 561/1706 - fcu_name = cumin, scientific name: Cuminum cyminum
# Wall time: 248 ms
# Number of results: 1
# ---- Running query 564/1706 - fcu_name = faux anis, scientific name: Anethum graveolens
# Wall time: 249 ms
# Number of results: 1
# ---- Running query 565/1706 - fcu_name = curcuma, scientific name: Maranta arundinacea
# Wall time: 264 ms
# Number of results: 1
# ---- Running query 567/1706 - fcu_name = dactyle aggloméré, scientific name: Dactylis glomerata
# Wall time: 252 ms
# Number of results: 1
# ---- Running query 568/1706 - fcu_name = dactyle pelotonné, scientific name: Dactylis glomerata
# Wall time: 736 ms
# Number of results: 1
# ---- Running query 569/1706 - fcu_name = dolique asperge, scientific name: Vigna unguiculata subsp. sesquipedalis
# Wall time: 289 ms
# Number of results: 1
# ---- Running query 578/1706 - fcu_name = échalote, scientific name: Allium ascalonicum
# Wall time: 256 ms
# Number of results: 3
# ---- Running query 581/1706 - fcu_name = échalote grise, scientific name: Allium oschaninii
# Wall time: 258 ms
# Number of results: 1
# ---- Running query 583/1706 - fcu_name = cynorhodon, scientific name: Rosa canina
# Wall time: 252 ms
# Number of results: 1
# ---- Running query 584/1706 - fcu_name = cynorrhodon, scientific name: Rosa canina
# Wall time: 244 ms
# Number of results: 1
# ---- Running query 585/1706 - fcu_name = rosier sauvage, scientific name: Rosa canina
# Wall time: 267 ms
# Number of results: 1
# ---- Running query 586/1706 - fcu_name = églantier, scientific name: Rosa canina
# Wall time: 773 ms
# Number of results: 1
# ---- Running query 588/1706 - fcu_name = engrain, scientific name: Triticum monococcum
# Wall time: 295 ms
# Number of results: 1
# ---- Running query 589/1706 - fcu_name = petit épeautre, scientific name: Triticum monococcum
# Wall time: 207 ms
# Number of results: 1
# ---- Running query 600/1706 - fcu_name = grand épeautre, scientific name: Triticum spelta
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 601/1706 - fcu_name = épeautre, scientific name: Triticum spelta
# Wall time: 241 ms
# Number of results: 1
# ---- Running query 602/1706 - fcu_name = épinard, scientific name: Spinacia oleracea
# Wall time: 216 ms
# Number of results: 1
# ---- Running query 605/1706 - fcu_name = sycomore, scientific name: Acer pseudoplatanus
# Wall time: 1.22 s
# Number of results: 1
# ---- Running query 606/1706 - fcu_name = érable sycomore, scientific name: Acer pseudoplatanus
# Wall time: 276 ms
# Number of results: 1
# ---- Running query 607/1706 - fcu_name = estragon, scientific name: Artemisia dracunculus
# Wall time: 260 ms
# Number of results: 1
# ---- Running query 608/1706 - fcu_name = fenouil, scientific name: Foeniculum vulgare
# Wall time: 1.25 s
# Number of results: 1
# ---- Running query 610/1706 - fcu_name = fenugrec, scientific name: Trigonella foenum-graecum
# Wall time: 254 ms
# Number of results: 1
# ---- Running query 613/1706 - fcu_name = trigonelle fenugrec, scientific name: Trigonella foenum-graecum
# Wall time: 235 ms
# Number of results: 1
# ---- Running query 616/1706 - fcu_name = fenugrec, scientific name: Trigonella foenum-graecum
# Wall time: 165 ms
# Number of results: 1
# ---- Running query 620/1706 - fcu_name = fétuque élevée, scientific name: Lolium pratense
# Wall time: 239 ms
# Number of results: 2
# ---- Running query 625/1706 - fcu_name = féverole, scientific name: Vicia faba subsp. minor
# Wall time: 256 ms
# Number of results: 1
# ---- Running query 626/1706 - fcu_name = féverolle, scientific name: Vicia faba subsp. minor
# Wall time: 255 ms
# Number of results: 1
# ---- Running query 630/1706 - fcu_name = féverole fourragère, scientific name: Vicia faba subsp. minor
# Wall time: 244 ms
# Number of results: 1
# ---- Running query 642/1706 - fcu_name = fève, scientific name: Vicia faba
# Wall time: 228 ms
# Number of results: 1
# ---- Running query 645/1706 - fcu_name = grosse fève, scientific name: Vicia faba
# Wall time: 271 ms
# Number of results: 1
# ---- Running query 650/1706 - fcu_name = figuier, scientific name: Ficus carica
# Wall time: 232 ms
# Number of results: 1
# ---- Running query 664/1706 - fcu_name = framboisier, scientific name: Rubus idaeus
# Wall time: 228 ms
# Number of results: 1
# ---- Running query 667/1706 - fcu_name = gaillet gratteron, scientific name: Galium aparine
# Wall time: 246 ms
# Number of results: 1
# ---- Running query 676/1706 - fcu_name = genêt des teinturiers, scientific name: Genista tinctoria
# Wall time: 259 ms
# Number of results: 1
# ---- Running query 678/1706 - fcu_name = gentiane jaune, scientific name: Gentiana lutea
# Wall time: 234 ms
# Number of results: 1
# ---- Running query 679/1706 - fcu_name = grande gentiane, scientific name: Gentiana lutea
# Wall time: 238 ms
# Number of results: 1
# ---- Running query 681/1706 - fcu_name = géranium, scientific name: Pelargonium x hortorum
# Wall time: 228 ms
# Number of results: 1
# ---- Running query 683/1706 - fcu_name = gerbera, scientific name: Gerbera
# Wall time: 264 ms
# Number of results: 0
# ---- Running query 685/1706 - fcu_name = gesse chiche, scientific name: Lathyrus cicera
# Wall time: 263 ms
# Number of results: 1
# ---- Running query 686/1706 - fcu_name = gesse cultivée, scientific name: Lathyrus sativus
# Wall time: 226 ms
# Number of results: 1
# ---- Running query 688/1706 - fcu_name = jarosse, scientific name: Lathyrus cicera
# Wall time: 283 ms
# Number of results: 1
# ---- Running query 690/1706 - fcu_name = gesse odorante, scientific name: Lathyrus odoratus
# Wall time: 240 ms
# Number of results: 1
# ---- Running query 691/1706 - fcu_name = pois de senteur, scientific name: Lathyrus odoratus
# Wall time: 238 ms
# Number of results: 1
# ---- Running query 694/1706 - fcu_name = gesse commune, scientific name: Lathyrus sativus
# Wall time: 254 ms
# Number of results: 1
# ---- Running query 697/1706 - fcu_name = pois carré, scientific name: Psophocarpus tetragonolobus
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 700/1706 - fcu_name = ginkgo biloba, scientific name: Ginkgo biloba
# Wall time: 277 ms
# Number of results: 1
# ---- Running query 704/1706 - fcu_name = gombo, scientific name: Abelmoschus esculentus
# Wall time: 274 ms
# Number of results: 1
# ---- Running query 705/1706 - fcu_name = okura, scientific name: Abelmoschus esculentus
# Wall time: 234 ms
# Number of results: 1
# ---- Running query 711/1706 - fcu_name = goyavier, scientific name: Psidium guajava
# Wall time: 216 ms
# Number of results: 1
# ---- Running query 713/1706 - fcu_name = goyavier fraise, scientific name: Psidium longipes
# Wall time: 258 ms
# Number of results: 1
# ---- Running query 718/1706 - fcu_name = grenadier, scientific name: Punica granatum
# Wall time: 292 ms
# Number of results: 1
# ---- Running query 720/1706 - fcu_name = fruit de la passion, scientific name: Passiflora edulis
# Wall time: 3.22 s
# Number of results: 1
# ---- Running query 725/1706 - fcu_name = maracudja, scientific name: Passiflora edulis
# Wall time: 237 ms
# Number of results: 1
# ---- Running query 726/1706 - fcu_name = maracuja, scientific name: Passiflora edulis f. flavicarpa
# Wall time: 208 ms
# Number of results: 1
# ---- Running query 736/1706 - fcu_name = haricot, scientific name: Phaseolus vulgaris
# Wall time: 232 ms
# Number of results: 1
# ---- Running query 737/1706 - fcu_name = haricot commun, scientific name: Phaseolus vulgaris
# Wall time: 232 ms
# Number of results: 1
# ---- Running query 738/1706 - fcu_name = haricot nain, scientific name: Phaseolus vulgaris subsp. nanus
# Wall time: 195 ms
# Number of results: 0
# ---- Running query 739/1706 - fcu_name = haricot à rames, scientific name: Phaseolus vulgaris
# Wall time: 280 ms
# Number of results: 1
# ---- Running query 740/1706 - fcu_name = haricot d'espagne, scientific name: Phaseolus coccineus
# Wall time: 244 ms
# Number of results: 1
# ---- Running query 743/1706 - fcu_name = haricot écarlate, scientific name: Phaseolus coccineus
# Wall time: 247 ms
# Number of results: 1
# ---- Running query 744/1706 - fcu_name = haricot-fleur, scientific name: Phaseolus coccineus
# Wall time: 239 ms
# Number of results: 1
# ---- Running query 745/1706 - fcu_name = flageolet, scientific name: Phaseolus vulgaris
# Wall time: 225 ms
# Number of results: 1
# ---- Running query 751/1706 - fcu_name = haricot sabre, scientific name: Canavalia ensiformis
# Wall time: 240 ms
# Number of results: 1
# ---- Running query 762/1706 - fcu_name = haricot nain, scientific name: Phaseolus vulgaris subsp. nanus
# Wall time: 174 ms
# Number of results: 0
# ---- Running query 764/1706 - fcu_name = haricot vert, scientific name: Phaseolus vulgaris
# Wall time: 253 ms
# Number of results: 1
# ---- Running query 765/1706 - fcu_name = haricot à rames, scientific name: Phaseolus vulgaris
# Wall time: 186 ms
# Number of results: 1
# ---- Running query 768/1706 - fcu_name = immortelle, scientific name: Xerochrysum bracteatum
# Wall time: 235 ms
# Number of results: 1
# ---- Running query 771/1706 - fcu_name = hellébore noir, scientific name: Helleborus niger
# Wall time: 265 ms
# Number of results: 1
# ---- Running query 772/1706 - fcu_name = rose de noël, scientific name: Euphorbia pulcherrima
# Wall time: 248 ms
# Number of results: 1
# ---- Running query 774/1706 - fcu_name = hêtre, scientific name: Fagus sylvatica
# Wall time: 251 ms
# Number of results: 1
# ---- Running query 775/1706 - fcu_name = hêtre commun, scientific name: Fagus sylvatica
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 776/1706 - fcu_name = hibiscus, scientific name: Hibiscus trionum
# Wall time: 238 ms
# Number of results: 1
# ---- Running query 780/1706 - fcu_name = rose de chine, scientific name: Hibiscus rosa-sinensis
# Wall time: 301 ms
# Number of results: 1
# ---- Running query 789/1706 - fcu_name = couleuvrée septentrionale, scientific name: Humulus lupulus
# Wall time: 251 ms
# Number of results: 1
# ---- Running query 790/1706 - fcu_name = houblon, scientific name: Humulus lupulus
# Wall time: 256 ms
# Number of results: 1
# ---- Running query 791/1706 - fcu_name = houblon grimpant, scientific name: Humulus lupulus
# Wall time: 268 ms
# Number of results: 1
# ---- Running query 793/1706 - fcu_name = salsepareille indigène, scientific name: Smilax anceps
# Wall time: 238 ms
# Number of results: 1
# ---- Running query 794/1706 - fcu_name = vigne du nord, scientific name: Humulus lupulus
# Wall time: 275 ms
# Number of results: 1
# ---- Running query 812/1706 - fcu_name = laitue cultivée, scientific name: Lactuca sativa
# Wall time: 238 ms
# Number of results: 1
# ---- Running query 825/1706 - fcu_name = laitue frisée, scientific name: Lactuca sativa var. crispa
# Wall time: 214 ms
# Number of results: 1
# ---- Running query 826/1706 - fcu_name = laitue à couper, scientific name: Lactuca sativa var. crispa
# Wall time: 264 ms
# Number of results: 1
# ---- Running query 835/1706 - fcu_name = laitue pommée, scientific name: Lactuca sativa var. capitata
# Wall time: 258 ms
# Number of results: 1
# ---- Running query 843/1706 - fcu_name = laitue romaine, scientific name: Lactuca sativa var. longifolia
# Wall time: 246 ms
# Number of results: 1
# ---- Running query 848/1706 - fcu_name = laurier sauce, scientific name: Laurus nobilis
# Wall time: 286 ms
# Number of results: 1
# ---- Running query 851/1706 - fcu_name = laurier tin, scientific name: Viburnum tinus
# Wall time: 227 ms
# Number of results: 1
# ---- Running query 852/1706 - fcu_name = laurier-cerise, scientific name: Prunus laurocerasus
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 857/1706 - fcu_name = lavandin, scientific name: Lavandula x intermedia
# Wall time: 283 ms
# Number of results: 1
# ---- Running query 882/1706 - fcu_name = lentille, scientific name: Lens culinaris
# Wall time: 238 ms
# Number of results: 1
# ---- Running query 883/1706 - fcu_name = lentille comestible, scientific name: Lens culinaris
# Wall time: 233 ms
# Number of results: 1
# ---- Running query 884/1706 - fcu_name = lentille cultivée, scientific name: Lens culinaris
# Wall time: 234 ms
# Number of results: 1
# ---- Running query 887/1706 - fcu_name = lentille noirâtre, scientific name: Lens nigricans
# Wall time: 240 ms
# Number of results: 1
# ---- Running query 895/1706 - fcu_name = citron vert, scientific name: Citrus aurantiifolia
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 896/1706 - fcu_name = lime, scientific name: Citrus aurantiifolia
# Wall time: 236 ms
# Number of results: 1
# ---- Running query 897/1706 - fcu_name = limette, scientific name: Citrus aurantiifolia
# Wall time: 310 ms
# Number of results: 1
# ---- Running query 898/1706 - fcu_name = limettier, scientific name: Citrus limetta
# Wall time: 267 ms
# Number of results: 1
# ---- Running query 899/1706 - fcu_name = limonium, scientific name: Limonium
# Wall time: 244 ms
# Number of results: 0
# ---- Running query 900/1706 - fcu_name = statice, scientific name: Limonium
# Wall time: 227 ms
# Number of results: 0
# ---- Running query 901/1706 - fcu_name = lin, scientific name: Linum usitatissimum
# Wall time: 229 ms
# Number of results: 1
# ---- Running query 902/1706 - fcu_name = lin cultivé, scientific name: Linum usitatissimum
# Wall time: 234 ms
# Number of results: 1
# ---- Running query 922/1706 - fcu_name = litchi, scientific name: Litchi chinensis
# Wall time: 232 ms
# Number of results: 1
# ---- Running query 923/1706 - fcu_name = litchi chinensis, scientific name: Litchi chinensis
# Wall time: 240 ms
# Number of results: 1
# ---- Running query 925/1706 - fcu_name = céleri perpétuel, scientific name: Levisticum officinale
# Wall time: 280 ms
# Number of results: 1
# ---- Running query 926/1706 - fcu_name = lavas, scientific name: Levisticum officinale
# Wall time: 289 ms
# Number of results: 1
# ---- Running query 927/1706 - fcu_name = livèche, scientific name: Levisticum officinale
# Wall time: 207 ms
# Number of results: 1
# ---- Running query 928/1706 - fcu_name = longane, scientific name: Dimocarpus longan
# Wall time: 277 ms
# Number of results: 1
# ---- Running query 929/1706 - fcu_name = longani, scientific name: Dimocarpus longan
# Wall time: 208 ms
# Number of results: 1
# ---- Running query 930/1706 - fcu_name = longanier, scientific name: Dimocarpus longan
# Wall time: 273 ms
# Number of results: 1
# ---- Running query 932/1706 - fcu_name = lotier corniculé, scientific name: Lotus corniculatus
# Wall time: 289 ms
# Number of results: 1
# ---- Running query 933/1706 - fcu_name = lotier des marais, scientific name: Lotus pedunculatus
# Wall time: 250 ms
# Number of results: 1
# ---- Running query 935/1706 - fcu_name = lupin, scientific name: Lupinus micranthus
# Wall time: 227 ms
# Number of results: 1
# ---- Running query 936/1706 - fcu_name = lupin blanc, scientific name: Lupinus albus
# Wall time: 250 ms
# Number of results: 1
# ---- Running query 938/1706 - fcu_name = lupin bleu, scientific name: Lupinus angustifolius
# Wall time: 241 ms
# Number of results: 1
# ---- Running query 942/1706 - fcu_name = lupin jaune, scientific name: Lupinus luteus
# Wall time: 202 ms
# Number of results: 1
# ---- Running query 946/1706 - fcu_name = lupin bleu, scientific name: Lupinus angustifolius
# Wall time: 215 ms
# Number of results: 1
# ---- Running query 953/1706 - fcu_name = lupin bleu, scientific name: Lupinus angustifolius
# Wall time: 189 ms
# Number of results: 1
# ---- Running query 955/1706 - fcu_name = lupin jaune, scientific name: Lupinus luteus
# Wall time: 188 ms
# Number of results: 1
# ---- Running query 958/1706 - fcu_name = lupin réticulé, scientific name: Lupinus angustifolius
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 960/1706 - fcu_name = lupin blanc, scientific name: Lupinus albus
# Wall time: 188 ms
# Number of results: 1
# ---- Running query 966/1706 - fcu_name = lupuline, scientific name: Medicago lupulina
# Wall time: 282 ms
# Number of results: 1
# ---- Running query 967/1706 - fcu_name = luzerne lupuline, scientific name: Medicago lupulina
# Wall time: 238 ms
# Number of results: 1
# ---- Running query 968/1706 - fcu_name = mignonette, scientific name: Reseda media
# Wall time: 253 ms
# Number of results: 0
# ---- Running query 969/1706 - fcu_name = minette, scientific name: Medicago lupulina
# Wall time: 254 ms
# Number of results: 1
# ---- Running query 970/1706 - fcu_name = petit trèfle jaune, scientific name: Trifolium dubium
# Wall time: 253 ms
# Number of results: 1
# ---- Running query 972/1706 - fcu_name = alfalfa, scientific name: Medicago sativa
# Wall time: 225 ms
# Number of results: 1
# ---- Running query 975/1706 - fcu_name = luzerne, scientific name: Medicago sativa
# Wall time: 371 ms
# Number of results: 1
# ---- Running query 976/1706 - fcu_name = luzerne cultivée, scientific name: Medicago sativa
# Wall time: 298 ms
# Number of results: 1
# ---- Running query 983/1706 - fcu_name = blanchette, scientific name: Suaeda maritima
# Wall time: 246 ms
# Number of results: 1
# ---- Running query 984/1706 - fcu_name = boursette, scientific name: Capsella bursa-pastoris
# Wall time: 243 ms
# Number of results: 1
# ---- Running query 986/1706 - fcu_name = doucette, scientific name: Valerianella eriocarpa
# Wall time: 227 ms
# Number of results: 1
# ---- Running query 987/1706 - fcu_name = mâche, scientific name: Valerianella eriocarpa
# Wall time: 260 ms
# Number of results: 1
# ---- Running query 988/1706 - fcu_name = oreillette, scientific name: Asarum europaeum
# Wall time: 232 ms
# Number of results: 1
# ---- Running query 989/1706 - fcu_name = raiponce, scientific name: Campanula rapunculus
# Wall time: 251 ms
# Number of results: 1
# ---- Running query 993/1706 - fcu_name = maïs, scientific name: Zea mays
# Wall time: 238 ms
# Number of results: 1
# ---- Running query 995/1706 - fcu_name = maïs doux, scientific name: Zea mays subsp. saccharata
# Wall time: 228 ms
# Number of results: 0
# ---- Running query 996/1706 - fcu_name = maïs sucré, scientific name: Zea mays subsp. saccharata
# Wall time: 261 ms
# Number of results: 0
# ---- Running query 1008/1706 - fcu_name = maïs éclaté, scientific name: Zea mays subsp. everta
# Wall time: 235 ms
# Number of results: 0
# ---- Running query 1010/1706 - fcu_name = popcorn, scientific name: Zea mays subsp. everta
# Wall time: 230 ms
# Number of results: 0
# ---- Running query 1013/1706 - fcu_name = mandarinier, scientific name: Citrus reticulata
# Wall time: 223 ms
# Number of results: 1
# ---- Running query 1014/1706 - fcu_name = tangerine, scientific name: Citrus reticulata
# Wall time: 221 ms
# Number of results: 1
# ---- Running query 1016/1706 - fcu_name = mangostan, scientific name: Garcinia mangostana
# Wall time: 265 ms
# Number of results: 1
# ---- Running query 1018/1706 - fcu_name = mangoustan, scientific name: Garcinia mangostana
# Wall time: 238 ms
# Number of results: 1
# ---- Running query 1023/1706 - fcu_name = mangue, scientific name: Mangifera indica
# Wall time: 240 ms
# Number of results: 1
# ---- Running query 1024/1706 - fcu_name = manguier, scientific name: Mangifera indica
# Wall time: 245 ms
# Number of results: 1
# ---- Running query 1027/1706 - fcu_name = manioc, scientific name: Manihot esculenta
# Wall time: 232 ms
# Number of results: 1
# ---- Running query 1032/1706 - fcu_name = marguerite, scientific name: Argyranthemum frutescens
# Wall time: 277 ms
# Number of results: 1
# ---- Running query 1033/1706 - fcu_name = marguerite commune, scientific name: Leucanthemum vulgare
# Wall time: 265 ms
# Number of results: 1
# ---- Running query 1034/1706 - fcu_name = marjolaine, scientific name: Origanum vulgare
# Wall time: 240 ms
# Number of results: 1
# ---- Running query 1038/1706 - fcu_name = grande mauve, scientific name: Malva sylvestris
# Wall time: 236 ms
# Number of results: 1
# ---- Running query 1039/1706 - fcu_name = mauve, scientific name: Abutilon hulseanum
# Wall time: 218 ms
# Number of results: 1
# ---- Running query 1040/1706 - fcu_name = mauve des bois, scientific name: Malva sylvestris
# Wall time: 265 ms
# Number of results: 1
# ---- Running query 1041/1706 - fcu_name = mauve sylvestre, scientific name: Malva sylvestris
# Wall time: 280 ms
# Number of results: 1
# ---- Running query 1042/1706 - fcu_name = mélilot, scientific name: Melilotus officinalis
# Wall time: 410 ms
# Number of results: 2
# ---- Running query 1043/1706 - fcu_name = couronne royale, scientific name: Melilotus officinalis
# Wall time: 461 ms
# Number of results: 2
# ---- Running query 1044/1706 - fcu_name = herbe aux puces, scientific name: Plantago sempervirens
# Wall time: 285 ms
# Number of results: 1
# ---- Running query 1046/1706 - fcu_name = mélilot blanc, scientific name: Melilotus albus
# Wall time: 244 ms
# Number of results: 1
# ---- Running query 1050/1706 - fcu_name = mélilot jaune, scientific name: Melilotus officinalis
# Wall time: 273 ms
# Number of results: 2
# ---- Running query 1051/1706 - fcu_name = petit trèfle jaune, scientific name: Trifolium dubium
# Wall time: 169 ms
# Number of results: 1
# ---- Running query 1052/1706 - fcu_name = trèfle de bokhara, scientific name: Melilotus albus
# Wall time: 237 ms
# Number of results: 1
# ---- Running query 1053/1706 - fcu_name = trèfle des mouches, scientific name: Melilotus officinalis
# Wall time: 286 ms
# Number of results: 2
# ---- Running query 1054/1706 - fcu_name = mélilot jaune, scientific name: Melilotus officinalis
# Wall time: 162 ms
# Number of results: 2
# ---- Running query 1055/1706 - fcu_name = mélilot officinal, scientific name: Melilotus officinalis
# Wall time: 205 ms
# Number of results: 2
# ---- Running query 1056/1706 - fcu_name = mélilot jaune, scientific name: Melilotus officinalis
# Wall time: 212 ms
# Number of results: 2
# ---- Running query 1057/1706 - fcu_name = mélilot officinal, scientific name: Melilotus officinalis
# Wall time: 192 ms
# Number of results: 2
# ---- Running query 1060/1706 - fcu_name = mélisse officinale, scientific name: Melissa officinalis
# Wall time: 255 ms
# Number of results: 1
# ---- Running query 1064/1706 - fcu_name = melon, scientific name: Cucumis melo
# Wall time: 209 ms
# Number of results: 1
# ---- Running query 1068/1706 - fcu_name = menthe poivrée, scientific name: Mentha x piperita
# Wall time: 261 ms
# Number of results: 1
# ---- Running query 1069/1706 - fcu_name = menthe verte, scientific name: Mentha spicata
# ...
# Wall time: 216 ms
# Number of results: 0
# ---- Running query 1316/1706 - fcu_name = carde, scientific name: Beta vulgaris subsp. vulgaris var. cicla
# Wall time: 256 ms
# Number of results: 0
# ---- Running query 1319/1706 - fcu_name = jotte, scientific name: Beta vulgaris subsp. vulgaris var. cicla
# Wall time: 301 ms
# Number of results: 0
# ---- Running query 1321/1706 - fcu_name = poirée, scientific name: Beta vulgaris subsp. vulgaris var. cicla
# Wall time: 233 ms
# Number of results: 0
# ---- Running query 1330/1706 - fcu_name = poirier, scientific name: Pyrus communis
# Wall time: 262 ms
# Number of results: 2
# ---- Running query 1333/1706 - fcu_name = pois cultivé, scientific name: Pisum sativum
# Wall time: 237 ms
# Number of results: 1
# ---- Running query 1335/1706 - fcu_name = pois chiche, scientific name: Cicer arietinum
# Wall time: 250 ms
# Number of results: 1
# ---- Running query 1337/1706 - fcu_name = pois fourrager, scientific name: Pisum sativum subsp. arvense
# Wall time: 243 ms
# Number of results: 1
# ---- Running query 1343/1706 - fcu_name = pois potager, scientific name: Pisum sativum
# Wall time: 251 ms
# Number of results: 1
# ---- Running query 1356/1706 - fcu_name = poivron, scientific name: Capsicum annuum
# Wall time: 210 ms
# Number of results: 1
# ---- Running query 1361/1706 - fcu_name = pamplemousse, scientific name: Citrus paradisi
# Wall time: 254 ms
# Number of results: 0
# ---- Running query 1362/1706 - fcu_name = pomelo, scientific name: Citrus maxima
# Wall time: 273 ms
# Number of results: 1
# ---- Running query 1363/1706 - fcu_name = pomme de terre, scientific name: Solanum tuberosum
# Wall time: 199 ms
# Number of results: 1
# ---- Running query 1383/1706 - fcu_name = pommier, scientific name: Malus domestica
# Wall time: 276 ms
# Number of results: 1
# ---- Running query 1385/1706 - fcu_name = potiron, scientific name: Cucurbita maxima
# Wall time: 271 ms
# Number of results: 1
# ---- Running query 1386/1706 - fcu_name = porcelane, scientific name: Portulaca oleracea
# Wall time: 204 ms
# Number of results: 2
# ---- Running query 1399/1706 - fcu_name = primevère, scientific name: Primula vulgaris
# Wall time: 276 ms
# Number of results: 1
# ---- Running query 1402/1706 - fcu_name = mirabelle, scientific name: Prunus domestica subsp. syriaca
# Wall time: 259 ms
# Number of results: 2
# ---- Running query 1407/1706 - fcu_name = prunier, scientific name: Prunus domestica
# Wall time: 235 ms
# Number of results: 1
# ---- Running query 1410/1706 - fcu_name = quetschier, scientific name: Prunus domestica
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 1411/1706 - fcu_name = reine-claude, scientific name: Prunus domestica subsp. italica
# Wall time: 236 ms
# Number of results: 1
# ---- Running query 1414/1706 - fcu_name = guinep, scientific name: Melicoccus bijugatus
# Wall time: 246 ms
# Number of results: 1
# ---- Running query 1416/1706 - fcu_name = limoncillo, scientific name: Melissa officinalis
# Wall time: 284 ms
# Number of results: 1
# ---- Running query 1417/1706 - fcu_name = mamoncillo, scientific name: Melicoccus bijugatus
# Wall time: 241 ms
# Number of results: 1
# ---- Running query 1419/1706 - fcu_name = quenettier, scientific name: Melicoccus bijugatus
# Wall time: 253 ms
# Number of results: 1
# ---- Running query 1420/1706 - fcu_name = quinoa, scientific name: Chenopodium quinoa
# Wall time: 250 ms
# Number of results: 1
# ---- Running query 1421/1706 - fcu_name = radis, scientific name: Raphanus sativus
# Wall time: 247 ms
# Number of results: 1
# ---- Running query 1426/1706 - fcu_name = radis d'espagne, scientific name: Raphanus sativus var. niger
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 1427/1706 - fcu_name = radis d'hiver, scientific name: Raphanus sativus var. niger
# Wall time: 246 ms
# Number of results: 1
# ---- Running query 1429/1706 - fcu_name = raifort cultivé, scientific name: Raphanus sativus var. niger
# Wall time: 262 ms
# Number of results: 1
# ---- Running query 1430/1706 - fcu_name = raifort des parisiens, scientific name: Raphanus sativus var. niger
# Wall time: 263 ms
# Number of results: 1
# ---- Running query 1439/1706 - fcu_name = cranson, scientific name: Armoracia rusticana
# Wall time: 236 ms
# Number of results: 1
# ---- Running query 1440/1706 - fcu_name = herbe au scorbut, scientific name: Cochlearia officinalis
# Wall time: 241 ms
# Number of results: 1
# ---- Running query 1441/1706 - fcu_name = herbe aux cuillers, scientific name: Cochlearia officinalis
# Wall time: 241 ms
# Number of results: 1
# ---- Running query 1444/1706 - fcu_name = raifort, scientific name: Armoracia rusticana
# Wall time: 246 ms
# Number of results: 1
# ---- Running query 1445/1706 - fcu_name = raifort sauvage, scientific name: Raphanus raphanistrum
# Wall time: 257 ms
# Number of results: 1
# ---- Running query 1448/1706 - fcu_name = ramboutan, scientific name: Nephelium lappaceum
# Wall time: 248 ms
# Number of results: 1
# ---- Running query 1451/1706 - fcu_name = lolium, scientific name: Lolium
# Wall time: 258 ms
# Number of results: 0
# ---- Running query 1453/1706 - fcu_name = ray-grass, scientific name: Lolium perenne
# Wall time: 240 ms
# Number of results: 1
# ---- Running query 1456/1706 - fcu_name = ivraie vivace, scientific name: Lolium perenne
# Wall time: 234 ms
# Number of results: 1
# ---- Running query 1458/1706 - fcu_name = ray-grass anglais, scientific name: Lolium perenne
# Wall time: 234 ms
# Number of results: 1
# ---- Running query 1465/1706 - fcu_name = ivraie multiflore, scientific name: Lolium multiflorum
# Wall time: 259 ms
# Number of results: 2
# ---- Running query 1468/1706 - fcu_name = ray-grass d'italie, scientific name: Lolium multiflorum
# Wall time: 259 ms
# Number of results: 2
# ---- Running query 1473/1706 - fcu_name = renoncule des fleuristes, scientific name: Ranunculus asiaticus
# Wall time: 229 ms
# Number of results: 1
# ---- Running query 1475/1706 - fcu_name = rhubarbe, scientific name: Rheum rhabarbarum
# Wall time: 268 ms
# Number of results: 0
# ---- Running query 1479/1706 - fcu_name = ricin, scientific name: Ricinus communis
# Wall time: 280 ms
# Number of results: 1
# ---- Running query 1481/1706 - fcu_name = riz, scientific name: Oryza sativa
# Wall time: 234 ms
# Number of results: 1
# ---- Running query 1483/1706 - fcu_name = romarin, scientific name: Salvia rosmarinus
# Wall time: 206 ms
# Number of results: 1
# ---- Running query 1484/1706 - fcu_name = mûre, scientific name: Morus nigra
# Wall time: 297 ms
# Number of results: 1
# ---- Running query 1485/1706 - fcu_name = mûrier des haies, scientific name: Rubus fruticosus
# Wall time: 289 ms
# Number of results: 2
# ---- Running query 1486/1706 - fcu_name = ronce, scientific name: Rubus fruticosus
# Wall time: 242 ms
# Number of results: 2
# ---- Running query 1488/1706 - fcu_name = roquette, scientific name: Eruca vesicaria
# Wall time: 254 ms
# Number of results: 1
# ---- Running query 1490/1706 - fcu_name = églantier, scientific name: Rosa canina
# Wall time: 238 ms
# Number of results: 1
# ---- Running query 1497/1706 - fcu_name = esparcette, scientific name: Onobrychis viciifolia
# Wall time: 221 ms
# Number of results: 1
# ---- Running query 1498/1706 - fcu_name = esparsette, scientific name: Onobrychis viciifolia
# Wall time: 281 ms
# Number of results: 1
# ---- Running query 1500/1706 - fcu_name = sainfoin, scientific name: Onobrychis viciifolia
# Wall time: 292 ms
# Number of results: 1
# ---- Running query 1506/1706 - fcu_name = salade, scientific name: Lactuca sativa
# Wall time: 201 ms
# Number of results: 1
# ---- Running query 1507/1706 - fcu_name = barbe de bouc, scientific name: Tragopogon pratensis
# Wall time: 277 ms
# Number of results: 1
# ---- Running query 1508/1706 - fcu_name = cercifis commun, scientific name: Tragopogon porrifolius
# Wall time: 275 ms
# Number of results: 1
# ---- Running query 1509/1706 - fcu_name = salsifis, scientific name: Tragopogon porrifolius
# Wall time: 229 ms
# Number of results: 1
# ---- Running query 1510/1706 - fcu_name = salsifis austral, scientific name: Tragopogon porrifolius subsp. australis
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 1511/1706 - fcu_name = salsifis blanc, scientific name: Tragopogon porrifolius
# Wall time: 271 ms
# Number of results: 1
# ---- Running query 1512/1706 - fcu_name = salsifis à feuilles de poireau, scientific name: Tragopogon porrifolius
# Wall time: 232 ms
# Number of results: 1
# ---- Running query 1514/1706 - fcu_name = sarriette, scientific name: Satureja montana
# Wall time: 260 ms
# Number of results: 1
# ---- Running query 1516/1706 - fcu_name = blé noir, scientific name: Fagopyrum esculentum
# Wall time: 202 ms
# Number of results: 1
# ---- Running query 1520/1706 - fcu_name = renouée sarrasin, scientific name: Fagopyrum esculentum
# Wall time: 265 ms
# Number of results: 1
# ---- Running query 1521/1706 - fcu_name = sarrasin, scientific name: Fagopyrum esculentum
# Wall time: 297 ms
# Number of results: 1
# ---- Running query 1522/1706 - fcu_name = sauge, scientific name: Salvia dichroantha
# Wall time: 236 ms
# Number of results: 0
# ---- Running query 1523/1706 - fcu_name = sauge officinale, scientific name: Salvia officinalis
# Wall time: 238 ms
# Number of results: 1
# ---- Running query 1524/1706 - fcu_name = sauge sclarée, scientific name: Salvia sclarea
# Wall time: 205 ms
# Number of results: 1
# ---- Running query 1531/1706 - fcu_name = scorsonère, scientific name: Scorzonera hispanica
# Wall time: 286 ms
# Number of results: 1
# ---- Running query 1532/1706 - fcu_name = scorsonère d'espagne, scientific name: Scorzonera hispanica
# Wall time: 290 ms
# Number of results: 1
# ---- Running query 1534/1706 - fcu_name = seigle, scientific name: Secale cereale
# Wall time: 232 ms
# Number of results: 1
# ---- Running query 1541/1706 - fcu_name = ornithope cultivé, scientific name: Ornithopus sativus
# Wall time: 275 ms
# Number of results: 1
# ---- Running query 1543/1706 - fcu_name = serradelle, scientific name: Ornithopus sativus
# Wall time: 284 ms
# Number of results: 1
# ---- Running query 1547/1706 - fcu_name = sésame, scientific name: Sesamum indicum
# Wall time: 226 ms
# Number of results: 1
# ---- Running query 1549/1706 - fcu_name = soja, scientific name: Glycine max
# Wall time: 302 ms
# Number of results: 1
# ---- Running query 1562/1706 - fcu_name = soya, scientific name: Glycine max
# Wall time: 251 ms
# Number of results: 1
# ---- Running query 1567/1706 - fcu_name = haricot mungo, scientific name: Vigna radiata
# Wall time: 235 ms
# Number of results: 1
# ---- Running query 1571/1706 - fcu_name = sorgho, scientific name: Sorghum bicolor
# Wall time: 246 ms
# Number of results: 1
# ---- Running query 1575/1706 - fcu_name = sorgho, scientific name: Sorghum bicolor
# Wall time: 172 ms
# Number of results: 1
# ---- Running query 1579/1706 - fcu_name = lande, scientific name: Ulex europaeus
# Wall time: 224 ms
# Number of results: 1
# ---- Running query 1584/1706 - fcu_name = bois, scientific name: Buxus sempervirens
# Wall time: 280 ms
# Number of results: 1
# ---- Running query 1588/1706 - fcu_name = grand tabac, scientific name: Nicotiana tabacum
# Wall time: 247 ms
# Number of results: 1
# ---- Running query 1589/1706 - fcu_name = herbe à nicot, scientific name: Nicotiana tabacum
# Wall time: 222 ms
# Number of results: 1
# ---- Running query 1590/1706 - fcu_name = tabac, scientific name: Nicotiana tabacum
# Wall time: 284 ms
# Number of results: 1
# ---- Running query 1594/1706 - fcu_name = tangor, scientific name: Citrus x nobilis
# Wall time: 256 ms
# Number of results: 0
# ---- Running query 1599/1706 - fcu_name = farigoule, scientific name: Thymus vulgaris
# Wall time: 242 ms
# Number of results: 1
# ---- Running query 1600/1706 - fcu_name = thym, scientific name: Thymus vulgaris
# Wall time: 243 ms
# Number of results: 1
# ---- Running query 1602/1706 - fcu_name = tomate, scientific name: Solanum lycopersicum
# Wall time: 263 ms
# Number of results: 1
# ---- Running query 1605/1706 - fcu_name = artichaut de jérusalem, scientific name: Helianthus tuberosus
# Wall time: 285 ms
# Number of results: 1
# ---- Running query 1607/1706 - fcu_name = topinambour, scientific name: Helianthus tuberosus
# Wall time: 236 ms
# Number of results: 1
# ---- Running query 1615/1706 - fcu_name = héliotrope, scientific name: Heliotropium europaeum
# Wall time: 276 ms
# Number of results: 1
# ---- Running query 1616/1706 - fcu_name = maurelle, scientific name: Chrozophora tinctoria
# Wall time: 203 ms
# Number of results: 1
# ---- Running query 1620/1706 - fcu_name = tournesol, scientific name: Chrozophora tinctoria
# Wall time: 283 ms
# Number of results: 1
# ---- Running query 1625/1706 - fcu_name = trèfle d'alexandrie, scientific name: Trifolium alexandrinum
# Wall time: 272 ms
# Number of results: 1
# ---- Running query 1626/1706 - fcu_name = trèfle de perse, scientific name: Trifolium resupinatum
# Wall time: 231 ms
# Number of results: 3
# ---- Running query 1628/1706 - fcu_name = petit trèfle, scientific name: Desmodium heterophyllum
# Wall time: 304 ms
# Number of results: 1
# ---- Running query 1629/1706 - fcu_name = trèfle blanc, scientific name: Trifolium repens
# Wall time: 285 ms
# Number of results: 1
# ---- Running query 1631/1706 - fcu_name = trèfle rampant, scientific name: Trifolium repens
# Wall time: 248 ms
# Number of results: 1
# ---- Running query 1632/1706 - fcu_name = trèfle hybride, scientific name: Trifolium hybridum
# Wall time: 253 ms
# Number of results: 2
# ---- Running query 1635/1706 - fcu_name = trèfle incarnat, scientific name: Trifolium incarnatum
# Wall time: 225 ms
# Number of results: 1
# ---- Running query 1636/1706 - fcu_name = trèfle de micheli, scientific name: Trifolium michelianum
# Wall time: 244 ms
# Number of results: 2
# ---- Running query 1637/1706 - fcu_name = trèfle de perse, scientific name: Trifolium resupinatum
# Wall time: 210 ms
# Number of results: 3
# ---- Running query 1638/1706 - fcu_name = trèfle des prés, scientific name: Trifolium pratense
# Wall time: 252 ms
# Number of results: 1
# ---- Running query 1639/1706 - fcu_name = trèfle violet, scientific name: Trifolium pratense
# Wall time: 277 ms
# Number of results: 1
# ---- Running query 1640/1706 - fcu_name = triticale, scientific name: Triticosecale rimpaui
# Wall time: 247 ms
# Number of results: 0
# ---- Running query 1648/1706 - fcu_name = valériane officinale, scientific name: Valeriana officinalis
# Wall time: 231 ms
# Number of results: 1
# ---- Running query 1649/1706 - fcu_name = vanille, scientific name: Vanilla planifolia
# Wall time: 199 ms
# Number of results: 2
# ---- Running query 1651/1706 - fcu_name = vanillier, scientific name: Vanilla planifolia
# Wall time: 269 ms
# Number of results: 2
# ---- Running query 1653/1706 - fcu_name = véronique officinale, scientific name: Veronica officinalis
# Wall time: 239 ms
# Number of results: 1
# ---- Running query 1654/1706 - fcu_name = verveine, scientific name: Verbena officinalis
# Wall time: 277 ms
# Number of results: 1
# ---- Running query 1656/1706 - fcu_name = vesce commune, scientific name: Vicia sativa
# Wall time: 240 ms
# Number of results: 1
# ---- Running query 1657/1706 - fcu_name = vesce cultivée, scientific name: Vicia sativa
# Wall time: 237 ms
# Number of results: 1
# ---- Running query 1659/1706 - fcu_name = vesce de cerdagne, scientific name: Vicia villosa subsp. varia
# Wall time: 250 ms
# Number of results: 1
# ---- Running query 1660/1706 - fcu_name = vesce de hongrie, scientific name: Vicia pannonica
# Wall time: 188 ms
# Number of results: 1
# ---- Running query 1661/1706 - fcu_name = vesce de pannonie, scientific name: Vicia pannonica
# Wall time: 256 ms
# Number of results: 1
# ---- Running query 1664/1706 - fcu_name = vesce fourragère, scientific name: Vicia sativa
# Wall time: 262 ms
# Number of results: 1
# ---- Running query 1668/1706 - fcu_name = vétiver, scientific name: Chrysopogon zizanioides
# Wall time: 248 ms
# Number of results: 1
# ---- Running query 1672/1706 - fcu_name = vigne vierge, scientific name: Parthenocissus quinquefolia
# Wall time: 245 ms
# Number of results: 2
# ---- Running query 1674/1706 - fcu_name = vigne cultivée, scientific name: Vitis vinifera
# Wall time: 276 ms
# Number of results: 1
# ---- Running query 1690/1706 - fcu_name = violette odorante, scientific name: Viola odorata
# Wall time: 212 ms
# Number of results: 1
# ---- Running query 1695/1706 - fcu_name = ylang-ylang, scientific name: Cananga odorata
# Wall time: 314 ms
# Number of results: 1

# %% [markdown]
# ### Result:
#
# - taxref_full_name: the full scientific name with authority and date, that matches the EPPO (short) scientific name
# - taxref_name_type: wether this full scientific name is a reference name (pref) or synonym (alt) of a taxon in TAXREF-LD
# - taxref_ref_full_name: if the full scientific name is an synonym (alt) name, this column gives the reference name that is the taxon name.

# %%
dataframe_preview(df_fcu_taxref)
# Out:
# == Number of lines: 656
# == Number of unique values:
# fcu_name                553
# eppo_code               355
# scientific_name         355
# taxref_name_type          2
# taxref_full_name        366
# taxref_ref_full_name    336
# taxon                   336
# rank                      4
# dtype: int64
#                   fcu_name eppo_code      scientific_name taxref_name_type  \
# 0               abricotier     PRNAR     Prunus armeniaca             pref
# 1               abricotier     PRNAR     Prunus armeniaca              alt
# 2  abricotier des antilles     MAFAM     Mammea americana             pref
# 3                    mamey     POJSA      Pouteria sapota             pref
# 4                actinidia     ATICH  Actinidia chinensis             pref
# 5                actinidia     ATICH  Actinidia chinensis              alt
# 6                     kiwi     ATICH  Actinidia chinensis             pref
# 7                     kiwi     ATICH  Actinidia chinensis              alt
# 8                      ail     ALLSA       Allium sativum             pref
# 9               ail commun     ALLSA       Allium sativum             pref
#
#                                    taxref_full_name  \
# 0                         Prunus armeniaca L., 1753
# 1                   Prunus armeniaca Chevall., 1827
# 2                         Mammea americana L., 1753
# 3  Pouteria sapota (Jacq.) H.E.Moore & Stearn, 1967
# 4                 Actinidia chinensis Planch., 1847
# 5       Actinidia chinensis auct. non Planch., 1847
# 6                 Actinidia chinensis Planch., 1847
# 7       Actinidia chinensis auct. non Planch., 1847
# 8                           Allium sativum L., 1753
# 9                           Allium sativum L., 1753
#
#                                 taxref_ref_full_name  \
# 0                          Prunus armeniaca L., 1753
# 1  Prunus domestica var. insititia (L.) Fiori & P...
# 2                          Mammea americana L., 1753
# 3   Pouteria sapota (Jacq.) H.E.Moore & Stearn, 1967
# 4                  Actinidia chinensis Planch., 1847
# 5  Actinidia deliciosa (A.Chev.) C.F.Liang & A.R....
# 6                  Actinidia chinensis Planch., 1847
# 7  Actinidia deliciosa (A.Chev.) C.F.Liang & A.R....
# 8                            Allium sativum L., 1753
# 9                            Allium sativum L., 1753
#
#                                     taxon  \
# 0  http://taxref.mnhn.fr/lod/taxon/116041
# 1  http://taxref.mnhn.fr/lod/taxon/965160
# 2  http://taxref.mnhn.fr/lod/taxon/447085
# 3  http://taxref.mnhn.fr/lod/taxon/630482
# 4   http://taxref.mnhn.fr/lod/taxon/80138
# 5   http://taxref.mnhn.fr/lod/taxon/80140
# 6   http://taxref.mnhn.fr/lod/taxon/80138
# 7   http://taxref.mnhn.fr/lod/taxon/80140
# 8   http://taxref.mnhn.fr/lod/taxon/81505
# 9   http://taxref.mnhn.fr/lod/taxon/81505
#
#                                          rank
# 0   http://taxref.mnhn.fr/lod/taxrank/Species
# 1  http://taxref.mnhn.fr/lod/taxrank/Varietas
# 2   http://taxref.mnhn.fr/lod/taxrank/Species
# 3   http://taxref.mnhn.fr/lod/taxrank/Species
# 4   http://taxref.mnhn.fr/lod/taxrank/Species
# 5   http://taxref.mnhn.fr/lod/taxrank/Species
# 6   http://taxref.mnhn.fr/lod/taxrank/Species
# 7   http://taxref.mnhn.fr/lod/taxrank/Species
# 8   http://taxref.mnhn.fr/lod/taxrank/Species
# 9   http://taxref.mnhn.fr/lod/taxrank/Species

# %%
df_fcu_taxref.to_excel("result2_eppo_taxref.xlsx")

# %% [markdown]
# ### Count only matches

# %%
dataframe_preview(df_fcu_taxref.dropna())
# Out:
# == Number of lines: 617
# == Number of unique values:
# fcu_name                517
# eppo_code               326
# scientific_name         326
# taxref_name_type          2
# taxref_full_name        366
# taxref_ref_full_name    336
# taxon                   336
# rank                      4
# dtype: int64
#                   fcu_name eppo_code      scientific_name taxref_name_type  \
# 0               abricotier     PRNAR     Prunus armeniaca             pref
# 1               abricotier     PRNAR     Prunus armeniaca              alt
# 2  abricotier des antilles     MAFAM     Mammea americana             pref
# 3                    mamey     POJSA      Pouteria sapota             pref
# 4                actinidia     ATICH  Actinidia chinensis             pref
# 5                actinidia     ATICH  Actinidia chinensis              alt
# 6                     kiwi     ATICH  Actinidia chinensis             pref
# 7                     kiwi     ATICH  Actinidia chinensis              alt
# 8                      ail     ALLSA       Allium sativum             pref
# 9               ail commun     ALLSA       Allium sativum             pref
#
#                                    taxref_full_name  \
# 0                         Prunus armeniaca L., 1753
# 1                   Prunus armeniaca Chevall., 1827
# 2                         Mammea americana L., 1753
# 3  Pouteria sapota (Jacq.) H.E.Moore & Stearn, 1967
# 4                 Actinidia chinensis Planch., 1847
# 5       Actinidia chinensis auct. non Planch., 1847
# 6                 Actinidia chinensis Planch., 1847
# 7       Actinidia chinensis auct. non Planch., 1847
# 8                           Allium sativum L., 1753
# 9                           Allium sativum L., 1753
#
#                                 taxref_ref_full_name  \
# 0                          Prunus armeniaca L., 1753
# 1  Prunus domestica var. insititia (L.) Fiori & P...
# 2                          Mammea americana L., 1753
# 3   Pouteria sapota (Jacq.) H.E.Moore & Stearn, 1967
# 4                  Actinidia chinensis Planch., 1847
# 5  Actinidia deliciosa (A.Chev.) C.F.Liang & A.R....
# 6                  Actinidia chinensis Planch., 1847
# 7  Actinidia deliciosa (A.Chev.) C.F.Liang & A.R....
# 8                            Allium sativum L., 1753
# 9                            Allium sativum L., 1753
#
#                                     taxon  \
# 0  http://taxref.mnhn.fr/lod/taxon/116041
# 1  http://taxref.mnhn.fr/lod/taxon/965160
# 2  http://taxref.mnhn.fr/lod/taxon/447085
# 3  http://taxref.mnhn.fr/lod/taxon/630482
# 4   http://taxref.mnhn.fr/lod/taxon/80138
# 5   http://taxref.mnhn.fr/lod/taxon/80140
# 6   http://taxref.mnhn.fr/lod/taxon/80138
# 7   http://taxref.mnhn.fr/lod/taxon/80140
# 8   http://taxref.mnhn.fr/lod/taxon/81505
# 9   http://taxref.mnhn.fr/lod/taxon/81505
#
#                                          rank
# 0   http://taxref.mnhn.fr/lod/taxrank/Species
# 1  http://taxref.mnhn.fr/lod/taxrank/Varietas
# 2   http://taxref.mnhn.fr/lod/taxrank/Species
# 3   http://taxref.mnhn.fr/lod/taxrank/Species
# 4   http://taxref.mnhn.fr/lod/taxrank/Species
# 5   http://taxref.mnhn.fr/lod/taxrank/Species
# 6   http://taxref.mnhn.fr/lod/taxrank/Species
# 7   http://taxref.mnhn.fr/lod/taxrank/Species
# 8   http://taxref.mnhn.fr/lod/taxrank/Species
# 9   http://taxref.mnhn.fr/lod/taxrank/Species

# %% [markdown]
# ---
# # Merge of FCU names list and TAXREF-LD names

# %%
df_merge = pd.merge(df_fcu, df_fcu_taxref, on="scientific_name", how='left')
df_merge.drop(columns=['fcu_name_y', 'eppo_code_y'], inplace=True)
df_merge.rename(columns={"fcu_name_x": "fcu_name", "eppo_code_x": "eppo_code"}, inplace=True)
df_merge.drop_duplicates(inplace=True)

# %%
dataframe_preview(df_merge)
# Out:
# == Number of lines: 1782
# == Number of unique values:
# fcu_concept              524
# fcu_name                1656
# fcu_name_type              2
# eppo_code                355
# scientific_name          355
# taxref_name_type           2
# taxref_full_name         366
# taxref_ref_full_name     336
# taxon                    336
# rank                       4
# dtype: int64
#                                          fcu_concept                 fcu_name  \
# 0  http://ontology.inrae.fr/frenchcropusage/Abric...                  abricot
# 1  http://ontology.inrae.fr/frenchcropusage/Abric...               abricotier
# 2  http://ontology.inrae.fr/frenchcropusage/Abric...               abricotier
# 3  http://ontology.inrae.fr/frenchcropusage/Abric...             abricot pays
# 4  http://ontology.inrae.fr/frenchcropusage/Abric...  abricotier des antilles
# 5  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier pays
# 6  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier-pays
# 7  http://ontology.inrae.fr/frenchcropusage/Abric...                    mamey
# 8  http://ontology.inrae.fr/frenchcropusage/Actin...                actinidia
# 9  http://ontology.inrae.fr/frenchcropusage/Actin...                actinidia
#
#   fcu_name_type eppo_code      scientific_name taxref_name_type  \
# 0           alt      None                 None              NaN
# 1          pref     PRNAR     Prunus armeniaca             pref
# 2          pref     PRNAR     Prunus armeniaca              alt
# 3           alt      None                 None              NaN
# 4           alt     MAFAM     Mammea americana             pref
# 5          pref      None                 None              NaN
# 6           alt      None                 None              NaN
# 7           alt     POJSA      Pouteria sapota             pref
# 8          pref     ATICH  Actinidia chinensis             pref
# 9          pref     ATICH  Actinidia chinensis              alt
#
#                                    taxref_full_name  \
# 0                                               NaN
# 1                         Prunus armeniaca L., 1753
# 2                   Prunus armeniaca Chevall., 1827
# 3                                               NaN
# 4                         Mammea americana L., 1753
# 5                                               NaN
# 6                                               NaN
# 7  Pouteria sapota (Jacq.) H.E.Moore & Stearn, 1967
# 8                 Actinidia chinensis Planch., 1847
# 9       Actinidia chinensis auct. non Planch., 1847
#
#                                 taxref_ref_full_name  \
# 0                                                NaN
# 1                          Prunus armeniaca L., 1753
# 2  Prunus domestica var. insititia (L.) Fiori & P...
# 3                                                NaN
# 4                          Mammea americana L., 1753
# 5                                                NaN
# 6                                                NaN
# 7   Pouteria sapota (Jacq.) H.E.Moore & Stearn, 1967
# 8                  Actinidia chinensis Planch., 1847
# 9  Actinidia deliciosa (A.Chev.) C.F.Liang & A.R....
#
#                                     taxon  \
# 0                                     NaN
# 1  http://taxref.mnhn.fr/lod/taxon/116041
# 2  http://taxref.mnhn.fr/lod/taxon/965160
# 3                                     NaN
# 4  http://taxref.mnhn.fr/lod/taxon/447085
# 5                                     NaN
# 6                                     NaN
# 7  http://taxref.mnhn.fr/lod/taxon/630482
# 8   http://taxref.mnhn.fr/lod/taxon/80138
# 9   http://taxref.mnhn.fr/lod/taxon/80140
#
#                                          rank
# 0                                         NaN
# 1   http://taxref.mnhn.fr/lod/taxrank/Species
# 2  http://taxref.mnhn.fr/lod/taxrank/Varietas
# 3                                         NaN
# 4   http://taxref.mnhn.fr/lod/taxrank/Species
# 5                                         NaN
# 6                                         NaN
# 7   http://taxref.mnhn.fr/lod/taxrank/Species
# 8   http://taxref.mnhn.fr/lod/taxrank/Species
# 9   http://taxref.mnhn.fr/lod/taxrank/Species

# %% [markdown]
# #### Count only matches

# %%
dataframe_preview(df_merge.dropna())
# Out:
# == Number of lines: 617
# == Number of unique values:
# fcu_concept             300
# fcu_name                517
# fcu_name_type             2
# eppo_code               326
# scientific_name         326
# taxref_name_type          2
# taxref_full_name        366
# taxref_ref_full_name    336
# taxon                   336
# rank                      4
# dtype: int64
#                                           fcu_concept  \
# 1   http://ontology.inrae.fr/frenchcropusage/Abric...
# 2   http://ontology.inrae.fr/frenchcropusage/Abric...
# 4   http://ontology.inrae.fr/frenchcropusage/Abric...
# 7   http://ontology.inrae.fr/frenchcropusage/Abric...
# 8   http://ontology.inrae.fr/frenchcropusage/Actin...
# 9   http://ontology.inrae.fr/frenchcropusage/Actin...
# 14  http://ontology.inrae.fr/frenchcropusage/Actin...
# 15  http://ontology.inrae.fr/frenchcropusage/Actin...
# 20      http://ontology.inrae.fr/frenchcropusage/Ails
# 23      http://ontology.inrae.fr/frenchcropusage/Ails
#
#                    fcu_name fcu_name_type eppo_code      scientific_name  \
# 1                abricotier          pref     PRNAR     Prunus armeniaca
# 2                abricotier          pref     PRNAR     Prunus armeniaca
# 4   abricotier des antilles           alt     MAFAM     Mammea americana
# 7                     mamey           alt     POJSA      Pouteria sapota
# 8                 actinidia          pref     ATICH  Actinidia chinensis
# 9                 actinidia          pref     ATICH  Actinidia chinensis
# 14                     kiwi           alt     ATICH  Actinidia chinensis
# 15                     kiwi           alt     ATICH  Actinidia chinensis
# 20                      ail          pref     ALLSA       Allium sativum
# 23               ail commun           alt     ALLSA       Allium sativum
#
#    taxref_name_type                                  taxref_full_name  \
# 1              pref                         Prunus armeniaca L., 1753
# 2               alt                   Prunus armeniaca Chevall., 1827
# 4              pref                         Mammea americana L., 1753
# 7              pref  Pouteria sapota (Jacq.) H.E.Moore & Stearn, 1967
# 8              pref                 Actinidia chinensis Planch., 1847
# 9               alt       Actinidia chinensis auct. non Planch., 1847
# 14             pref                 Actinidia chinensis Planch., 1847
# 15              alt       Actinidia chinensis auct. non Planch., 1847
# 20             pref                           Allium sativum L., 1753
# 23             pref                           Allium sativum L., 1753
#
#                                  taxref_ref_full_name  \
# 1                           Prunus armeniaca L., 1753
# 2   Prunus domestica var. insititia (L.) Fiori & P...
# 4                           Mammea americana L., 1753
# 7    Pouteria sapota (Jacq.) H.E.Moore & Stearn, 1967
# 8                   Actinidia chinensis Planch., 1847
# 9   Actinidia deliciosa (A.Chev.) C.F.Liang & A.R....
# 14                  Actinidia chinensis Planch., 1847
# 15  Actinidia deliciosa (A.Chev.) C.F.Liang & A.R....
# 20                            Allium sativum L., 1753
# 23                            Allium sativum L., 1753
#
#                                      taxon  \
# 1   http://taxref.mnhn.fr/lod/taxon/116041
# 2   http://taxref.mnhn.fr/lod/taxon/965160
# 4   http://taxref.mnhn.fr/lod/taxon/447085
# 7   http://taxref.mnhn.fr/lod/taxon/630482
# 8    http://taxref.mnhn.fr/lod/taxon/80138
# 9    http://taxref.mnhn.fr/lod/taxon/80140
# 14   http://taxref.mnhn.fr/lod/taxon/80138
# 15   http://taxref.mnhn.fr/lod/taxon/80140
# 20   http://taxref.mnhn.fr/lod/taxon/81505
# 23   http://taxref.mnhn.fr/lod/taxon/81505
#
#                                           rank
# 1    http://taxref.mnhn.fr/lod/taxrank/Species
# 2   http://taxref.mnhn.fr/lod/taxrank/Varietas
# 4    http://taxref.mnhn.fr/lod/taxrank/Species
# 7    http://taxref.mnhn.fr/lod/taxrank/Species
# 8    http://taxref.mnhn.fr/lod/taxrank/Species
# 9    http://taxref.mnhn.fr/lod/taxrank/Species
# 14   http://taxref.mnhn.fr/lod/taxrank/Species
# 15   http://taxref.mnhn.fr/lod/taxrank/Species
# 20   http://taxref.mnhn.fr/lod/taxrank/Species
# 23   http://taxref.mnhn.fr/lod/taxrank/Species

# %% [markdown]
# ### Matches:
# - FCU: 300 unique concepts, 517 unique labels
# - EPPO: 326 unique codes and scientific names
# - TAXREF-LD: 336 unique taxa from 4 ranks

# %% [markdown]
# ### Exports

# %%
df_merge.to_excel("result3_fcu_eppo_taxref.xlsx")

# %%
# Reshape the DataFrame for later merging with other methods
df_merge.dropna(inplace=True)
df_merge.drop(columns=['fcu_name_type', 'fcu_name', 'eppo_code', 'taxref_name_type', 'taxref_full_name'], inplace=True)
df_merge.insert(1, 'method', 'eppo')
df_merge.insert(2, 'geves_name', '')
df_merge.rename(columns={'scientific_name': 'eppo_scientific_name'}, inplace=True)

# %%
dataframe_preview(df_merge)
df_merge.to_excel("result3_fcu_eppo_taxref_merge.xlsx", index=False)
df_merge.to_csv("result3_fcu_eppo_taxref_merge.csv", index=False)
# Out:
# == Number of lines: 617
# == Number of unique values:
# fcu_concept             300
# method                    1
# geves_name                1
# eppo_scientific_name    326
# taxref_ref_full_name    336
# taxon                   336
# rank                      4
# dtype: int64
#                                           fcu_concept method geves_name  \
# 1   http://ontology.inrae.fr/frenchcropusage/Abric...   eppo
# 2   http://ontology.inrae.fr/frenchcropusage/Abric...   eppo
# 4   http://ontology.inrae.fr/frenchcropusage/Abric...   eppo
# 7   http://ontology.inrae.fr/frenchcropusage/Abric...   eppo
# 8   http://ontology.inrae.fr/frenchcropusage/Actin...   eppo
# 9   http://ontology.inrae.fr/frenchcropusage/Actin...   eppo
# 14  http://ontology.inrae.fr/frenchcropusage/Actin...   eppo
# 15  http://ontology.inrae.fr/frenchcropusage/Actin...   eppo
# 20      http://ontology.inrae.fr/frenchcropusage/Ails   eppo
# 23      http://ontology.inrae.fr/frenchcropusage/Ails   eppo
#
#    eppo_scientific_name                               taxref_ref_full_name  \
# 1      Prunus armeniaca                          Prunus armeniaca L., 1753
# 2      Prunus armeniaca  Prunus domestica var. insititia (L.) Fiori & P...
# 4      Mammea americana                          Mammea americana L., 1753
# 7       Pouteria sapota   Pouteria sapota (Jacq.) H.E.Moore & Stearn, 1967
# 8   Actinidia chinensis                  Actinidia chinensis Planch., 1847
# 9   Actinidia chinensis  Actinidia deliciosa (A.Chev.) C.F.Liang & A.R....
# 14  Actinidia chinensis                  Actinidia chinensis Planch., 1847
# 15  Actinidia chinensis  Actinidia deliciosa (A.Chev.) C.F.Liang & A.R....
# 20       Allium sativum                            Allium sativum L., 1753
# 23       Allium sativum                            Allium sativum L., 1753
#
#                                      taxon  \
# 1   http://taxref.mnhn.fr/lod/taxon/116041
# 2   http://taxref.mnhn.fr/lod/taxon/965160
# 4   http://taxref.mnhn.fr/lod/taxon/447085
# 7   http://taxref.mnhn.fr/lod/taxon/630482
# 8    http://taxref.mnhn.fr/lod/taxon/80138
# 9    http://taxref.mnhn.fr/lod/taxon/80140
# 14   http://taxref.mnhn.fr/lod/taxon/80138
# 15   http://taxref.mnhn.fr/lod/taxon/80140
# 20   http://taxref.mnhn.fr/lod/taxon/81505
# 23   http://taxref.mnhn.fr/lod/taxon/81505
#
#                                           rank
# 1    http://taxref.mnhn.fr/lod/taxrank/Species
# 2   http://taxref.mnhn.fr/lod/taxrank/Varietas
# 4    http://taxref.mnhn.fr/lod/taxrank/Species
# 7    http://taxref.mnhn.fr/lod/taxrank/Species
# 8    http://taxref.mnhn.fr/lod/taxrank/Species
# 9    http://taxref.mnhn.fr/lod/taxrank/Species
# 14   http://taxref.mnhn.fr/lod/taxrank/Species
# 15   http://taxref.mnhn.fr/lod/taxrank/Species
# 20   http://taxref.mnhn.fr/lod/taxrank/Species
# 23   http://taxref.mnhn.fr/lod/taxrank/Species
