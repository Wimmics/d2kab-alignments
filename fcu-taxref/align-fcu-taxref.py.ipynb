# %% [markdown]
# # Direct join between French Crop Usage (FCU) and TAXREF-LD
#
# Join condition: FCU crop name = TAXREF-LD vernacular name

# %% [markdown]
# ### Initializations

# %%
import json
import os
from string import Template
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON, POST
from time import sleep
from math import isnan, nan

# %%
# Initializations
prefixes = '''
prefix fcu:            <http://ontology.inrae.fr/frenchcropusage/>
prefix owl:            <http://www.w3.org/2002/07/owl#>
prefix rdf:            <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
prefix rdfs:           <http://www.w3.org/2000/01/rdf-schema#>
prefix skos:           <http://www.w3.org/2004/02/skos/core#>
prefix skosxl:         <http://www.w3.org/2008/05/skos-xl#>
prefix taxrefp:        <http://taxref.mnhn.fr/lod/property/>
prefix taxrefrk:       <http://taxref.mnhn.fr/lod/taxrank/>
prefix xsd:            <http://www.w3.org/2001/XMLSchema#>
'''

# %%
fcu_endpoint = "http://ontology.inrae.fr/frenchcropusage/sparql"
#fcu_endpoint = "http://localhost:8080/sparql"
taxref_endpoint = "https://taxref.mnhn.fr/sparql"

# %%
def exec_sparql(endpoint, query):
    """
    Execute a SPARQL query and return results as a Pandas DataFrame.
    Invocation uses the HTTP POST method. Requested result format is JSON.

    In case of failure, the function retries up to MAX_ATTEMPTS attempts while waiting increasing time between each attempt.
    An empty DataFrame is returned in case no attempt is successful.
    """
    # Max number of time a SPARQL query can fail before giving up
    MAX_ATTEMPTS = 3

    sparql = SPARQLWrapper(endpoint)
    sparql.setMethod(POST)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(query)
    
    attempt = 1;
    success = False
    while not success and attempt <= MAX_ATTEMPTS:
        try:
            raw_results = sparql.query()
            results = raw_results.convert()
        except:
            print(f'Error while executing SPARQL query (attempt {attempt}/{MAX_ATTEMPTS}).', end=' ')
            if attempt < MAX_ATTEMPTS:
                # Wait a few seconds before next attempt (5, 10, 15, ...)
                print(f'Will retry in {attempt * 5}s.')
                sleep(attempt * 5)
        else:
            success = True
        finally:
            attempt = attempt + 1

    if success:
        if 'head' in results and 'results' in results:
            cols = results['head']['vars']
            out = []
            for row in results['results']['bindings']:
                item = []
                for c in cols:
                    item.append(row.get(c, {}).get('value'))
                out.append(item)
            return pd.DataFrame(out, columns=cols)
        else:
            print('Invalid SPARQL result. Will return empty DataFrame.\n' + str(results))
    else:
        print(f'Unable to execute SPARQL query after {MAX_ATTEMPTS} attempts. Will return empty DataFarme.')
                  
    return pd.DataFrame()            


def dataframe_preview(df, start=0, end=10):
    print("== Number of lines: " + str(df.shape[0]))
    print("== Number of unique values:")
    print(df.nunique())
    display(df[start:end])

# %% [markdown]
# ___
# # Get all varieties from FCU
# FCU labels = vernacular names

# %%
query =  prefixes + '''
select distinct ?fcu_concept ?fcu_name ?fcu_name_type where {

    # Select only cultivated crops
    <http://ontology.inrae.fr/frenchcropusage/Usages_plantes_cultivees> skos:narrower+ ?fcu_concept.

    # Keep only leaves or their direct parent but not above
    FILTER (NOT EXISTS { ?fcu_concept skos:narrower/skos:narrower ?child. })

    # Get prefered and alternate labels and keep track of the type of label
    # ?fcu_concept a skos:Concept.
    { ?fcu_concept skos:prefLabel ?lb. bind("pref" as ?fcu_name_type) }
    UNION
    { ?fcu_concept skos:altLabel  ?lb. bind("alt" as ?fcu_name_type) }

    bind(str(lcase(?lb)) as ?fcu_name)

} order by ?fcu_concept
'''

# %%
# %time df_fcu = exec_sparql(fcu_endpoint, query)
# Out:
# Wall time: 129 ms

# %%
dataframe_preview(df_fcu, end=5)
# Out:
# == Number of lines: 1515
# == Number of unique values:
# fcu_concept       446
# fcu_name         1481
# fcu_name_type       2
# dtype: int64
#                                          fcu_concept                 fcu_name  \
# 0  http://ontology.inrae.fr/frenchcropusage/Abric...               abricotier
# 1  http://ontology.inrae.fr/frenchcropusage/Abric...                  abricot
# 2  http://ontology.inrae.fr/frenchcropusage/Abric...          abricotier pays
# 3  http://ontology.inrae.fr/frenchcropusage/Abric...             abricot pays
# 4  http://ontology.inrae.fr/frenchcropusage/Abric...  abricotier des antilles
#
#   fcu_name_type
# 0          pref
# 1           alt
# 2          pref
# 3           alt
# 4           alt

# %% [markdown]
# ---
# # Join FCU with TAXREF-LD
# ### FCU varieties names = TAXREF-LD vernacular names
#
# The SPARQL endpoint of TAXREF-LD does not support passing all varietes at once in a VALUES clause (ends up with an "HTTP Error 502: Proxy Error").
# To avoid this, we make a SPARQL query for each FCU variety. It takes more time but it completes.

# %%
queryTpl = Template(prefixes + '''
select distinct ("$fcu_concept" as ?fcu_concept) ("$fcu_name" as ?fcu_name) ("$fcu_name_type" as ?fcu_name_type) ?taxref_full_name ?taxon ?rank
from <http://taxref.mnhn.fr/lod/graph/classes/15.0>
from <http://taxref.mnhn.fr/lod/graph/vernacular/15.0>
from <http://taxref.mnhn.fr/lod/graph/concepts>
where {
    # ?taxon
       a                      owl:Class;
       taxrefp:hasReferenceName [ rdfs:label ?taxref_full_name ];
       taxrefp:hasRank        ?rank;
       taxrefp:vernacularName ?vn.

    # To lowercase + remove language tag if any
    filter (str(lcase(?vn)) = "$fcu_name")
    
    # All ranks up to spcecies but not above
    filter (?rank in (
        taxrefrk:Species,  taxrefrk:SemiSpecies, taxrefrk:MicroSpecies, taxrefrk:SubSpecies, taxrefrk:Natio, 
        taxrefrk:Varietas, taxrefrk:SubVarietas, taxrefrk:Forma,        taxrefrk:SubForma,   taxrefrk:FormaSpecies,
        taxrefrk:Linea,    taxrefrk:Clone,       taxrefrk:Race,         taxrefrk:Cultivar,   taxrefrk:Morpha,
        taxrefrk:Abberatio ))
}
''')

# %%
# Set a max number of queries to submit. 0 = unlimited.
MAX_QUERIES = 0

# Result DataFrame
df_fcu_taxref = pd.DataFrame()

for idx, row in df_fcu.iterrows():
    query = queryTpl.substitute(
        fcu_concept = row['fcu_concept'].strip(), 
        fcu_name = row['fcu_name'].strip().lower(),
        fcu_name_type = row['fcu_name_type'].strip().lower())
    #print(query)
    
    print(f"---- Running query {idx + 1}/{len(df_fcu)} - name = {row['fcu_name']}")
    # %time _df = exec_sparql(taxref_endpoint, query)
    print(f'Number of results: {_df.shape[0]}')
    df_fcu_taxref = df_fcu_taxref.append(_df)
    
    # Keep track of the names not matched with TAXREF
    if _df.shape[0] == 0:
        nomatch_row = {'fcu_concept': row['fcu_concept'].strip(), 'fcu_name': row['fcu_name'].strip().lower(), 'fcu_name_type': row['fcu_name_type'].strip().lower(), 'taxref_full_name': None, 'taxon': None, 'rank': None}
        df_fcu_taxref = df_fcu_taxref.append(nomatch_row, ignore_index=True)

    if MAX_QUERIES > 0 and (idx+1) >= MAX_QUERIES:
        break
# Out:
# ---- Running query 1/1515 - name = abricotier
# Wall time: 817 ms
# Number of results: 0
# ---- Running query 2/1515 - name = abricot
# Wall time: 799 ms
# Number of results: 0
# ---- Running query 3/1515 - name = abricotier pays
# Wall time: 804 ms
# Number of results: 0
# ---- Running query 4/1515 - name = abricot pays
# Wall time: 815 ms
# Number of results: 0
# ---- Running query 5/1515 - name = abricotier des antilles
# Wall time: 750 ms
# Number of results: 0
# ---- Running query 6/1515 - name = mamey
# Wall time: 599 ms
# Number of results: 0
# ---- Running query 7/1515 - name = abricotier-pays
# Wall time: 763 ms
# Number of results: 0
# ---- Running query 8/1515 - name = actinidia
# Wall time: 786 ms
# Number of results: 0
# ---- Running query 9/1515 - name = groseille de chine
# Wall time: 771 ms
# Number of results: 0
# ---- Running query 10/1515 - name = kiwi
# Wall time: 716 ms
# Number of results: 0
# ---- Running query 11/1515 - name = yang tao
# Wall time: 696 ms
# Number of results: 0
# ---- Running query 12/1515 - name = actinidier
# Wall time: 800 ms
# Number of results: 0
# ---- Running query 13/1515 - name = agrume
# Wall time: 745 ms
# Number of results: 0
# ---- Running query 14/1515 - name = ail
# Wall time: 705 ms
# Number of results: 0
# ---- Running query 15/1515 - name = ail commun
# Wall time: 682 ms
# Number of results: 0
# ---- Running query 16/1515 - name = ail cultivé
# Wall time: 1.3 s
# Number of results: 0
# ---- Running query 17/1515 - name = aillet
# Wall time: 683 ms
# Number of results: 0
# ---- Running query 18/1515 - name = alpiste
# Wall time: 795 ms
# Number of results: 0
# ---- Running query 19/1515 - name = alpiste des canaries
# Wall time: 699 ms
# Number of results: 0
# ---- Running query 20/1515 - name = blé des canaries
# Wall time: 672 ms
# Number of results: 0
# ---- Running query 21/1515 - name = millet long
# Wall time: 711 ms
# Number of results: 0
# ---- Running query 22/1515 - name = amandier
# Wall time: 659 ms
# Number of results: 0
# ---- Running query 23/1515 - name = amandaie
# Wall time: 584 ms
# Number of results: 0
# ---- Running query 24/1515 - name = amande
# Wall time: 693 ms
# Number of results: 0
# ---- Running query 25/1515 - name = amande douce
# Wall time: 671 ms
# Number of results: 0
# ---- Running query 26/1515 - name = amanderaie
# Wall time: 693 ms
# Number of results: 0
# ---- Running query 27/1515 - name = ananas
# Wall time: 742 ms
# Number of results: 1
# ---- Running query 28/1515 - name = anémone
# Wall time: 612 ms
# Number of results: 1
# ---- Running query 29/1515 - name = aneth
# Wall time: 700 ms
# Number of results: 0
# ---- Running query 30/1515 - name = faux anis
# Wall time: 836 ms
# Number of results: 0
# ---- Running query 31/1515 - name = fenouil bâtard
# Wall time: 801 ms
# Number of results: 0
# ---- Running query 32/1515 - name = angélique
# Wall time: 798 ms
# Number of results: 1
# ---- Running query 33/1515 - name = angélique officinale
# Wall time: 793 ms
# Number of results: 0
# ---- Running query 34/1515 - name = archangélique
# Wall time: 789 ms
# Number of results: 0
# ---- Running query 35/1515 - name = anis vert
# Wall time: 768 ms
# Number of results: 0
# ---- Running query 36/1515 - name = anis
# Wall time: 713 ms
# Number of results: 0
# ---- Running query 37/1515 - name = graine d’anis
# Wall time: 746 ms
# Number of results: 0
# ---- Running query 38/1515 - name = arachide
# Wall time: 787 ms
# Number of results: 1
# ---- Running query 39/1515 - name = cacahouète
# Wall time: 761 ms
# Number of results: 0
# ---- Running query 40/1515 - name = cacahuète
# Wall time: 640 ms
# Number of results: 0
# ---- Running query 41/1515 - name = huile d’arachide
# Wall time: 692 ms
# Number of results: 0
# ---- Running query 42/1515 - name = arboriculture fruitière tropicale
# Wall time: 736 ms
# Number of results: 0
# ---- Running query 43/1515 - name = arbre à fruits tropicaux
# Wall time: 789 ms
# Number of results: 0
# ---- Running query 44/1515 - name = fruit tropical
# Wall time: 763 ms
# Number of results: 0
# ---- Running query 45/1515 - name = fruits tropicaux
# Wall time: 722 ms
# Number of results: 0
# ---- Running query 46/1515 - name = arboriculture ornementale
# Wall time: 740 ms
# Number of results: 0
# ---- Running query 47/1515 - name = végétaux d'ornement
# Wall time: 736 ms
# Number of results: 0
# ---- Running query 48/1515 - name = arbuste  à baies
# Wall time: 684 ms
# Number of results: 0
# ---- Running query 49/1515 - name = baie
# Wall time: 617 ms
# Number of results: 0
# ---- Running query 50/1515 - name = arbre à fruits à coques
# Wall time: 776 ms
# Number of results: 0
# ---- Running query 51/1515 - name = arbre à fruits secs
# Wall time: 757 ms
# Number of results: 0
# ---- Running query 52/1515 - name = fruit sec
# Wall time: 763 ms
# Number of results: 0
# ---- Running query 53/1515 - name = fruit à coque
# Wall time: 774 ms
# Number of results: 0
# ---- Running query 54/1515 - name = fruits à coques
# Wall time: 728 ms
# Number of results: 0
# ---- Running query 55/1515 - name = arbre fruitier à noyau
# Wall time: 680 ms
# Number of results: 0
# ---- Running query 56/1515 - name = arbre à noyau
# Wall time: 754 ms
# Number of results: 0
# ---- Running query 57/1515 - name = fruit à noyau
# Wall time: 779 ms
# Number of results: 0
# ---- Running query 58/1515 - name = arbre à fruits à pépins
# Wall time: 776 ms
# Number of results: 0
# ---- Running query 59/1515 - name = arbre à pépins
# Wall time: 755 ms
# Number of results: 0
# ---- Running query 60/1515 - name = fruit à pépins
# Wall time: 750 ms
# Number of results: 0
# ---- Running query 61/1515 - name = arroche
# Wall time: 743 ms
# Number of results: 0
# ---- Running query 62/1515 - name = artichaut
# Wall time: 760 ms
# Number of results: 1
# ---- Running query 478/1515 - name = courgette
# Wall time: 715 ms
# Number of results: 1
# ---- Running query 479/1515 - name = fleur de courgette
# Wall time: 697 ms
# Number of results: 0
# ---- Running query 480/1515 - name = cresson alénois plante de service
# Wall time: 737 ms
# Number of results: 0
# ---- Running query 481/1515 - name = crocus cultivé
# Wall time: 730 ms
# Number of results: 0
# ---- Running query 482/1515 - name = crocus à safran
# Wall time: 739 ms
# Number of results: 0
# ---- Running query 483/1515 - name = safran
# Wall time: 693 ms
# Number of results: 0
# ---- Running query 484/1515 - name = safran cultivé
# Wall time: 866 ms
# Number of results: 0
# ---- Running query 485/1515 - name = crosne
# Wall time: 685 ms
# Number of results: 0
# ---- Running query 486/1515 - name = crosne du japon
# Wall time: 494 ms
# Number of results: 0
# ---- Running query 487/1515 - name = jardins familiaux
# Wall time: 751 ms
# Number of results: 0
# ---- Running query 488/1515 - name = jardin familial
# Wall time: 741 ms
# Number of results: 0
# ---- Running query 489/1515 - name = jardins ouvriers
# Wall time: 716 ms
# Number of results: 0
# ---- Running query 490/1515 - name = potager
# Wall time: 741 ms
# Number of results: 0
# ---- Running query 491/1515 - name = vergers familiaux
# Wall time: 595 ms
# Number of results: 0
# ---- Running query 492/1515 - name = culture légumière de plein champ
# Wall time: 558 ms
# Number of results: 0
# ---- Running query 493/1515 - name = culture de plein champ
# Wall time: 692 ms
# Number of results: 0
# ---- Running query 494/1515 - name = culture plein champ
# Wall time: 706 ms
# Number of results: 0
# ---- Running query 495/1515 - name = légumes industries
# Wall time: 474 ms
# Number of results: 0
# ---- Running query 496/1515 - name = culture vivrière
# Wall time: 776 ms
# Number of results: 0
# ---- Running query 497/1515 - name = cumin
# Wall time: 723 ms
# Number of results: 1
# ---- Running query 498/1515 - name = faux anis
# Wall time: 695 ms
# Number of results: 0
# ---- Running query 499/1515 - name = cumin blanc
# Wall time: 559 ms
# Number of results: 0
# ---- Running query 500/1515 - name = cumin du maroc
# Wall time: 752 ms
# Number of results: 0
# ---- Running query 501/1515 - name = curcuma
# Wall time: 761 ms
# Number of results: 1
# ---- Running query 502/1515 - name = dactyle
# Wall time: 507 ms
# Number of results: 0
# ---- Running query 503/1515 - name = dactyle aggloméré
# Wall time: 744 ms
# Number of results: 0
# ---- Running query 504/1515 - name = dactyle pelotonné
# Wall time: 692 ms
# Number of results: 0
# ---- Running query 505/1515 - name = dolique asperge
# Wall time: 674 ms
# Number of results: 0
# ---- Running query 506/1515 - name = dolique à longue cosse
# Wall time: 684 ms
# Number of results: 0
# ---- Running query 507/1515 - name = dolique à longue gousse
# Wall time: 707 ms
# Number of results: 0
# ---- Running query 508/1515 - name = haricot asperge
# Wall time: 744 ms
# Number of results: 0
# ---- Running query 509/1515 - name = haricot kilomètre
# Wall time: 725 ms
# Number of results: 0
# ---- Running query 510/1515 - name = haricot vert chinois
# Wall time: 728 ms
# Number of results: 0
# ---- Running query 511/1515 - name = pois kilomètre
# Wall time: 560 ms
# Number of results: 0
# ---- Running query 512/1515 - name = échalion
# Wall time: 784 ms
# Number of results: 0
# ---- Running query 513/1515 - name = échalote cuisse de poulet
# Wall time: 716 ms
# Number of results: 0
# ---- Running query 514/1515 - name = échalote
# Wall time: 696 ms
# Number of results: 1
# ---- Running query 515/1515 - name = échalote de jersey
# Wall time: 602 ms
# Number of results: 0
# ---- Running query 516/1515 - name = échalote grise
# Wall time: 760 ms
# Number of results: 0
# ---- Running query 517/1515 - name = échalote rose
# Wall time: 775 ms
# Number of results: 0
# ---- Running query 518/1515 - name = échalote de plantation
# Wall time: 706 ms
# Number of results: 0
# ---- Running query 519/1515 - name = églantier
# Wall time: 763 ms
# Number of results: 0
# ---- Running query 520/1515 - name = cynorhodon
# Wall time: 650 ms
# Number of results: 0
# ---- Running query 521/1515 - name = cynorrhodon
# Wall time: 652 ms
# Number of results: 0
# ---- Running query 522/1515 - name = rosier sauvage
# Wall time: 1.05 s
# Number of results: 0
# ---- Running query 523/1515 - name = eleagnus
# Wall time: 758 ms
# Number of results: 0
# ---- Running query 524/1515 - name = engrain
# Wall time: 740 ms
# Number of results: 0
# ---- Running query 525/1515 - name = petit épeautre
# Wall time: 690 ms
# Number of results: 0
# ---- Running query 526/1515 - name = épeautre
# Wall time: 729 ms
# Number of results: 1
# ---- Running query 527/1515 - name = blé des gaulois
# Wall time: 740 ms
# Number of results: 0
# ---- Running query 528/1515 - name = grand épeautre
# Wall time: 737 ms
# Number of results: 0
# ---- Running query 529/1515 - name = épinard
# Wall time: 740 ms
# Number of results: 0
# ---- Running query 530/1515 - name = épinard d'automne
# Wall time: 900 ms
# Number of results: 0
# ---- Running query 531/1515 - name = épinard de printemps
# Wall time: 731 ms
# Number of results: 0
# ---- Running query 532/1515 - name = érable sycomore
# Wall time: 617 ms
# Number of results: 0
# ---- Running query 533/1515 - name = sycomore
# Wall time: 650 ms
# Number of results: 0
# ---- Running query 534/1515 - name = estragon
# Wall time: 717 ms
# Number of results: 0
# ---- Running query 535/1515 - name = fenouil
# Wall time: 542 ms
# ...
# ---- Running query 1342/1515 - name = carabin
# Wall time: 707 ms
# Number of results: 0
# ---- Running query 1343/1515 - name = froment noir
# Wall time: 563 ms
# Number of results: 0
# ---- Running query 1344/1515 - name = renouée sarrasin
# Wall time: 714 ms
# Number of results: 0
# ---- Running query 1345/1515 - name = sauge
# Wall time: 687 ms
# Number of results: 2
# ---- Running query 1346/1515 - name = sauge officinale
# Wall time: 769 ms
# Number of results: 2
# ---- Running query 1347/1515 - name = sauge sclarée
# Wall time: 754 ms
# Number of results: 0
# ---- Running query 1348/1515 - name = saule
# Wall time: 743 ms
# Number of results: 26
# ---- Running query 1349/1515 - name = saulaie
# Wall time: 525 ms
# Number of results: 0
# ---- Running query 1350/1515 - name = saulée
# Wall time: 657 ms
# Number of results: 0
# ---- Running query 1351/1515 - name = saussaie
# Wall time: 709 ms
# Number of results: 0
# ---- Running query 1352/1515 - name = scorsonère
# Wall time: 728 ms
# Number of results: 1
# Wall time: 782 ms
# Number of results: 0
# ---- Running query 1454/1515 - name = valériane
# Wall time: 738 ms
# Number of results: 1
# ---- Running query 1455/1515 - name = racine de valériane
# Wall time: 697 ms
# Number of results: 0
# ---- Running query 1456/1515 - name = valériane des petites feuilles
# Wall time: 761 ms
# Number of results: 0
# ---- Running query 1457/1515 - name = valériane officinale
# Wall time: 745 ms
# Number of results: 1
# ---- Running query 1458/1515 - name = vanillier
# Wall time: 613 ms
# Number of results: 0
# ---- Running query 1459/1515 - name = vanille
# Wall time: 1.24 s
# Number of results: 0
# ---- Running query 1460/1515 - name = vanille verte
# Wall time: 15.9 s
# Number of results: 0
# ---- Running query 1461/1515 - name = véronique
# Wall time: 789 ms
# Number of results: 3
# ---- Running query 1462/1515 - name = véronique officinale
# Wall time: 604 ms
# Number of results: 1
# ---- Running query 1463/1515 - name = verveine
# Wall time: 658 ms
# Number of results: 3
# ---- Running query 1464/1515 - name = vesce fourragère
# Wall time: 1.04 s
# Number of results: 0
# ---- Running query 1465/1515 - name = vesce
# Wall time: 711 ms
# Number of results: 0
# ---- Running query 1466/1515 - name = vesce commune
# Wall time: 685 ms
# Number of results: 0
# ---- Running query 1467/1515 - name = vesce cultivée
# Wall time: 785 ms
# Number of results: 1
# ---- Running query 1468/1515 - name = vesce d'hiver
# Wall time: 761 ms
# Number of results: 0
# ---- Running query 1469/1515 - name = vesce de cerdagne
# Wall time: 792 ms
# Number of results: 0
# ---- Running query 1470/1515 - name = vesce de hongrie
# Wall time: 778 ms
# Number of results: 0
# ---- Running query 1471/1515 - name = vesce de pannonie
# Wall time: 845 ms
# Number of results: 1
# ---- Running query 1472/1515 - name = vesce de printemps
# Wall time: 776 ms
# Number of results: 0
# ---- Running query 1473/1515 - name = vesce hiver
# Wall time: 720 ms
# Number of results: 0
# ---- Running query 1474/1515 - name = vesce printemps
# Wall time: 712 ms
# Number of results: 0
# ---- Running query 1475/1515 - name = vesce déshydratée
# Wall time: 799 ms
# Number of results: 0
# ---- Running query 1476/1515 - name = vétiver
# Wall time: 1.58 s
# Number of results: 1
# ---- Running query 1477/1515 - name = essence de vétiver
# Wall time: 803 ms
# Number of results: 0
# ---- Running query 1478/1515 - name = vétivier
# Wall time: 801 ms
# Number of results: 0
# ---- Running query 1479/1515 - name = vétyver
# Wall time: 799 ms
# Number of results: 0
# ---- Running query 1480/1515 - name = vigne agrément
# Wall time: 619 ms
# Number of results: 0
# ---- Running query 1481/1515 - name = vigne vierge
# Wall time: 748 ms
# Number of results: 0
# ---- Running query 1482/1515 - name = vigne cultivée
# Wall time: 775 ms
# Number of results: 0
# ---- Running query 1483/1515 - name = raisin
# Wall time: 741 ms
# Number of results: 0
# ---- Running query 1484/1515 - name = viticulture
# Wall time: 509 ms
# Number of results: 0
# ---- Running query 1485/1515 - name = vigne de cuve
# Wall time: 585 ms
# Number of results: 0
# ---- Running query 1486/1515 - name = vin
# Wall time: 765 ms
# Number of results: 0
# ---- Running query 1487/1515 - name = raisin de cuve
# Wall time: 761 ms
# Number of results: 0
# ---- Running query 1488/1515 - name = vigne: raisin de cuve non en production
# Wall time: 702 ms
# Number of results: 0
# ---- Running query 1489/1515 - name = vigne: raisins de cuve en production
# Wall time: 743 ms
# Number of results: 0
# ---- Running query 1490/1515 - name = vigne jus
# Wall time: 758 ms
# Number of results: 0
# ---- Running query 1491/1515 - name = jus de raisin
# Wall time: 683 ms
# Number of results: 0
# ---- Running query 1492/1515 - name = vigne jus de raisin
# Wall time: 647 ms
# Number of results: 0
# ---- Running query 1493/1515 - name = vigne rouge
# Wall time: 737 ms
# Number of results: 0
# ---- Running query 1494/1515 - name = feuille de vigne rouge
# Wall time: 776 ms
# Number of results: 0
# ---- Running query 1495/1515 - name = vigne de table
# Wall time: 777 ms
# Number of results: 0
# ---- Running query 1496/1515 - name = raisin de table
# Wall time: 719 ms
# Number of results: 0
# ---- Running query 1497/1515 - name = vigne: raisin de table
# Wall time: 751 ms
# Number of results: 0
# ---- Running query 1498/1515 - name = violette odorante
# Wall time: 499 ms
# Number of results: 1
# ---- Running query 1499/1515 - name = fleur de violette
# Wall time: 620 ms
# Number of results: 0
# ---- Running query 1500/1515 - name = violette parfumée
# Wall time: 710 ms
# Number of results: 0
# ---- Running query 1501/1515 - name = x-festulolium
# Wall time: 776 ms
# Number of results: 0
# ---- Running query 1502/1515 - name = festulolium
# Wall time: 740 ms
# Number of results: 0
# ---- Running query 1503/1515 - name = ylang-ylang
# Wall time: 675 ms
# Number of results: 1
# ---- Running query 1504/1515 - name = ylang ylang
# Wall time: 716 ms
# Number of results: 0
# ---- Running query 1505/1515 - name = zone non agricole
# Wall time: 758 ms
# Number of results: 0
# ---- Running query 1506/1515 - name = jardin
# Wall time: 479 ms
# Number of results: 0
# ---- Running query 1507/1515 - name = espace vert
# Wall time: 724 ms
# Number of results: 0
# ---- Running query 1508/1515 - name = parc
# Wall time: 784 ms
# Number of results: 0
# ---- Running query 1509/1515 - name = zna
# Wall time: 1.86 s
# Number of results: 0
# ---- Running query 1510/1515 - name = lin oléagineux d'hiver
# Wall time: 1.66 s
# Number of results: 0
# ---- Running query 1511/1515 - name = lin graine d'hiver
# Wall time: 700 ms
# Number of results: 0
# ---- Running query 1512/1515 - name = lin non textile d'hiver
# Wall time: 780 ms
# Number of results: 0
# ---- Running query 1513/1515 - name = lin oléagineux de printemps
# Wall time: 805 ms
# Number of results: 0
# ---- Running query 1514/1515 - name = lin graine de printemps
# Wall time: 805 ms
# Number of results: 0
# ---- Running query 1515/1515 - name = lin non textile de printemps
# Wall time: 611 ms
# Number of results: 0

# %%
# Number of matches
df_fcu_taxref_matched = df_fcu_taxref.dropna()
dataframe_preview(df_fcu_taxref_matched)
# Out:
# == Number of lines: 393
# == Number of unique values:
# fcu_concept         161
# fcu_name            185
# fcu_name_type         2
# taxref_full_name    369
# taxon               369
# rank                  4
# dtype: int64
#                                           fcu_concept         fcu_name  \
# 26    http://ontology.inrae.fr/frenchcropusage/Ananas           ananas
# 27  http://ontology.inrae.fr/frenchcropusage/Anemones          anémone
# 31  http://ontology.inrae.fr/frenchcropusage/Angel...        angélique
# 37  http://ontology.inrae.fr/frenchcropusage/Arach...         arachide
# 61  http://ontology.inrae.fr/frenchcropusage/Artic...        artichaut
# 64  http://ontology.inrae.fr/frenchcropusage/Asperges  asperge blanche
# 70   http://ontology.inrae.fr/frenchcropusage/Attiers   pomme cannelle
# 72  http://ontology.inrae.fr/frenchcropusage/Auber...        aubergine
# 73  http://ontology.inrae.fr/frenchcropusage/Avoca...        avocatier
# 77   http://ontology.inrae.fr/frenchcropusage/Avoines  avoine cultivée
#
#    fcu_name_type                                   taxref_full_name  \
# 26          pref                    Ananas comosus (L.) Merr., 1917
# 27          pref  Anemone hortensis nothosubsp. fulgens (J.Gay) ...
# 31          pref                 Dicorynia guianensis Amshoff, 1939
# 37          pref                          Arachis hypogaea L., 1753
# 61          pref                        Cynara cardunculus L., 1753
# 64           alt                           Asparagus albus L., 1753
# 70           alt                           Annona squamosa L., 1753
# 72          pref                         Solanum melongena L., 1753
# 73          pref                       Persea americana Mill., 1768
# 77           alt                Avena sativa subsp. sativa L., 1753
#
#                                      taxon  \
# 26  http://taxref.mnhn.fr/lod/taxon/447782
# 27  http://taxref.mnhn.fr/lod/taxon/131396
# 31  http://taxref.mnhn.fr/lod/taxon/733639
# 37  http://taxref.mnhn.fr/lod/taxon/611649
# 61   http://taxref.mnhn.fr/lod/taxon/93783
# 64   http://taxref.mnhn.fr/lod/taxon/84265
# 70  http://taxref.mnhn.fr/lod/taxon/446901
# 72  http://taxref.mnhn.fr/lod/taxon/124075
# 73  http://taxref.mnhn.fr/lod/taxon/447273
# 77  http://taxref.mnhn.fr/lod/taxon/132016
#
#                                             rank
# 26     http://taxref.mnhn.fr/lod/taxrank/Species
# 27  http://taxref.mnhn.fr/lod/taxrank/SubSpecies
# 31     http://taxref.mnhn.fr/lod/taxrank/Species
# 37     http://taxref.mnhn.fr/lod/taxrank/Species
# 61     http://taxref.mnhn.fr/lod/taxrank/Species
# 64     http://taxref.mnhn.fr/lod/taxrank/Species
# 70     http://taxref.mnhn.fr/lod/taxrank/Species
# 72     http://taxref.mnhn.fr/lod/taxrank/Species
# 73     http://taxref.mnhn.fr/lod/taxrank/Species
# 77  http://taxref.mnhn.fr/lod/taxrank/SubSpecies

# %% [markdown]
# ### Matches:
# - FCU: 161 unique concepts, 185 unique labels
# - TAXREF-LD: 369 unique taxa from 4 ranks

# %% [markdown]
# ### Exports

# %%
df_fcu_taxref.to_excel("result_fcu_taxref.xlsx")

# %%
# Reshape the DataFrame for later merging with other methods
df_fcu_taxref_matched.drop(columns=['fcu_name_type', 'fcu_name'], inplace=True)
df_fcu_taxref_matched.rename(columns={'taxref_full_name': 'taxref_ref_full_name'}, inplace=True)
df_fcu_taxref_matched.insert(1, 'method', 'direct')
df_fcu_taxref_matched.insert(2, 'geves_name', '')
df_fcu_taxref_matched.insert(3, 'eppo_scientific_name', '')
# Out:
# C:\Users\fmichel\anaconda3\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\fmichel\anaconda3\lib\site-packages\pandas\core\frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
dataframe_preview(df_fcu_taxref_matched)
df_fcu_taxref_matched.to_excel("result_fcu_taxref_merge.xlsx", index=False)
df_fcu_taxref_matched.to_csv("result_fcu_taxref_merge.csv", index=False)
# Out:
# == Number of lines: 393
# == Number of unique values:
# fcu_concept             161
# method                    1
# geves_name                1
# eppo_scientific_name      1
# taxref_ref_full_name    369
# taxon                   369
# rank                      4
# dtype: int64
#                                           fcu_concept  method geves_name  \
# 26    http://ontology.inrae.fr/frenchcropusage/Ananas  direct
# 27  http://ontology.inrae.fr/frenchcropusage/Anemones  direct
# 31  http://ontology.inrae.fr/frenchcropusage/Angel...  direct
# 37  http://ontology.inrae.fr/frenchcropusage/Arach...  direct
# 61  http://ontology.inrae.fr/frenchcropusage/Artic...  direct
# 64  http://ontology.inrae.fr/frenchcropusage/Asperges  direct
# 70   http://ontology.inrae.fr/frenchcropusage/Attiers  direct
# 72  http://ontology.inrae.fr/frenchcropusage/Auber...  direct
# 73  http://ontology.inrae.fr/frenchcropusage/Avoca...  direct
# 77   http://ontology.inrae.fr/frenchcropusage/Avoines  direct
#
#    eppo_scientific_name                               taxref_ref_full_name  \
# 26                                         Ananas comosus (L.) Merr., 1917
# 27                       Anemone hortensis nothosubsp. fulgens (J.Gay) ...
# 31                                      Dicorynia guianensis Amshoff, 1939
# 37                                               Arachis hypogaea L., 1753
# 61                                             Cynara cardunculus L., 1753
# 64                                                Asparagus albus L., 1753
# 70                                                Annona squamosa L., 1753
# 72                                              Solanum melongena L., 1753
# 73                                            Persea americana Mill., 1768
# 77                                     Avena sativa subsp. sativa L., 1753
#
#                                      taxon  \
# 26  http://taxref.mnhn.fr/lod/taxon/447782
# 27  http://taxref.mnhn.fr/lod/taxon/131396
# 31  http://taxref.mnhn.fr/lod/taxon/733639
# 37  http://taxref.mnhn.fr/lod/taxon/611649
# 61   http://taxref.mnhn.fr/lod/taxon/93783
# 64   http://taxref.mnhn.fr/lod/taxon/84265
# 70  http://taxref.mnhn.fr/lod/taxon/446901
# 72  http://taxref.mnhn.fr/lod/taxon/124075
# 73  http://taxref.mnhn.fr/lod/taxon/447273
# 77  http://taxref.mnhn.fr/lod/taxon/132016
#
#                                             rank
# 26     http://taxref.mnhn.fr/lod/taxrank/Species
# 27  http://taxref.mnhn.fr/lod/taxrank/SubSpecies
# 31     http://taxref.mnhn.fr/lod/taxrank/Species
# 37     http://taxref.mnhn.fr/lod/taxrank/Species
# 61     http://taxref.mnhn.fr/lod/taxrank/Species
# 64     http://taxref.mnhn.fr/lod/taxrank/Species
# 70     http://taxref.mnhn.fr/lod/taxrank/Species
# 72     http://taxref.mnhn.fr/lod/taxrank/Species
# 73     http://taxref.mnhn.fr/lod/taxrank/Species
# 77  http://taxref.mnhn.fr/lod/taxrank/SubSpecies
